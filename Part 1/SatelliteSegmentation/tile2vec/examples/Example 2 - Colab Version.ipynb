# %% [markdown]
# # Train a Tile2Vec Algorithm From Scratch

# %% [markdown]
# ## Step 1: Import Libraries and Mount google drive

# %% [markdown]
# **This notebook is intended to be run on Google Colab**

# %%
import sys
import os
import torch
from torch import optim
from time import time
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DIR = '../content/drive/MyDrive/tile2vec/'

# %%
tile2vec_dir = '/atlas/u/swang/software/GitHub/tile2vec'
sys.path.append('../')
sys.path.append(tile2vec_dir)

# %%
from src.datasets import TileTripletsDataset, GetBands, RandomFlipAndRotate, ClipAndScale, ToFloatTensor, triplet_dataloader
from src.tilenet import make_tilenet

# %%
from src.training import prep_triplets, train_triplet_epoch

# %%
# !unzip /content/drive/MyDrive/toa_triplets.zip > /dev/null

# %% [markdown]
# # Step 2. Set up dataloader

# %% [markdown]
# Run this if you wish to delete X number of images and reduce the training dataset size

# %%
triplet_nums = {}
for filename in os.listdir('../data/toa_triplets/'):
    triplet_num = filename.split("anchor")[0]
    triplet_num = triplet_num.split("neighbor")[0]
    triplet_num = triplet_num.split("distant")[0]

    if ".npy" in filename:
        triplet_nums[triplet_num] = 0

keys = []
for key in triplet_nums:
    keys.append(key)

# Reduce number of triplets (this time 2/3rds are kept)
keep_keys = keys[::582] 
#keep_keys = list(set(keys) - set(remove_keys))

kept_files = []
for filename in os.listdir('../data/toa_triplets/'):

    triplet_num = filename.split("anchor")[0]
    triplet_num = triplet_num.split("neighbor")[0]
    triplet_num = triplet_num.split("distant")[0]

    img_ext = filename.split(triplet_num)[1]

    if (triplet_num in keep_keys) and (".npy" in filename):
        new_filename = str(keep_keys.index(triplet_num)) + img_ext
        kept_files.append(new_filename)
        os.rename(os.path.join('../data/toa_triplets/', filename),os.path.join('../data/new_toa_triplets/', new_filename) )
    else:
        #os.remove(os.path.join('/content/toa_triplets/', filename))
        pass

# %% [markdown]
# Check new length of the dataset

# %%
print (len(os.listdir('../data/new_toa_triplets/')))
# Out:
# 303

# %% [markdown]
# Initialise Cuda

# %%
# Environment stuff
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
cuda = torch.cuda.is_available()
print('PyTorch is using GPU: {}'.format(cuda))
# Out:
# PyTorch is using GPU: False

# %% [markdown]
# Set up the dataloader for training.

# %%
# Change these arguments to match your directory and desired parameters
img_type = 'naip'
tile_dir = '../data/new_toa_triplets/'
bands = 3
augment = True
batch_size = 50
shuffle = True
num_workers = 4
n_triplets = 101

# %%
dataloader = triplet_dataloader(img_type, tile_dir, bands=bands, augment=augment,
                                batch_size=batch_size, shuffle=shuffle, num_workers=num_workers, 
                                n_triplets=n_triplets, pairs_only=True)
print('Dataloader set up complete.')
# Out:
# Dataloader set up complete.

# %% [markdown]
# # Step 3. Set up TileNet

# %%
in_channels = bands
z_dim = 512

# %%
TileNet = make_tilenet(in_channels=in_channels, z_dim=z_dim)

# Below commented lines are for loading a checkpoint

#model_fn = '/content/drive/MyDrive/models/TileNet_epoch61_toa_data.ckpt'
#checkpoint = torch.load(model_fn, map_location=torch.device('cpu'))
#TileNet.load_state_dict(checkpoint)

if cuda: TileNet.cuda()
print('TileNet set up complete.')
TileNet.train()
# Out:
# TileNet set up complete.
# TileNet(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): ResidualBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): ResidualBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): ResidualBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): ResidualBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): ResidualBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): ResidualBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer4): Sequential(
#     (0): ResidualBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): ResidualBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer5): Sequential(
#     (0): ResidualBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): ResidualBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
# )

# %% [markdown]
# Set up optimizer.

# %%
lr = 1e-3
optimizer = optim.Adam(TileNet.parameters(), lr=lr, betas=(0.5, 0.999))

# %% [markdown]
# # Step 4. Train Tile2Vec model!

# %%
epochs = 100
margin = 10
l2 = 0.01
print_every = 1000
save_models = True

# %% [markdown]
# Define the directory for saving models.

# %%
model_dir = '/content/drive/MyDrive/tile2vec/models/Tile2Vec'
if not os.path.exists(model_dir): os.makedirs(model_dir)

# %%
t0 = time()
avg_38802_img_losses = []
avg_38802_img_l_ns = []
avg_38802_img_l_ds = []
avg_38802_img_nds = []

with open("results_fn", 'w') as file:

    print('Begin training.................')
    for epoch in range(95, epochs):
        (avg_loss, avg_l_n, avg_l_d, avg_l_nd) = train_triplet_epoch(
            TileNet, cuda, dataloader, optimizer, epoch+1, margin=margin, l2=l2,
            print_every=print_every, t0=t0)
        avg_38802_img_losses.append(avg_loss)
        avg_38802_img_l_ns.append(avg_l_n)
        avg_38802_img_l_ds.append(avg_l_d)
        avg_38802_img_nds.append(avg_l_nd)
        # Save model after last epoch
        if save_models:
            model_fn = os.path.join(model_dir, 'TileNet_epoch{}_toa_data.ckpt'.format(epoch))
            torch.save(TileNet.state_dict(), model_fn)
# Out:
# Begin training.................
# Finished epoch 1: 65.142s
#   Num Batches: 3
#   Sum Loss: 39.18760108947754
#   Average loss: 13.0625
#   Average l_n: 7.6390
#   Average l_d: -8.5146
#   Average l_nd: -0.8756
#
# Finished epoch 2: 125.941s
#   Num Batches: 3
#   Sum Loss: 37.81863021850586
#   Average loss: 12.6062
#   Average l_n: 8.3711
#   Average l_d: -11.4333
#   Average l_nd: -3.0622
#
# Finished epoch 3: 195.594s
#   Num Batches: 3
#   Sum Loss: 34.282400131225586
#   Average loss: 11.4275
#   Average l_n: 6.5566
#   Average l_d: -7.7297
#   Average l_nd: -1.1730
#
# Finished epoch 4: 260.470s
#   Num Batches: 3
#   Sum Loss: 34.566630363464355
#   Average loss: 11.5222
#   Average l_n: 5.6348
#   Average l_d: -6.9989
#   Average l_nd: -1.3641
#
# Finished epoch 5: 324.866s
#   Num Batches: 3
#   Sum Loss: 34.04160976409912
#   Average loss: 11.3472
#   Average l_n: 3.8508
#   Average l_d: -4.2173
#   Average l_nd: -0.3665
#
# Finished epoch 6: 387.458s
#   Num Batches: 3
#   Sum Loss: 29.647513389587402
#   Average loss: 9.8825
#   Average l_n: 4.9544
#   Average l_d: -7.0192
#   Average l_nd: -2.0648
#
# Finished epoch 7: 450.985s
#   Num Batches: 3
#   Sum Loss: 31.851086616516113
#   Average loss: 10.6170
#   Average l_n: 4.9508
#   Average l_d: -6.3196
#   Average l_nd: -1.3688
#
# Finished epoch 8: 511.286s
#   Num Batches: 3
#   Sum Loss: 32.070008277893066
#   Average loss: 10.6900
#   Average l_n: 4.7920
#   Average l_d: -6.1253
#   Average l_nd: -1.3333
#
# Finished epoch 9: 569.431s
#   Num Batches: 3
#   Sum Loss: 31.381149291992188
#   Average loss: 10.4604
#   Average l_n: 3.7081
#   Average l_d: -4.8330
#   Average l_nd: -1.1249
#
# Finished epoch 10: 627.664s
#   Num Batches: 3
#   Sum Loss: 32.37980079650879
#   Average loss: 10.7933
#   Average l_n: 5.2618
#   Average l_d: -7.1976
#   Average l_nd: -1.9358
#
# Finished epoch 11: 703.616s
#   Num Batches: 3
#   Sum Loss: 33.08849239349365
#   Average loss: 11.0295
#   Average l_n: 6.5931
#   Average l_d: -7.6004
#   Average l_nd: -1.0073
#
# Finished epoch 12: 763.662s
#   Num Batches: 3
#   Sum Loss: 30.967623710632324
#   Average loss: 10.3225
#   Average l_n: 4.3646
#   Average l_d: -5.8921
#   Average l_nd: -1.5274
#
# Finished epoch 13: 824.320s
#   Num Batches: 3
#   Sum Loss: 30.59648323059082
#   Average loss: 10.1988
#   Average l_n: 4.1872
#   Average l_d: -5.8970
#   Average l_nd: -1.7098
#
# Finished epoch 14: 892.997s
#   Num Batches: 3
#   Sum Loss: 31.645156860351562
#   Average loss: 10.5484
#   Average l_n: 3.8259
#   Average l_d: -4.6621
#   Average l_nd: -0.8362
#
# Finished epoch 15: 965.995s
#   Num Batches: 3
#   Sum Loss: 29.844167709350586
#   Average loss: 9.9481
#   Average l_n: 3.4404
#   Average l_d: -5.0612
#   Average l_nd: -1.6209
#
# Finished epoch 16: 1035.907s
#   Num Batches: 3
#   Sum Loss: 31.569674491882324
#   Average loss: 10.5232
#   Average l_n: 3.3915
#   Average l_d: -4.2377
#   Average l_nd: -0.8462
#
# Finished epoch 17: 1113.631s
#   Num Batches: 3
#   Sum Loss: 30.250497817993164
#   Average loss: 10.0835
#   Average l_n: 3.8477
#   Average l_d: -5.3885
#   Average l_nd: -1.5408
#
# Finished epoch 18: 1191.596s
#   Num Batches: 3
#   Sum Loss: 29.118165016174316
#   Average loss: 9.7061
#   Average l_n: 4.6702
#   Average l_d: -7.0599
#   Average l_nd: -2.3897
#
# Finished epoch 19: 1251.870s
#   Num Batches: 3
#   Sum Loss: 30.717164993286133
#   Average loss: 10.2391
#   Average l_n: 4.1094
#   Average l_d: -5.9294
#   Average l_nd: -1.8199
#
# Finished epoch 20: 1315.670s
#   Num Batches: 3
#   Sum Loss: 31.818242073059082
#   Average loss: 10.6061
#   Average l_n: 4.4229
#   Average l_d: -5.9874
#   Average l_nd: -1.5645
#
# Finished epoch 21: 1395.816s
#   Num Batches: 3
#   Sum Loss: 30.45546245574951
#   Average loss: 10.1518
#   Average l_n: 3.5588
#   Average l_d: -5.1815
#   Average l_nd: -1.6227
#
# Finished epoch 22: 1479.809s
#   Num Batches: 3
#   Sum Loss: 30.724831581115723
#   Average loss: 10.2416
#   Average l_n: 3.9021
#   Average l_d: -5.8200
#   Average l_nd: -1.9179
#
# Finished epoch 23: 1558.092s
#   Num Batches: 3
#   Sum Loss: 28.44337558746338
#   Average loss: 9.4811
#   Average l_n: 3.5509
#   Average l_d: -5.9597
#   Average l_nd: -2.4088
#
# Finished epoch 24: 1622.033s
#   Num Batches: 3
#   Sum Loss: 28.29687786102295
#   Average loss: 9.4323
#   Average l_n: 3.3461
#   Average l_d: -5.4285
#   Average l_nd: -2.0824
#
# Finished epoch 25: 1679.319s
#   Num Batches: 3
#   Sum Loss: 28.797422409057617
#   Average loss: 9.5991
#   Average l_n: 3.9495
#   Average l_d: -6.0131
#   Average l_nd: -2.0635
#
# Finished epoch 26: 1736.572s
#   Num Batches: 3
#   Sum Loss: 27.94228982925415
#   Average loss: 9.3141
#   Average l_n: 3.9152
#   Average l_d: -6.2479
#   Average l_nd: -2.3327
#
# Finished epoch 27: 1796.363s
#   Num Batches: 3
#   Sum Loss: 29.55495834350586
#   Average loss: 9.8517
#   Average l_n: 2.8235
#   Average l_d: -4.4406
#   Average l_nd: -1.6171
#
# Finished epoch 28: 1858.427s
#   Num Batches: 3
#   Sum Loss: 30.392911911010742
#   Average loss: 10.1310
#   Average l_n: 3.8575
#   Average l_d: -5.1207
#   Average l_nd: -1.2632
#
# Finished epoch 29: 1919.303s
#   Num Batches: 3
#   Sum Loss: 32.777024269104004
#   Average loss: 10.9257
#   Average l_n: 5.4168
#   Average l_d: -6.1154
#   Average l_nd: -0.6985
#
# Finished epoch 30: 1975.053s
#   Num Batches: 3
#   Sum Loss: 33.76858711242676
#   Average loss: 11.2562
#   Average l_n: 4.1808
#   Average l_d: -4.2233
#   Average l_nd: -0.0426
#
# Finished epoch 31: 2031.574s
#   Num Batches: 3
#   Sum Loss: 31.975422859191895
#   Average loss: 10.6585
#   Average l_n: 2.5621
#   Average l_d: -2.8536
#   Average l_nd: -0.2914
#
# Finished epoch 32: 2089.631s
#   Num Batches: 3
#   Sum Loss: 30.194011688232422
#   Average loss: 10.0647
#   Average l_n: 2.4595
#   Average l_d: -3.3573
#   Average l_nd: -0.8977
#
# Finished epoch 33: 2147.132s
#   Num Batches: 3
#   Sum Loss: 27.075559616088867
#   Average loss: 9.0252
#   Average l_n: 3.1107
#   Average l_d: -5.3375
#   Average l_nd: -2.2268
#
# Finished epoch 34: 2205.490s
#   Num Batches: 3
#   Sum Loss: 28.408205032348633
#   Average loss: 9.4694
#   Average l_n: 4.2583
#   Average l_d: -6.5617
#   Average l_nd: -2.3034
#
# Finished epoch 35: 2266.183s
#   Num Batches: 3
#   Sum Loss: 28.20121192932129
#   Average loss: 9.4004
#   Average l_n: 3.7647
#   Average l_d: -6.0975
#   Average l_nd: -2.3328
#
# Finished epoch 36: 2321.479s
#   Num Batches: 3
#   Sum Loss: 28.336085319519043
#   Average loss: 9.4454
#   Average l_n: 3.2129
#   Average l_d: -5.2081
#   Average l_nd: -1.9951
#
# Finished epoch 37: 2378.422s
#   Num Batches: 3
#   Sum Loss: 24.617006301879883
#   Average loss: 8.2057
#   Average l_n: 2.6619
#   Average l_d: -6.3612
#   Average l_nd: -3.6993
#
# Finished epoch 38: 2438.907s
#   Num Batches: 3
#   Sum Loss: 27.918599128723145
#   Average loss: 9.3062
#   Average l_n: 3.8504
#   Average l_d: -5.9946
#   Average l_nd: -2.1443
#
# Finished epoch 39: 2501.711s
#   Num Batches: 3
#   Sum Loss: 26.595265865325928
#   Average loss: 8.8651
#   Average l_n: 2.8180
#   Average l_d: -6.0181
#   Average l_nd: -3.2001
#
# Finished epoch 40: 2557.886s
#   Num Batches: 3
#   Sum Loss: 26.012346267700195
#   Average loss: 8.6708
#   Average l_n: 2.5848
#   Average l_d: -5.4545
#   Average l_nd: -2.8697
#
# Finished epoch 41: 2613.493s
#   Num Batches: 3
#   Sum Loss: 27.254589080810547
#   Average loss: 9.0849
#   Average l_n: 2.7316
#   Average l_d: -5.9336
#   Average l_nd: -3.2020
#
# Finished epoch 42: 2669.065s
#   Num Batches: 3
#   Sum Loss: 33.26350784301758
#   Average loss: 11.0878
#   Average l_n: 4.3398
#   Average l_d: -4.9043
#   Average l_nd: -0.5646
#
# Finished epoch 43: 2726.238s
#   Num Batches: 3
#   Sum Loss: 30.7976016998291
#   Average loss: 10.2659
#   Average l_n: 3.3373
#   Average l_d: -4.1825
#   Average l_nd: -0.8452
#
# Finished epoch 44: 2782.229s
#   Num Batches: 3
#   Sum Loss: 27.774012565612793
#   Average loss: 9.2580
#   Average l_n: 2.5011
#   Average l_d: -4.3215
#   Average l_nd: -1.8204
#
# Finished epoch 45: 2837.764s
#   Num Batches: 3
#   Sum Loss: 26.63222074508667
#   Average loss: 8.8774
#   Average l_n: 3.2941
#   Average l_d: -6.4049
#   Average l_nd: -3.1108
#
# Finished epoch 46: 2911.352s
#   Num Batches: 3
#   Sum Loss: 27.071642875671387
#   Average loss: 9.0239
#   Average l_n: 2.8405
#   Average l_d: -5.2620
#   Average l_nd: -2.4215
#
# Finished epoch 47: 2978.702s
#   Num Batches: 3
#   Sum Loss: 28.66140604019165
#   Average loss: 9.5538
#   Average l_n: 3.0702
#   Average l_d: -5.3482
#   Average l_nd: -2.2780
#
# Finished epoch 48: 3055.920s
#   Num Batches: 3
#   Sum Loss: 26.773361206054688
#   Average loss: 8.9245
#   Average l_n: 3.5189
#   Average l_d: -5.9462
#   Average l_nd: -2.4273
#
# Finished epoch 49: 3119.799s
#   Num Batches: 3
#   Sum Loss: 29.018820762634277
#   Average loss: 9.6729
#   Average l_n: 3.7653
#   Average l_d: -5.6104
#   Average l_nd: -1.8451
# Finished epoch 50: 3187.067s
#   Num Batches: 3
#   Sum Loss: 27.698665618896484
#   Average loss: 9.2329
#   Average l_n: 3.4647
#   Average l_d: -5.8813
#   Average l_nd: -2.4165
#
# Finished epoch 51: 3262.776s
#   Num Batches: 3
#   Sum Loss: 25.58309555053711
#   Average loss: 8.5277
#   Average l_n: 2.6276
#   Average l_d: -5.8420
#   Average l_nd: -3.2144
#
# Finished epoch 52: 3335.028s
#   Num Batches: 3
#   Sum Loss: 28.219429969787598
#   Average loss: 9.4065
#   Average l_n: 3.4280
#   Average l_d: -5.2631
#   Average l_nd: -1.8351
#
# Finished epoch 53: 3408.116s
#   Num Batches: 3
#   Sum Loss: 25.762423515319824
#   Average loss: 8.5875
#   Average l_n: 2.5735
#   Average l_d: -5.7942
#   Average l_nd: -3.2207
#
# Finished epoch 54: 3503.495s
#   Num Batches: 3
#   Sum Loss: 26.899226188659668
#   Average loss: 8.9664
#   Average l_n: 2.9579
#   Average l_d: -5.8018
#   Average l_nd: -2.8439
#
# Finished epoch 55: 3625.308s
#   Num Batches: 3
#   Sum Loss: 26.261643409729004
#   Average loss: 8.7539
#   Average l_n: 2.7768
#   Average l_d: -5.6415
#   Average l_nd: -2.8647
#
# Finished epoch 56: 3732.674s
#   Num Batches: 3
#   Sum Loss: 27.208115100860596
#   Average loss: 9.0694
#   Average l_n: 2.6355
#   Average l_d: -4.9779
#   Average l_nd: -2.3424
#
# Finished epoch 57: 3827.246s
#   Num Batches: 3
#   Sum Loss: 27.85475254058838
#   Average loss: 9.2849
#   Average l_n: 2.3538
#   Average l_d: -4.3096
#   Average l_nd: -1.9559
#
# Finished epoch 58: 3951.544s
#   Num Batches: 3
#   Sum Loss: 27.280990600585938
#   Average loss: 9.0937
#   Average l_n: 3.3508
#   Average l_d: -5.8695
#   Average l_nd: -2.5187
#
# Finished epoch 59: 4053.275s
#   Num Batches: 3
#   Sum Loss: 25.76557445526123
#   Average loss: 8.5885
#   Average l_n: 2.6575
#   Average l_d: -6.3665
#   Average l_nd: -3.7090
#
# Finished epoch 60: 4139.994s
#   Num Batches: 3
#   Sum Loss: 25.922377109527588
#   Average loss: 8.6408
#   Average l_n: 2.2448
#   Average l_d: -4.8426
#   Average l_nd: -2.5978
#
# Finished epoch 61: 4200.871s
#   Num Batches: 3
#   Sum Loss: 26.726027011871338
#   Average loss: 8.9087
#   Average l_n: 1.8583
#   Average l_d: -3.9463
#   Average l_nd: -2.0881
#
# Finished epoch 62: 4268.876s
#   Num Batches: 3
#   Sum Loss: 28.402981758117676
#   Average loss: 9.4677
#   Average l_n: 2.7571
#   Average l_d: -4.6753
#   Average l_nd: -1.9182
#
# Finished epoch 63: 4351.952s
#   Num Batches: 3
#   Sum Loss: 24.94572114944458
#   Average loss: 8.3152
#   Average l_n: 2.3541
#   Average l_d: -5.5226
#   Average l_nd: -3.1685
#
# Finished epoch 64: 4420.080s
#   Num Batches: 3
#   Sum Loss: 24.422089099884033
#   Average loss: 8.1407
#   Average l_n: 2.3599
#   Average l_d: -5.7892
#   Average l_nd: -3.4293
#
# Finished epoch 65: 4514.984s
#   Num Batches: 3
#   Sum Loss: 28.797508239746094
#   Average loss: 9.5992
#   Average l_n: 3.2742
#   Average l_d: -5.0475
#   Average l_nd: -1.7733
#
# Finished epoch 66: 4587.315s
#   Num Batches: 3
#   Sum Loss: 25.493046760559082
#   Average loss: 8.4977
#   Average l_n: 2.1304
#   Average l_d: -5.3240
#   Average l_nd: -3.1937
#
# Finished epoch 67: 4655.246s
#   Num Batches: 3
#   Sum Loss: 25.718775749206543
#   Average loss: 8.5729
#   Average l_n: 1.8949
#   Average l_d: -4.3981
#   Average l_nd: -2.5032
#
# Finished epoch 68: 4719.836s
#   Num Batches: 3
#   Sum Loss: 27.7064847946167
#   Average loss: 9.2355
#   Average l_n: 2.4969
#   Average l_d: -5.3220
#   Average l_nd: -2.8251
#
# Finished epoch 69: 4807.038s
#   Num Batches: 3
#   Sum Loss: 28.170658111572266
#   Average loss: 9.3902
#   Average l_n: 2.8321
#   Average l_d: -5.0553
#   Average l_nd: -2.2232
#
# Finished epoch 70: 4899.695s
#   Num Batches: 3
#   Sum Loss: 26.192492485046387
#   Average loss: 8.7308
#   Average l_n: 2.3465
#   Average l_d: -5.4770
#   Average l_nd: -3.1305
#
# Finished epoch 71: 4963.463s
#   Num Batches: 3
#   Sum Loss: 27.238215446472168
#   Average loss: 9.0794
#   Average l_n: 3.1356
#   Average l_d: -5.5072
#   Average l_nd: -2.3716
#
# Finished epoch 72: 5030.779s
#   Num Batches: 3
#   Sum Loss: 27.55563449859619
#   Average loss: 9.1852
#   Average l_n: 2.8231
#   Average l_d: -4.9155
#   Average l_nd: -2.0925
#
# Finished epoch 73: 5088.756s
#   Num Batches: 3
#   Sum Loss: 29.435429573059082
#   Average loss: 9.8118
#   Average l_n: 3.3686
#   Average l_d: -5.1002
#   Average l_nd: -1.7317
#
# Finished epoch 74: 5146.323s
#   Num Batches: 3
#   Sum Loss: 27.028507709503174
#   Average loss: 9.0095
#   Average l_n: 2.7342
#   Average l_d: -4.8822
#   Average l_nd: -2.1480
#
# Finished epoch 75: 5203.285s
#   Num Batches: 3
#   Sum Loss: 26.82079792022705
#   Average loss: 8.9403
#   Average l_n: 3.1878
#   Average l_d: -5.6012
#   Average l_nd: -2.4134
#
# Finished epoch 76: 5260.093s
#   Num Batches: 3
#   Sum Loss: 27.707143783569336
#   Average loss: 9.2357
#   Average l_n: 3.0216
#   Average l_d: -4.9738
#   Average l_nd: -1.9522
#
# Finished epoch 77: 5316.359s
#   Num Batches: 3
#   Sum Loss: 28.134397506713867
#   Average loss: 9.3781
#   Average l_n: 3.2044
#   Average l_d: -5.0749
#   Average l_nd: -1.8706
#
# Finished epoch 78: 5373.873s
#   Num Batches: 3
#   Sum Loss: 28.07252597808838
#   Average loss: 9.3575
#   Average l_n: 2.6283
#   Average l_d: -4.5445
#   Average l_nd: -1.9162
#
# Finished epoch 79: 5429.552s
#   Num Batches: 3
#   Sum Loss: 26.534925937652588
#   Average loss: 8.8450
#   Average l_n: 2.3644
#   Average l_d: -4.9799
#   Average l_nd: -2.6155
#
# Finished epoch 80: 5485.157s
#   Num Batches: 3
#   Sum Loss: 31.403464317321777
#   Average loss: 10.4678
#   Average l_n: 4.3216
#   Average l_d: -5.1336
#   Average l_nd: -0.8119
#
# Finished epoch 81: 5542.955s
#   Num Batches: 3
#   Sum Loss: 31.28732967376709
#   Average loss: 10.4291
#   Average l_n: 3.9491
#   Average l_d: -4.8931
#   Average l_nd: -0.9440
#
# Finished epoch 82: 5602.945s
#   Num Batches: 3
#   Sum Loss: 28.69473361968994
#   Average loss: 9.5649
#   Average l_n: 3.7928
#   Average l_d: -5.7211
#   Average l_nd: -1.9283
#
# Finished epoch 83: 5680.622s
#   Num Batches: 3
#   Sum Loss: 28.617401123046875
#   Average loss: 9.5391
#   Average l_n: 4.2479
#   Average l_d: -6.9308
#   Average l_nd: -2.6830
#
# Finished epoch 84: 5739.476s
#   Num Batches: 3
#   Sum Loss: 29.92274045944214
#   Average loss: 9.9742
#   Average l_n: 3.8596
#   Average l_d: -5.3874
#   Average l_nd: -1.5277
#
# Finished epoch 85: 5798.842s
#   Num Batches: 3
#   Sum Loss: 27.3054141998291
#   Average loss: 9.1018
#   Average l_n: 2.5712
#   Average l_d: -4.9610
#   Average l_nd: -2.3898
#
# Finished epoch 86: 5866.931s
#   Num Batches: 3
#   Sum Loss: 27.45967388153076
#   Average loss: 9.1532
#   Average l_n: 3.0210
#   Average l_d: -5.7828
#   Average l_nd: -2.7618
#
# Finished epoch 87: 5941.899s
#   Num Batches: 3
#   Sum Loss: 29.797146797180176
#   Average loss: 9.9324
#   Average l_n: 3.1974
#   Average l_d: -4.6771
#   Average l_nd: -1.4797
#
# Finished epoch 88: 6011.906s
#   Num Batches: 3
#   Sum Loss: 24.02016544342041
#   Average loss: 8.0067
#   Average l_n: 2.2026
#   Average l_d: -5.6827
#   Average l_nd: -3.4801
#
# Finished epoch 89: 6081.202s
#   Num Batches: 3
#   Sum Loss: 27.593871116638184
#   Average loss: 9.1980
#   Average l_n: 3.0364
#   Average l_d: -5.6925
#   Average l_nd: -2.6561
#
# Finished epoch 90: 6150.602s
#   Num Batches: 3
#   Sum Loss: 26.186898231506348
#   Average loss: 8.7290
#   Average l_n: 3.5791
#   Average l_d: -7.0039
#   Average l_nd: -3.4248
#
# Finished epoch 91: 6212.168s
#   Num Batches: 3
#   Sum Loss: 26.059689044952393
#   Average loss: 8.6866
#   Average l_n: 2.7192
#   Average l_d: -5.7721
#   Average l_nd: -3.0529
#
# Finished epoch 92: 6280.193s
#   Num Batches: 3
#   Sum Loss: 24.52094602584839
#   Average loss: 8.1736
#   Average l_n: 2.3592
#   Average l_d: -5.4454
#   Average l_nd: -3.0861
#
# Finished epoch 93: 6351.696s
#   Num Batches: 3
#   Sum Loss: 28.025218963623047
#   Average loss: 9.3417
#   Average l_n: 3.7272
#   Average l_d: -6.3693
#   Average l_nd: -2.6420
#
# Finished epoch 94: 6427.549s
#   Num Batches: 3
#   Sum Loss: 25.592194080352783
#   Average loss: 8.5307
#   Average l_n: 2.9788
#   Average l_d: -6.1462
#   Average l_nd: -3.1674
#
# Finished epoch 95: 6496.903s
#   Num Batches: 3
#   Sum Loss: 23.657897472381592
#   Average loss: 7.8860
#   Average l_n: 2.3248
#   Average l_d: -6.4100
#   Average l_nd: -4.0853
#
# Finished epoch 96: 6557.656s
#   Num Batches: 3
#   Sum Loss: 24.765674591064453
#   Average loss: 8.2552
#   Average l_n: 2.3901
#   Average l_d: -5.7426
#   Average l_nd: -3.3525
#
# Finished epoch 97: 6618.989s
#   Num Batches: 3
#   Sum Loss: 28.324923038482666
#   Average loss: 9.4416
#   Average l_n: 3.1232
#   Average l_d: -5.2040
#   Average l_nd: -2.0807
#
# Finished epoch 98: 6679.168s
#   Num Batches: 3
#   Sum Loss: 24.8674898147583
#   Average loss: 8.2892
#   Average l_n: 2.5281
#   Average l_d: -6.0406
#   Average l_nd: -3.5124
# Finished epoch 99: 6742.265s
#   Num Batches: 3
#   Sum Loss: 26.655125617980957
#   Average loss: 8.8850
#   Average l_n: 2.9695
#   Average l_d: -5.4856
#   Average l_nd: -2.5161
#
# Finished epoch 100: 6814.286s
#   Num Batches: 3
#   Sum Loss: 25.10195541381836
#   Average loss: 8.3673
#   Average l_n: 2.6601
#   Average l_d: -5.8363
#   Average l_nd: -3.1762

# %%
np.save('/content/drive/MyDrive/tile2vec/models/38802Img/avg_38802_img_losses', avg_38802_img_losses)
np.save('/content/drive/MyDrive/tile2vec/models/38802Img/avg_38802_img_l_ns', avg_38802_img_l_ns)
np.save('/content/drive/MyDrive/tile2vec/models/38802Img/avg_38802_img_l_ds', avg_38802_img_l_ds)
np.save('/content/drive/MyDrive/tile2vec/models/38802Img/avg_38802_img_nds', avg_38802_img_nds)

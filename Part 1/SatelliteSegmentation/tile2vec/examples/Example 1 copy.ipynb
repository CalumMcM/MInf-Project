# %% [markdown]
# # Example 1: Sampling triplets from image dataset
# In this notebook, we'll demonstrate how to sample triplets for training a Tile2Vec model from an image dataset.

# %%
import numpy as np
import os
import sys
sys.path.append('../')
import matplotlib.pyplot as plt
from src.sample_tiles import *
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# In the workflow detailed in our paper, we exported NAIP imagery over Central California in a bunch of GeoTIFF files (the usual format with Google Earth Engine). We'll walk through sampling tiles from GeoTIFFs here, but a similar workflow can apply to other file formats as well.
#
# Note that this notebook requires the user to have GDAL installed.
#
# The sampling of triplet tiles can happen with an arbitrary number of images. The focus of our functions is on efficiency and scalability, since the overall area covered quite large and loading all images into memory is not advised. The process is broken down into:
#
# 1. Sampling triplets of images
# 2. Loading images one at a time and sampling tile centers from them
# 3. Extracting tiles given the tile center and radius
#
# For simplicity, here we'll assume we're sampling from just 1 GeoTIFF file.

# %% [markdown]
# ## Step 1. Sample image names

# %% [markdown]
# We assume that the anchor tile and neighbor tile will come from the same image, and the distant tile may or may not come from the same image. Therefore to sample $n$ triplets, we first sample $2n$ image names from which to sample tiles.
#
# Let's sample 20 tiles.

# %%
amazonia_img_dir = '../data/Amazonia' # directory where amazonia images are saved

cerrado_img_dir = '../data/Cerrado' # directory where cerrado images are saved

caatinga_img_dir = '../data/Caatinga' # directory where caatinga images are saved

# Get Amazonia triplets
amazonia_img_triplets = get_triplet_imgs(amazonia_img_dir, n_triplets=30000) # This means we need 40 images

# Get Cerrado triplets
cerrado_img_triplets = get_triplet_imgs(cerrado_img_dir, n_triplets=25000) # This means we need 40 images

# Get Amazonia
caatinga_img_triplets = get_triplet_imgs(caatinga_img_dir, n_triplets=25000) # This means we need 40 images


print(cerrado_img_triplets[:5,:])
# Out:
# [['22976.tif' '33454.tif']
#  ['39059.tif' '26841.tif']
#  ['42053.tif' '8553.tif']
#  ['23074.tif' '51593.tif']
#  ['28666.tif' '11566.tif']]

# %%
amazonia_quads = get_triplet_imgs_quad("Amazonia", quads=[1,2,3])

cerrado_quads = get_triplet_imgs_quad("Cerrado", quads=[1,2,3])

caatinga_quads = get_triplet_imgs_quad("Caatinga", quads=[1,2,3])


for quad in amazonia_quads:
    for img in quad:
        if not '.tif' in img:
            print (img)

# %% [markdown]
# Since we only have one image, all tiles are coming from 0.tif.

# %% [markdown]
# ## Steps 2 & 3. Load images, sample tile centers, and extract tiles

# %% [markdown]
# Next we feed the list of images into the get_triplet_tiles function, which loads in each image sequentially and samples tile centers for all tiles that come from that image. This way a given image is only loaded once.

# %%
img_dir = '../data'
tile_dir = '../data/toa_triplets' # where you want to save your tiles
tiles = get_triplet_tiles_simple(tile_dir,
                          img_dir, 
                          amazonia_quads,
                          cerrado_quads,
                          caatinga_quads,
                          training_quads = [1,2,3],
                          num_triplets_per_biome=190000,
                          seed = 1,
                          val_type='uint8',
                          bands_only=True,
                          save=True,
                          verbose=False)
# Out:
# CURRENT BIOME: Amazonia
#
#
# CURRENT QUAD: 1
#
#
# BIOME Amazonia progress: 0.02%
# BIOME Amazonia progress: 0.03%
# BIOME Amazonia progress: 0.05%
# BIOME Amazonia progress: 0.06%
# BIOME Amazonia progress: 0.08%
# BIOME Amazonia progress: 0.09%
# BIOME Amazonia progress: 0.11%
# BIOME Amazonia progress: 0.12%
# BIOME Amazonia progress: 0.14%
# BIOME Amazonia progress: 0.15%
# BIOME Amazonia progress: 0.17%
# BIOME Amazonia progress: 0.18%
# BIOME Amazonia progress: 0.20%
# BIOME Amazonia progress: 0.21%
# BIOME Amazonia progress: 0.23%
# BIOME Amazonia progress: 0.24%
# BIOME Amazonia progress: 0.26%
# BIOME Amazonia progress: 0.27%
# BIOME Amazonia progress: 0.29%
# BIOME Amazonia progress: 0.30%
# BIOME Amazonia progress: 0.32%
# BIOME Amazonia progress: 0.33%
# BIOME Amazonia progress: 0.35%
# BIOME Amazonia progress: 0.36%
# BIOME Amazonia progress: 0.38%
# BIOME Amazonia progress: 0.39%
# BIOME Amazonia progress: 0.41%
# BIOME Amazonia progress: 0.42%
# BIOME Amazonia progress: 0.44%
# BIOME Amazonia progress: 0.45%
# BIOME Amazonia progress: 0.47%
# BIOME Amazonia progress: 0.48%
# BIOME Amazonia progress: 0.50%
# BIOME Amazonia progress: 0.51%
# BIOME Amazonia progress: 0.53%
# BIOME Amazonia progress: 0.54%
# BIOME Amazonia progress: 0.56%
# BIOME Amazonia progress: 0.57%
# BIOME Amazonia progress: 0.59%
# BIOME Amazonia progress: 0.60%
# BIOME Amazonia progress: 0.62%
# BIOME Amazonia progress: 0.64%
# BIOME Amazonia progress: 0.65%
# BIOME Amazonia progress: 0.67%
# BIOME Amazonia progress: 0.68%
# BIOME Amazonia progress: 0.70%
# BIOME Amazonia progress: 0.71%
# BIOME Amazonia progress: 0.73%
# ../src/sample_tiles.py:274: RuntimeWarning: Mean of empty slice
#   mean = np.nanmean(new_tile)
# BIOME Amazonia progress: 0.74%
# BIOME Amazonia progress: 0.76%
# BIOME Amazonia progress: 0.77%
# BIOME Amazonia progress: 0.79%
# BIOME Amazonia progress: 0.80%
# BIOME Amazonia progress: 0.82%
# BIOME Amazonia progress: 0.83%
# BIOME Amazonia progress: 0.85%
# BIOME Amazonia progress: 0.86%
# BIOME Amazonia progress: 0.88%
# BIOME Amazonia progress: 0.89%
# BIOME Amazonia progress: 0.91%
# BIOME Amazonia progress: 0.92%
# BIOME Amazonia progress: 0.94%
# BIOME Amazonia progress: 0.95%
# BIOME Amazonia progress: 0.97%
# BIOME Amazonia progress: 0.98%
# BIOME Amazonia progress: 1.00%
# BIOME Amazonia progress: 1.01%
# BIOME Amazonia progress: 1.03%
# BIOME Amazonia progress: 1.04%
# BIOME Amazonia progress: 1.06%
# BIOME Amazonia progress: 1.07%
# BIOME Amazonia progress: 1.09%
# BIOME Amazonia progress: 1.10%
# BIOME Amazonia progress: 1.12%
# BIOME Amazonia progress: 1.13%
# BIOME Amazonia progress: 1.15%
# BIOME Amazonia progress: 1.16%
# BIOME Amazonia progress: 1.18%
# BIOME Amazonia progress: 1.19%
# BIOME Amazonia progress: 1.21%
# BIOME Amazonia progress: 1.22%
# BIOME Amazonia progress: 1.24%
# BIOME Amazonia progress: 1.25%
# BIOME Amazonia progress: 1.27%
# BIOME Amazonia progress: 1.29%
# BIOME Amazonia progress: 1.30%
# BIOME Amazonia progress: 1.32%
# BIOME Amazonia progress: 1.33%
# BIOME Amazonia progress: 1.35%
# BIOME Amazonia progress: 1.36%
# BIOME Amazonia progress: 1.38%
# BIOME Amazonia progress: 1.39%
# BIOME Amazonia progress: 1.41%
# BIOME Amazonia progress: 1.42%
# BIOME Amazonia progress: 1.44%
# BIOME Amazonia progress: 1.45%
# BIOME Amazonia progress: 1.47%
# BIOME Amazonia progress: 1.48%
# BIOME Amazonia progress: 1.50%
# BIOME Amazonia progress: 1.51%
# BIOME Amazonia progress: 1.53%
# BIOME Amazonia progress: 1.54%
# BIOME Amazonia progress: 1.56%
# BIOME Amazonia progress: 1.57%
# BIOME Amazonia progress: 1.59%
# BIOME Amazonia progress: 1.60%
# BIOME Amazonia progress: 1.62%
# BIOME Amazonia progress: 1.63%
# BIOME Amazonia progress: 1.65%
# BIOME Amazonia progress: 1.66%
# BIOME Amazonia progress: 1.68%
# BIOME Amazonia progress: 1.69%
# BIOME Amazonia progress: 1.71%
# BIOME Amazonia progress: 1.72%
# BIOME Amazonia progress: 1.74%
# BIOME Amazonia progress: 1.75%
# BIOME Amazonia progress: 1.77%
# BIOME Amazonia progress: 1.78%
# BIOME Amazonia progress: 1.80%
# BIOME Amazonia progress: 1.81%
# BIOME Amazonia progress: 1.83%
# BIOME Amazonia progress: 1.84%
# BIOME Amazonia progress: 1.86%
# BIOME Amazonia progress: 1.87%
# BIOME Amazonia progress: 1.89%
# BIOME Amazonia progress: 1.91%
# BIOME Amazonia progress: 1.92%
# BIOME Amazonia progress: 1.94%
# BIOME Amazonia progress: 1.95%
# BIOME Amazonia progress: 1.97%
# BIOME Amazonia progress: 1.98%
# BIOME Amazonia progress: 2.00%
# BIOME Amazonia progress: 2.01%
# BIOME Amazonia progress: 2.03%
# BIOME Amazonia progress: 2.04%
# BIOME Amazonia progress: 2.06%
# BIOME Amazonia progress: 2.07%
# BIOME Amazonia progress: 2.09%
# BIOME Amazonia progress: 2.10%
# BIOME Amazonia progress: 2.12%
# BIOME Amazonia progress: 2.13%
# BIOME Amazonia progress: 2.15%
# BIOME Amazonia progress: 2.16%
# BIOME Amazonia progress: 2.18%
# BIOME Amazonia progress: 2.19%
# BIOME Amazonia progress: 2.21%
# BIOME Amazonia progress: 2.22%
# BIOME Amazonia progress: 2.24%
# BIOME Amazonia progress: 2.25%
# BIOME Amazonia progress: 2.27%
# BIOME Amazonia progress: 2.28%
# BIOME Amazonia progress: 2.30%
# BIOME Amazonia progress: 2.31%
# BIOME Amazonia progress: 2.33%
# BIOME Amazonia progress: 2.34%
# BIOME Amazonia progress: 2.36%
# BIOME Amazonia progress: 2.37%
# BIOME Amazonia progress: 2.39%
# BIOME Amazonia progress: 2.40%
# BIOME Amazonia progress: 2.42%
# BIOME Amazonia progress: 2.43%
# BIOME Amazonia progress: 2.45%
# BIOME Amazonia progress: 2.46%
# BIOME Amazonia progress: 2.48%
# BIOME Amazonia progress: 2.49%
# BIOME Amazonia progress: 2.51%
# BIOME Amazonia progress: 2.52%
# BIOME Amazonia progress: 2.54%
# BIOME Amazonia progress: 2.56%
# BIOME Amazonia progress: 2.57%
# BIOME Amazonia progress: 2.59%
# BIOME Amazonia progress: 2.60%
# BIOME Amazonia progress: 2.62%
# BIOME Amazonia progress: 2.63%
# BIOME Amazonia progress: 2.65%
# BIOME Amazonia progress: 2.66%
# BIOME Amazonia progress: 2.68%
# BIOME Amazonia progress: 2.69%
# BIOME Amazonia progress: 2.71%
# BIOME Amazonia progress: 2.72%
# BIOME Amazonia progress: 2.74%
# BIOME Amazonia progress: 2.75%
# BIOME Amazonia progress: 2.77%
# BIOME Amazonia progress: 2.78%
# BIOME Amazonia progress: 2.80%
# BIOME Amazonia progress: 2.81%
# BIOME Amazonia progress: 2.83%
# BIOME Amazonia progress: 2.84%
# BIOME Amazonia progress: 2.86%
# BIOME Amazonia progress: 2.87%
# BIOME Amazonia progress: 2.89%
# BIOME Amazonia progress: 2.90%
# BIOME Amazonia progress: 2.92%
# BIOME Amazonia progress: 2.93%
# BIOME Amazonia progress: 2.95%
# BIOME Amazonia progress: 2.96%
# BIOME Amazonia progress: 2.98%
# BIOME Amazonia progress: 2.99%
# BIOME Amazonia progress: 3.01%
# BIOME Amazonia progress: 3.02%
# BIOME Amazonia progress: 3.04%
# BIOME Amazonia progress: 3.05%
# BIOME Amazonia progress: 3.07%
# BIOME Amazonia progress: 3.08%
# BIOME Amazonia progress: 3.10%
# BIOME Amazonia progress: 3.11%
# BIOME Amazonia progress: 3.13%
# BIOME Amazonia progress: 3.14%
# BIOME Amazonia progress: 3.16%
# BIOME Amazonia progress: 3.18%
# BIOME Amazonia progress: 3.19%
# BIOME Amazonia progress: 3.21%
# BIOME Amazonia progress: 3.22%
# BIOME Amazonia progress: 3.24%
# BIOME Amazonia progress: 3.25%
# BIOME Amazonia progress: 3.27%
# BIOME Amazonia progress: 3.28%
# BIOME Amazonia progress: 3.30%
# BIOME Amazonia progress: 3.31%
# BIOME Amazonia progress: 3.33%
# BIOME Amazonia progress: 3.34%
# BIOME Amazonia progress: 3.36%
# BIOME Amazonia progress: 3.37%
# BIOME Amazonia progress: 3.39%
# BIOME Amazonia progress: 3.40%
# BIOME Amazonia progress: 3.42%
# BIOME Amazonia progress: 3.43%
# BIOME Amazonia progress: 3.45%
# BIOME Amazonia progress: 3.46%
# BIOME Amazonia progress: 3.48%
# BIOME Amazonia progress: 3.49%
# BIOME Amazonia progress: 3.51%
# BIOME Amazonia progress: 3.52%
# BIOME Amazonia progress: 3.54%
# BIOME Amazonia progress: 3.55%
# BIOME Amazonia progress: 3.57%
# BIOME Amazonia progress: 3.58%
# BIOME Amazonia progress: 3.60%
# BIOME Amazonia progress: 3.61%
# BIOME Amazonia progress: 3.63%
# BIOME Amazonia progress: 3.64%
# BIOME Amazonia progress: 3.66%
# BIOME Amazonia progress: 3.67%
# BIOME Amazonia progress: 3.69%
# BIOME Amazonia progress: 3.70%
# BIOME Amazonia progress: 3.72%
# BIOME Amazonia progress: 3.73%
# BIOME Amazonia progress: 3.75%
# BIOME Amazonia progress: 3.76%
# BIOME Amazonia progress: 3.78%
# BIOME Amazonia progress: 3.79%
# BIOME Amazonia progress: 3.81%
# BIOME Amazonia progress: 3.83%
# BIOME Amazonia progress: 3.84%
# BIOME Amazonia progress: 3.86%
# BIOME Amazonia progress: 3.87%
# BIOME Amazonia progress: 3.89%
# BIOME Amazonia progress: 3.90%
# BIOME Amazonia progress: 3.92%
# BIOME Amazonia progress: 3.93%
# BIOME Amazonia progress: 3.95%
# BIOME Amazonia progress: 3.96%
# BIOME Amazonia progress: 3.98%
# BIOME Amazonia progress: 3.99%
# BIOME Amazonia progress: 4.01%
# BIOME Amazonia progress: 4.02%
# BIOME Amazonia progress: 4.04%
# BIOME Amazonia progress: 4.05%
# BIOME Amazonia progress: 4.07%
# BIOME Amazonia progress: 4.08%
# BIOME Amazonia progress: 4.10%
# BIOME Amazonia progress: 4.11%
# BIOME Amazonia progress: 4.13%
# BIOME Amazonia progress: 4.14%
# BIOME Amazonia progress: 4.16%
# BIOME Amazonia progress: 4.17%
# BIOME Amazonia progress: 4.19%
# BIOME Amazonia progress: 4.20%
# BIOME Amazonia progress: 4.22%
# BIOME Amazonia progress: 4.23%
# BIOME Amazonia progress: 4.25%
# BIOME Amazonia progress: 4.26%
# BIOME Amazonia progress: 4.28%
# BIOME Amazonia progress: 4.29%
# BIOME Amazonia progress: 4.31%
# BIOME Amazonia progress: 4.32%
# BIOME Amazonia progress: 4.34%
# BIOME Amazonia progress: 4.35%
# BIOME Amazonia progress: 4.37%
# BIOME Amazonia progress: 4.38%
# BIOME Amazonia progress: 4.40%
# BIOME Amazonia progress: 4.41%
# BIOME Amazonia progress: 4.43%
# BIOME Amazonia progress: 4.45%
# BIOME Amazonia progress: 4.46%
# BIOME Amazonia progress: 4.48%
# BIOME Amazonia progress: 4.49%
# BIOME Amazonia progress: 4.51%
# BIOME Amazonia progress: 4.52%
# BIOME Amazonia progress: 4.54%
# BIOME Amazonia progress: 4.55%
# BIOME Amazonia progress: 4.57%
# BIOME Amazonia progress: 4.58%
# BIOME Amazonia progress: 4.60%
# BIOME Amazonia progress: 4.61%
# BIOME Amazonia progress: 4.63%
# BIOME Amazonia progress: 4.64%
# BIOME Amazonia progress: 4.66%
# BIOME Amazonia progress: 4.67%
# BIOME Amazonia progress: 4.69%
# BIOME Amazonia progress: 4.70%
# BIOME Amazonia progress: 4.72%
# BIOME Amazonia progress: 4.73%
# BIOME Amazonia progress: 4.75%
# BIOME Amazonia progress: 4.76%
# BIOME Amazonia progress: 4.78%
# BIOME Amazonia progress: 4.79%
# BIOME Amazonia progress: 4.81%
# BIOME Amazonia progress: 4.82%
# BIOME Amazonia progress: 4.84%
# BIOME Amazonia progress: 4.85%
# BIOME Amazonia progress: 4.87%
# BIOME Amazonia progress: 4.88%
# BIOME Amazonia progress: 4.90%
# BIOME Amazonia progress: 4.91%
# BIOME Amazonia progress: 4.93%
# BIOME Amazonia progress: 4.94%
# BIOME Amazonia progress: 4.96%
# BIOME Amazonia progress: 4.97%
# BIOME Amazonia progress: 4.99%
# BIOME Amazonia progress: 5.00%
# BIOME Amazonia progress: 5.02%
# BIOME Amazonia progress: 5.03%
# BIOME Amazonia progress: 5.05%
# BIOME Amazonia progress: 5.07%
# BIOME Amazonia progress: 5.08%
# BIOME Amazonia progress: 5.10%
# BIOME Amazonia progress: 5.11%
# BIOME Amazonia progress: 5.13%
# BIOME Amazonia progress: 5.14%
# BIOME Amazonia progress: 5.16%
# BIOME Amazonia progress: 5.17%
# BIOME Amazonia progress: 5.19%
# BIOME Amazonia progress: 5.20%
# BIOME Amazonia progress: 5.22%
# BIOME Amazonia progress: 5.23%
# BIOME Amazonia progress: 5.25%
# BIOME Amazonia progress: 5.26%
# BIOME Amazonia progress: 5.28%
# BIOME Amazonia progress: 5.29%
# BIOME Amazonia progress: 5.31%
# BIOME Amazonia progress: 5.32%
# BIOME Amazonia progress: 5.34%
# BIOME Amazonia progress: 5.35%
# BIOME Amazonia progress: 5.37%
# BIOME Amazonia progress: 5.38%
# BIOME Amazonia progress: 5.40%
# BIOME Amazonia progress: 5.41%
# BIOME Amazonia progress: 5.43%
# BIOME Amazonia progress: 5.44%
# BIOME Amazonia progress: 5.46%
# BIOME Amazonia progress: 5.47%
# BIOME Amazonia progress: 5.49%
# BIOME Amazonia progress: 5.50%
# BIOME Amazonia progress: 5.52%
# BIOME Amazonia progress: 5.53%
# BIOME Amazonia progress: 5.55%
# BIOME Amazonia progress: 5.56%
# BIOME Amazonia progress: 5.58%
# BIOME Amazonia progress: 5.59%
# BIOME Amazonia progress: 5.61%
# BIOME Amazonia progress: 5.62%
# BIOME Amazonia progress: 5.64%
# BIOME Amazonia progress: 5.65%
# BIOME Amazonia progress: 5.67%
# BIOME Amazonia progress: 5.68%
# BIOME Amazonia progress: 5.70%
# BIOME Amazonia progress: 5.72%
# BIOME Amazonia progress: 5.73%
# BIOME Amazonia progress: 5.75%
# BIOME Amazonia progress: 5.76%
# BIOME Amazonia progress: 5.78%
# BIOME Amazonia progress: 5.79%
# BIOME Amazonia progress: 5.81%
# BIOME Amazonia progress: 5.82%
# BIOME Amazonia progress: 5.84%
# BIOME Amazonia progress: 5.85%
# BIOME Amazonia progress: 5.87%
# BIOME Amazonia progress: 5.88%
# BIOME Amazonia progress: 5.90%
# BIOME Amazonia progress: 5.91%
# BIOME Amazonia progress: 5.93%
# BIOME Amazonia progress: 5.94%
# BIOME Amazonia progress: 5.96%
# BIOME Amazonia progress: 5.97%
# BIOME Amazonia progress: 5.99%
# BIOME Amazonia progress: 6.00%
# BIOME Amazonia progress: 6.02%
# BIOME Amazonia progress: 6.03%
# BIOME Amazonia progress: 6.05%
# BIOME Amazonia progress: 6.06%
# BIOME Amazonia progress: 6.08%
# BIOME Amazonia progress: 6.09%
# BIOME Amazonia progress: 6.11%
# BIOME Amazonia progress: 6.12%
# BIOME Amazonia progress: 6.14%
# BIOME Amazonia progress: 6.15%
# BIOME Amazonia progress: 6.17%
# BIOME Amazonia progress: 6.18%
# BIOME Amazonia progress: 6.20%
# BIOME Amazonia progress: 6.21%
# BIOME Amazonia progress: 6.23%
# BIOME Amazonia progress: 6.24%
# BIOME Amazonia progress: 6.26%
# BIOME Amazonia progress: 6.27%
# BIOME Amazonia progress: 6.29%
# BIOME Amazonia progress: 6.30%
# BIOME Amazonia progress: 6.32%
# BIOME Amazonia progress: 6.34%
# BIOME Amazonia progress: 6.35%
# BIOME Amazonia progress: 6.37%
# BIOME Amazonia progress: 6.38%
# BIOME Amazonia progress: 6.40%
# BIOME Amazonia progress: 6.41%
# BIOME Amazonia progress: 6.43%
# BIOME Amazonia progress: 6.44%
# BIOME Amazonia progress: 6.46%
# BIOME Amazonia progress: 6.47%
# BIOME Amazonia progress: 6.49%
# BIOME Amazonia progress: 6.50%
# BIOME Amazonia progress: 6.52%
# BIOME Amazonia progress: 6.53%
# BIOME Amazonia progress: 6.55%
# BIOME Amazonia progress: 6.56%
# BIOME Amazonia progress: 6.58%
# BIOME Amazonia progress: 6.59%
# BIOME Amazonia progress: 6.61%
# BIOME Amazonia progress: 6.62%
# BIOME Amazonia progress: 6.64%
# BIOME Amazonia progress: 6.65%
# BIOME Amazonia progress: 6.67%
# BIOME Amazonia progress: 6.68%
# BIOME Amazonia progress: 6.70%
# BIOME Amazonia progress: 6.71%
# BIOME Amazonia progress: 6.73%
# BIOME Amazonia progress: 6.74%
# BIOME Amazonia progress: 6.76%
# BIOME Amazonia progress: 6.77%
# BIOME Amazonia progress: 6.79%
# BIOME Amazonia progress: 6.80%
# BIOME Amazonia progress: 6.82%
# BIOME Amazonia progress: 6.83%
# BIOME Amazonia progress: 6.85%
# BIOME Amazonia progress: 6.86%
# BIOME Amazonia progress: 6.88%
# BIOME Amazonia progress: 6.89%
# BIOME Amazonia progress: 6.91%
# BIOME Amazonia progress: 6.92%
# BIOME Amazonia progress: 6.94%
# BIOME Amazonia progress: 6.95%
# BIOME Amazonia progress: 6.97%
# BIOME Amazonia progress: 6.99%
# BIOME Amazonia progress: 7.00%
# BIOME Amazonia progress: 7.02%
# BIOME Amazonia progress: 7.03%
# BIOME Amazonia progress: 7.05%
# BIOME Amazonia progress: 7.06%
# BIOME Amazonia progress: 7.08%
# BIOME Amazonia progress: 7.09%
# BIOME Amazonia progress: 7.11%
# BIOME Amazonia progress: 7.12%
# BIOME Amazonia progress: 7.14%
# BIOME Amazonia progress: 7.15%
# BIOME Amazonia progress: 7.17%
# BIOME Amazonia progress: 7.18%
# BIOME Amazonia progress: 7.20%
# BIOME Amazonia progress: 7.21%
# BIOME Amazonia progress: 7.23%
# BIOME Amazonia progress: 7.24%
# BIOME Amazonia progress: 7.26%
# BIOME Amazonia progress: 7.27%
# BIOME Amazonia progress: 7.29%
# BIOME Amazonia progress: 7.30%
# BIOME Amazonia progress: 7.32%
# BIOME Amazonia progress: 7.33%
# BIOME Amazonia progress: 7.35%
# BIOME Amazonia progress: 7.36%
# BIOME Amazonia progress: 7.38%
# BIOME Amazonia progress: 7.39%
# BIOME Amazonia progress: 7.41%
# BIOME Amazonia progress: 7.42%
# BIOME Amazonia progress: 7.44%
# BIOME Amazonia progress: 7.45%
# BIOME Amazonia progress: 7.47%
# BIOME Amazonia progress: 7.48%
# BIOME Amazonia progress: 7.50%
# BIOME Amazonia progress: 7.51%
# BIOME Amazonia progress: 7.53%
# BIOME Amazonia progress: 7.54%
# BIOME Amazonia progress: 7.56%
# BIOME Amazonia progress: 7.57%
# BIOME Amazonia progress: 7.59%
# BIOME Amazonia progress: 7.61%
# BIOME Amazonia progress: 7.62%
# BIOME Amazonia progress: 7.64%
# BIOME Amazonia progress: 7.65%
# BIOME Amazonia progress: 7.67%
# BIOME Amazonia progress: 7.68%
# BIOME Amazonia progress: 7.70%
# BIOME Amazonia progress: 7.71%
# BIOME Amazonia progress: 7.73%
# BIOME Amazonia progress: 7.74%
# BIOME Amazonia progress: 7.76%
# BIOME Amazonia progress: 7.77%
# BIOME Amazonia progress: 7.79%
# BIOME Amazonia progress: 7.80%
# BIOME Amazonia progress: 7.82%
# BIOME Amazonia progress: 7.83%
# BIOME Amazonia progress: 7.85%
# BIOME Amazonia progress: 7.86%
# BIOME Amazonia progress: 7.88%
# BIOME Amazonia progress: 7.89%
# BIOME Amazonia progress: 7.91%
# BIOME Amazonia progress: 7.92%
# BIOME Amazonia progress: 7.94%
# BIOME Amazonia progress: 7.95%
# BIOME Amazonia progress: 7.97%
# BIOME Amazonia progress: 7.98%
# BIOME Amazonia progress: 8.00%
# BIOME Amazonia progress: 8.01%
# BIOME Amazonia progress: 8.03%
# BIOME Amazonia progress: 8.04%
# BIOME Amazonia progress: 8.06%
# BIOME Amazonia progress: 8.07%
# BIOME Amazonia progress: 8.09%
# BIOME Amazonia progress: 8.10%
# BIOME Amazonia progress: 8.12%
# BIOME Amazonia progress: 8.13%
# BIOME Amazonia progress: 8.15%
# BIOME Amazonia progress: 8.16%
# BIOME Amazonia progress: 8.18%
# BIOME Amazonia progress: 8.19%
# BIOME Amazonia progress: 8.21%
# BIOME Amazonia progress: 8.22%
# BIOME Amazonia progress: 8.24%
# BIOME Amazonia progress: 8.26%
# BIOME Amazonia progress: 8.27%
# BIOME Amazonia progress: 8.29%
# BIOME Amazonia progress: 8.30%
# BIOME Amazonia progress: 8.32%
# BIOME Amazonia progress: 8.33%
# BIOME Amazonia progress: 8.35%
# BIOME Amazonia progress: 8.36%
# BIOME Amazonia progress: 8.38%
# BIOME Amazonia progress: 8.39%
# BIOME Amazonia progress: 8.41%
# BIOME Amazonia progress: 8.42%
# BIOME Amazonia progress: 8.44%
# BIOME Amazonia progress: 8.45%
# BIOME Amazonia progress: 8.47%
# BIOME Amazonia progress: 8.48%
# BIOME Amazonia progress: 8.50%
# BIOME Amazonia progress: 8.51%
# BIOME Amazonia progress: 8.53%
# BIOME Amazonia progress: 8.54%
# BIOME Amazonia progress: 8.56%
# BIOME Amazonia progress: 8.57%
# BIOME Amazonia progress: 8.59%
# BIOME Amazonia progress: 8.60%
# BIOME Amazonia progress: 8.62%
# BIOME Amazonia progress: 8.63%
# BIOME Amazonia progress: 8.65%
# BIOME Amazonia progress: 8.66%
# BIOME Amazonia progress: 8.68%
# BIOME Amazonia progress: 8.69%
# BIOME Amazonia progress: 8.71%
# BIOME Amazonia progress: 8.72%
# BIOME Amazonia progress: 8.74%
# BIOME Amazonia progress: 8.75%
# BIOME Amazonia progress: 8.77%
# BIOME Amazonia progress: 8.78%
# BIOME Amazonia progress: 8.80%
# BIOME Amazonia progress: 8.81%
# BIOME Amazonia progress: 8.83%
# BIOME Amazonia progress: 8.84%
# BIOME Amazonia progress: 8.86%
# BIOME Amazonia progress: 8.88%
# BIOME Amazonia progress: 8.89%
# BIOME Amazonia progress: 8.91%
# BIOME Amazonia progress: 8.92%
# BIOME Amazonia progress: 8.94%
# BIOME Amazonia progress: 8.95%
# BIOME Amazonia progress: 8.97%
# BIOME Amazonia progress: 8.98%
# BIOME Amazonia progress: 9.00%
# BIOME Amazonia progress: 9.01%
# BIOME Amazonia progress: 9.03%
# BIOME Amazonia progress: 9.04%
# BIOME Amazonia progress: 9.06%
# BIOME Amazonia progress: 9.07%
# BIOME Amazonia progress: 9.09%
# BIOME Amazonia progress: 9.10%
# BIOME Amazonia progress: 9.12%
# BIOME Amazonia progress: 9.13%
# BIOME Amazonia progress: 9.15%
# BIOME Amazonia progress: 9.16%
# BIOME Amazonia progress: 9.18%
# BIOME Amazonia progress: 9.19%
# BIOME Amazonia progress: 9.21%
# BIOME Amazonia progress: 9.22%
# BIOME Amazonia progress: 9.24%
# BIOME Amazonia progress: 9.25%
# BIOME Amazonia progress: 9.27%
# BIOME Amazonia progress: 9.28%
# BIOME Amazonia progress: 9.30%
# BIOME Amazonia progress: 9.31%
# BIOME Amazonia progress: 9.33%
# BIOME Amazonia progress: 9.34%
# BIOME Amazonia progress: 9.36%
# BIOME Amazonia progress: 9.37%
# BIOME Amazonia progress: 9.39%
# BIOME Amazonia progress: 9.40%
# BIOME Amazonia progress: 9.42%
# BIOME Amazonia progress: 9.43%
# BIOME Amazonia progress: 9.45%
# BIOME Amazonia progress: 9.46%
# BIOME Amazonia progress: 9.48%
# BIOME Amazonia progress: 9.50%
# BIOME Amazonia progress: 9.51%
# BIOME Amazonia progress: 9.53%
# BIOME Amazonia progress: 9.54%
# BIOME Amazonia progress: 9.56%
# BIOME Amazonia progress: 9.57%
# BIOME Amazonia progress: 9.59%
# BIOME Amazonia progress: 9.60%
# BIOME Amazonia progress: 9.62%
# BIOME Amazonia progress: 9.63%
# BIOME Amazonia progress: 9.65%
# BIOME Amazonia progress: 9.66%
# BIOME Amazonia progress: 9.68%
# BIOME Amazonia progress: 9.69%
# BIOME Amazonia progress: 9.71%
# BIOME Amazonia progress: 9.72%
# BIOME Amazonia progress: 9.74%
# BIOME Amazonia progress: 9.75%
# BIOME Amazonia progress: 9.77%
# BIOME Amazonia progress: 9.78%
# BIOME Amazonia progress: 9.80%
# BIOME Amazonia progress: 9.81%
# BIOME Amazonia progress: 9.83%
# BIOME Amazonia progress: 9.84%
# BIOME Amazonia progress: 9.86%
# BIOME Amazonia progress: 9.87%
# BIOME Amazonia progress: 9.89%
# BIOME Amazonia progress: 9.90%
# BIOME Amazonia progress: 9.92%
# BIOME Amazonia progress: 9.93%
# BIOME Amazonia progress: 9.95%
# BIOME Amazonia progress: 9.96%
# BIOME Amazonia progress: 9.98%
# BIOME Amazonia progress: 9.99%
# BIOME Amazonia progress: 10.01%
# BIOME Amazonia progress: 10.02%
# BIOME Amazonia progress: 10.04%
# BIOME Amazonia progress: 10.05%
# BIOME Amazonia progress: 10.07%
# BIOME Amazonia progress: 10.08%
# BIOME Amazonia progress: 10.10%
# BIOME Amazonia progress: 10.11%
# BIOME Amazonia progress: 10.13%
# BIOME Amazonia progress: 10.15%
# BIOME Amazonia progress: 10.16%
# BIOME Amazonia progress: 10.18%
# BIOME Amazonia progress: 10.19%
# BIOME Amazonia progress: 10.21%
# BIOME Amazonia progress: 10.22%
# BIOME Amazonia progress: 10.24%
# BIOME Amazonia progress: 10.25%
# BIOME Amazonia progress: 10.27%
# BIOME Amazonia progress: 10.28%
# BIOME Amazonia progress: 10.30%
# BIOME Amazonia progress: 10.31%
# BIOME Amazonia progress: 10.33%
# BIOME Amazonia progress: 10.34%
# BIOME Amazonia progress: 10.36%
# BIOME Amazonia progress: 10.37%
# BIOME Amazonia progress: 10.39%
# BIOME Amazonia progress: 10.40%
# BIOME Amazonia progress: 10.42%
# BIOME Amazonia progress: 10.43%
# BIOME Amazonia progress: 10.45%
# BIOME Amazonia progress: 10.46%
# BIOME Amazonia progress: 10.48%
# BIOME Amazonia progress: 10.49%
# BIOME Amazonia progress: 10.51%
# BIOME Amazonia progress: 10.52%
# BIOME Amazonia progress: 10.54%
# BIOME Amazonia progress: 10.55%
# BIOME Amazonia progress: 10.57%
# BIOME Amazonia progress: 10.58%
# BIOME Amazonia progress: 10.60%
# BIOME Amazonia progress: 10.61%
# BIOME Amazonia progress: 10.63%
# BIOME Amazonia progress: 10.64%
# BIOME Amazonia progress: 10.66%
# BIOME Amazonia progress: 10.67%
# BIOME Amazonia progress: 10.69%
# BIOME Amazonia progress: 10.70%
# BIOME Amazonia progress: 10.72%
# BIOME Amazonia progress: 10.73%
# BIOME Amazonia progress: 10.75%
# BIOME Amazonia progress: 10.77%
# BIOME Amazonia progress: 10.78%
# BIOME Amazonia progress: 10.80%
# BIOME Amazonia progress: 10.81%
# BIOME Amazonia progress: 10.83%
# BIOME Amazonia progress: 10.84%
# BIOME Amazonia progress: 10.86%
# BIOME Amazonia progress: 10.87%
# BIOME Amazonia progress: 10.89%
# BIOME Amazonia progress: 10.90%
# BIOME Amazonia progress: 10.92%
# BIOME Amazonia progress: 10.93%
# BIOME Amazonia progress: 10.95%
# BIOME Amazonia progress: 10.96%
# BIOME Amazonia progress: 10.98%
# BIOME Amazonia progress: 10.99%
# BIOME Amazonia progress: 11.01%
# BIOME Amazonia progress: 11.02%
# BIOME Amazonia progress: 11.04%
# BIOME Amazonia progress: 11.05%
# BIOME Amazonia progress: 11.07%
# BIOME Amazonia progress: 11.08%
# BIOME Amazonia progress: 11.10%
# BIOME Amazonia progress: 11.11%
# BIOME Amazonia progress: 11.13%
# BIOME Amazonia progress: 11.14%
# BIOME Amazonia progress: 11.16%
# BIOME Amazonia progress: 11.17%
# BIOME Amazonia progress: 11.19%
# BIOME Amazonia progress: 11.20%
# BIOME Amazonia progress: 11.22%
# BIOME Amazonia progress: 11.23%
# BIOME Amazonia progress: 11.25%
# BIOME Amazonia progress: 11.26%
# BIOME Amazonia progress: 11.28%
# BIOME Amazonia progress: 11.29%
# BIOME Amazonia progress: 11.31%
# BIOME Amazonia progress: 11.32%
# BIOME Amazonia progress: 11.34%
# BIOME Amazonia progress: 11.35%
# BIOME Amazonia progress: 11.37%
# BIOME Amazonia progress: 11.38%
# BIOME Amazonia progress: 11.40%
# BIOME Amazonia progress: 11.42%
# BIOME Amazonia progress: 11.43%
# BIOME Amazonia progress: 11.45%
# BIOME Amazonia progress: 11.46%
# BIOME Amazonia progress: 11.48%
# BIOME Amazonia progress: 11.49%
# BIOME Amazonia progress: 11.51%
# BIOME Amazonia progress: 11.52%
# BIOME Amazonia progress: 11.54%
# BIOME Amazonia progress: 11.55%
# BIOME Amazonia progress: 11.57%
# BIOME Amazonia progress: 11.58%
# BIOME Amazonia progress: 11.60%
# BIOME Amazonia progress: 11.61%
# BIOME Amazonia progress: 11.63%
# BIOME Amazonia progress: 11.64%
# BIOME Amazonia progress: 11.66%
# BIOME Amazonia progress: 11.67%
# BIOME Amazonia progress: 11.69%
# BIOME Amazonia progress: 11.70%
# BIOME Amazonia progress: 11.72%
# BIOME Amazonia progress: 11.73%
# BIOME Amazonia progress: 11.75%
# BIOME Amazonia progress: 11.76%
# BIOME Amazonia progress: 11.78%
# BIOME Amazonia progress: 11.79%
# BIOME Amazonia progress: 11.81%
# BIOME Amazonia progress: 11.82%
# BIOME Amazonia progress: 11.84%
# BIOME Amazonia progress: 11.85%
# BIOME Amazonia progress: 11.87%
# BIOME Amazonia progress: 11.88%
# BIOME Amazonia progress: 11.90%
# BIOME Amazonia progress: 11.91%
# BIOME Amazonia progress: 11.93%
# BIOME Amazonia progress: 11.94%
# BIOME Amazonia progress: 11.96%
# BIOME Amazonia progress: 11.97%
# BIOME Amazonia progress: 11.99%
# BIOME Amazonia progress: 12.00%
# BIOME Amazonia progress: 12.02%
# BIOME Amazonia progress: 12.04%
# BIOME Amazonia progress: 12.05%
# BIOME Amazonia progress: 12.07%
# BIOME Amazonia progress: 12.08%
# BIOME Amazonia progress: 12.10%
# BIOME Amazonia progress: 12.11%
# BIOME Amazonia progress: 12.13%
# BIOME Amazonia progress: 12.14%
# BIOME Amazonia progress: 12.16%
# BIOME Amazonia progress: 12.17%
# BIOME Amazonia progress: 12.19%
# BIOME Amazonia progress: 12.20%
# BIOME Amazonia progress: 12.22%
# BIOME Amazonia progress: 12.23%
# BIOME Amazonia progress: 12.25%
# BIOME Amazonia progress: 12.26%
# BIOME Amazonia progress: 12.28%
# BIOME Amazonia progress: 12.29%
# BIOME Amazonia progress: 12.31%
# BIOME Amazonia progress: 12.32%
# BIOME Amazonia progress: 12.34%
# BIOME Amazonia progress: 12.35%
# BIOME Amazonia progress: 12.37%
# BIOME Amazonia progress: 12.38%
# BIOME Amazonia progress: 12.40%
# BIOME Amazonia progress: 12.41%
# BIOME Amazonia progress: 12.43%
# BIOME Amazonia progress: 12.44%
# BIOME Amazonia progress: 12.46%
# BIOME Amazonia progress: 12.47%
# BIOME Amazonia progress: 12.49%
# BIOME Amazonia progress: 12.50%
# BIOME Amazonia progress: 12.52%
# BIOME Amazonia progress: 12.53%
# BIOME Amazonia progress: 12.55%
# BIOME Amazonia progress: 12.56%
# BIOME Amazonia progress: 12.58%
# BIOME Amazonia progress: 12.59%
# BIOME Amazonia progress: 12.61%
# BIOME Amazonia progress: 12.62%
# BIOME Amazonia progress: 12.64%
# BIOME Amazonia progress: 12.65%
# BIOME Amazonia progress: 12.67%
# BIOME Amazonia progress: 12.69%
# BIOME Amazonia progress: 12.70%
# BIOME Amazonia progress: 12.72%
# BIOME Amazonia progress: 12.73%
# BIOME Amazonia progress: 12.75%
# BIOME Amazonia progress: 12.76%
# BIOME Amazonia progress: 12.78%
# BIOME Amazonia progress: 12.79%
# BIOME Amazonia progress: 12.81%
# BIOME Amazonia progress: 12.82%
# BIOME Amazonia progress: 12.84%
# BIOME Amazonia progress: 12.85%
# BIOME Amazonia progress: 12.87%
# BIOME Amazonia progress: 12.88%
# BIOME Amazonia progress: 12.90%
# BIOME Amazonia progress: 12.91%
# BIOME Amazonia progress: 12.93%
# BIOME Amazonia progress: 12.94%
# BIOME Amazonia progress: 12.96%
# BIOME Amazonia progress: 12.97%
# BIOME Amazonia progress: 12.99%
# BIOME Amazonia progress: 13.00%
# BIOME Amazonia progress: 13.02%
# BIOME Amazonia progress: 13.03%
# BIOME Amazonia progress: 13.05%
# BIOME Amazonia progress: 13.06%
# BIOME Amazonia progress: 13.08%
# BIOME Amazonia progress: 13.09%
# BIOME Amazonia progress: 13.11%
# BIOME Amazonia progress: 13.12%
# BIOME Amazonia progress: 13.14%
# BIOME Amazonia progress: 13.15%
# BIOME Amazonia progress: 13.17%
# BIOME Amazonia progress: 13.18%
# BIOME Amazonia progress: 13.20%
# BIOME Amazonia progress: 13.21%
# BIOME Amazonia progress: 13.23%
# BIOME Amazonia progress: 13.24%
# BIOME Amazonia progress: 13.26%
# BIOME Amazonia progress: 13.27%
# BIOME Amazonia progress: 13.29%
# BIOME Amazonia progress: 13.31%
# BIOME Amazonia progress: 13.32%
# BIOME Amazonia progress: 13.34%
# BIOME Amazonia progress: 13.35%
# BIOME Amazonia progress: 13.37%
# BIOME Amazonia progress: 13.38%
# BIOME Amazonia progress: 13.40%
# BIOME Amazonia progress: 13.41%
# BIOME Amazonia progress: 13.43%
# BIOME Amazonia progress: 13.44%
# BIOME Amazonia progress: 13.46%
# BIOME Amazonia progress: 13.47%
# BIOME Amazonia progress: 13.49%
# BIOME Amazonia progress: 13.50%
# BIOME Amazonia progress: 13.52%
# BIOME Amazonia progress: 13.53%
# BIOME Amazonia progress: 13.55%
# BIOME Amazonia progress: 13.56%
# BIOME Amazonia progress: 13.58%
# BIOME Amazonia progress: 13.59%
# BIOME Amazonia progress: 13.61%
# BIOME Amazonia progress: 13.62%
# BIOME Amazonia progress: 13.64%
# BIOME Amazonia progress: 13.65%
# BIOME Amazonia progress: 13.67%
# BIOME Amazonia progress: 13.68%
# BIOME Amazonia progress: 13.70%
# BIOME Amazonia progress: 13.71%
# BIOME Amazonia progress: 13.73%
# BIOME Amazonia progress: 13.74%
# BIOME Amazonia progress: 13.76%
# BIOME Amazonia progress: 13.77%
# BIOME Amazonia progress: 13.79%
# BIOME Amazonia progress: 13.80%
# BIOME Amazonia progress: 13.82%
# BIOME Amazonia progress: 13.83%
# BIOME Amazonia progress: 13.85%
# BIOME Amazonia progress: 13.86%
# BIOME Amazonia progress: 13.88%
# BIOME Amazonia progress: 13.89%
# BIOME Amazonia progress: 13.91%
# BIOME Amazonia progress: 13.93%
# BIOME Amazonia progress: 13.94%
# BIOME Amazonia progress: 13.96%
# BIOME Amazonia progress: 13.97%
# BIOME Amazonia progress: 13.99%
# BIOME Amazonia progress: 14.00%
# BIOME Amazonia progress: 14.02%
# BIOME Amazonia progress: 14.03%
# BIOME Amazonia progress: 14.05%
# BIOME Amazonia progress: 14.06%
# BIOME Amazonia progress: 14.08%
# BIOME Amazonia progress: 14.09%
# BIOME Amazonia progress: 14.11%
# BIOME Amazonia progress: 14.12%
# BIOME Amazonia progress: 14.14%
# BIOME Amazonia progress: 14.15%
# BIOME Amazonia progress: 14.17%
# BIOME Amazonia progress: 14.18%
# BIOME Amazonia progress: 14.20%
# BIOME Amazonia progress: 14.21%
# BIOME Amazonia progress: 14.23%
# BIOME Amazonia progress: 14.24%
# BIOME Amazonia progress: 14.26%
# BIOME Amazonia progress: 14.27%
# BIOME Amazonia progress: 14.29%
# BIOME Amazonia progress: 14.30%
# BIOME Amazonia progress: 14.32%
# BIOME Amazonia progress: 14.33%
# BIOME Amazonia progress: 14.35%
# BIOME Amazonia progress: 14.36%
# BIOME Amazonia progress: 14.38%
# BIOME Amazonia progress: 14.39%
# BIOME Amazonia progress: 14.41%
# BIOME Amazonia progress: 14.42%
# BIOME Amazonia progress: 14.44%
# BIOME Amazonia progress: 14.45%
# BIOME Amazonia progress: 14.47%
# BIOME Amazonia progress: 14.48%
# BIOME Amazonia progress: 14.50%
# BIOME Amazonia progress: 14.51%
# BIOME Amazonia progress: 14.53%
# BIOME Amazonia progress: 14.54%
# BIOME Amazonia progress: 14.56%
# BIOME Amazonia progress: 14.58%
# BIOME Amazonia progress: 14.59%
# BIOME Amazonia progress: 14.61%
# BIOME Amazonia progress: 14.62%
# BIOME Amazonia progress: 14.64%
# BIOME Amazonia progress: 14.65%
# BIOME Amazonia progress: 14.67%
# BIOME Amazonia progress: 14.68%
# BIOME Amazonia progress: 14.70%
# BIOME Amazonia progress: 14.71%
# BIOME Amazonia progress: 14.73%
# BIOME Amazonia progress: 14.74%
# BIOME Amazonia progress: 14.76%
# BIOME Amazonia progress: 14.77%
# BIOME Amazonia progress: 14.79%
# BIOME Amazonia progress: 14.80%
# BIOME Amazonia progress: 14.82%
# BIOME Amazonia progress: 14.83%
# BIOME Amazonia progress: 14.85%
# BIOME Amazonia progress: 14.86%
# BIOME Amazonia progress: 14.88%
# BIOME Amazonia progress: 14.89%
# BIOME Amazonia progress: 14.91%
# BIOME Amazonia progress: 14.92%
# BIOME Amazonia progress: 14.94%
# BIOME Amazonia progress: 14.95%
# BIOME Amazonia progress: 14.97%
# BIOME Amazonia progress: 14.98%
# BIOME Amazonia progress: 15.00%
# BIOME Amazonia progress: 15.01%
# BIOME Amazonia progress: 15.03%
# BIOME Amazonia progress: 15.04%
# BIOME Amazonia progress: 15.06%
# BIOME Amazonia progress: 15.07%
# BIOME Amazonia progress: 15.09%
# BIOME Amazonia progress: 15.10%
# BIOME Amazonia progress: 15.12%
# BIOME Amazonia progress: 15.13%
# BIOME Amazonia progress: 15.15%
# BIOME Amazonia progress: 15.16%
# BIOME Amazonia progress: 15.18%
# BIOME Amazonia progress: 15.20%
# BIOME Amazonia progress: 15.21%
# BIOME Amazonia progress: 15.23%
# BIOME Amazonia progress: 15.24%
# BIOME Amazonia progress: 15.26%
# BIOME Amazonia progress: 15.27%
# BIOME Amazonia progress: 15.29%
# BIOME Amazonia progress: 15.30%
# BIOME Amazonia progress: 15.32%
# BIOME Amazonia progress: 15.33%
# BIOME Amazonia progress: 15.35%
# BIOME Amazonia progress: 15.36%
# BIOME Amazonia progress: 15.38%
# BIOME Amazonia progress: 15.39%
# BIOME Amazonia progress: 15.41%
# BIOME Amazonia progress: 15.42%
# BIOME Amazonia progress: 15.44%
# BIOME Amazonia progress: 15.45%
# BIOME Amazonia progress: 15.47%
# BIOME Amazonia progress: 15.48%
# BIOME Amazonia progress: 15.50%
# BIOME Amazonia progress: 15.51%
# BIOME Amazonia progress: 15.53%
# BIOME Amazonia progress: 15.54%
# BIOME Amazonia progress: 15.56%
# BIOME Amazonia progress: 15.57%
# BIOME Amazonia progress: 15.59%
# BIOME Amazonia progress: 15.60%
# BIOME Amazonia progress: 15.62%
# BIOME Amazonia progress: 15.63%
# BIOME Amazonia progress: 15.65%
# BIOME Amazonia progress: 15.66%
# BIOME Amazonia progress: 15.68%
# BIOME Amazonia progress: 15.69%
# BIOME Amazonia progress: 15.71%
# BIOME Amazonia progress: 15.72%
# BIOME Amazonia progress: 15.74%
# BIOME Amazonia progress: 15.75%
# BIOME Amazonia progress: 15.77%
# BIOME Amazonia progress: 15.78%
# BIOME Amazonia progress: 15.80%
# BIOME Amazonia progress: 15.81%
# BIOME Amazonia progress: 15.83%
# BIOME Amazonia progress: 15.85%
# BIOME Amazonia progress: 15.86%
# BIOME Amazonia progress: 15.88%
# BIOME Amazonia progress: 15.89%
# BIOME Amazonia progress: 15.91%
# BIOME Amazonia progress: 15.92%
# BIOME Amazonia progress: 15.94%
# BIOME Amazonia progress: 15.95%
# BIOME Amazonia progress: 15.97%
# BIOME Amazonia progress: 15.98%
# BIOME Amazonia progress: 16.00%
# BIOME Amazonia progress: 16.01%
# BIOME Amazonia progress: 16.03%
# BIOME Amazonia progress: 16.04%
# BIOME Amazonia progress: 16.06%
# BIOME Amazonia progress: 16.07%
# BIOME Amazonia progress: 16.09%
# BIOME Amazonia progress: 16.10%
# BIOME Amazonia progress: 16.12%
# BIOME Amazonia progress: 16.13%
# BIOME Amazonia progress: 16.15%
# BIOME Amazonia progress: 16.16%
# BIOME Amazonia progress: 16.18%
# BIOME Amazonia progress: 16.19%
# BIOME Amazonia progress: 16.21%
# BIOME Amazonia progress: 16.22%
# BIOME Amazonia progress: 16.24%
# BIOME Amazonia progress: 16.25%
# BIOME Amazonia progress: 16.27%
# BIOME Amazonia progress: 16.28%
# BIOME Amazonia progress: 16.30%
# BIOME Amazonia progress: 16.31%
# BIOME Amazonia progress: 16.33%
# BIOME Amazonia progress: 16.34%
# BIOME Amazonia progress: 16.36%
# BIOME Amazonia progress: 16.37%
# BIOME Amazonia progress: 16.39%
# BIOME Amazonia progress: 16.40%
# BIOME Amazonia progress: 16.42%
# BIOME Amazonia progress: 16.43%
# BIOME Amazonia progress: 16.45%
# BIOME Amazonia progress: 16.47%
# BIOME Amazonia progress: 16.48%
# BIOME Amazonia progress: 16.50%
# BIOME Amazonia progress: 16.51%
# BIOME Amazonia progress: 16.53%
# BIOME Amazonia progress: 16.54%
# BIOME Amazonia progress: 16.56%
# BIOME Amazonia progress: 16.57%
# BIOME Amazonia progress: 16.59%
# BIOME Amazonia progress: 16.60%
# BIOME Amazonia progress: 16.62%
# BIOME Amazonia progress: 16.63%
# BIOME Amazonia progress: 16.65%
# BIOME Amazonia progress: 16.66%
# BIOME Amazonia progress: 16.68%
# BIOME Amazonia progress: 16.69%
# BIOME Amazonia progress: 16.71%
# BIOME Amazonia progress: 16.72%
# BIOME Amazonia progress: 16.74%
# BIOME Amazonia progress: 16.75%
# BIOME Amazonia progress: 16.77%
# BIOME Amazonia progress: 16.78%
# BIOME Amazonia progress: 16.80%
# BIOME Amazonia progress: 16.81%
# BIOME Amazonia progress: 16.83%
# BIOME Amazonia progress: 16.84%
# BIOME Amazonia progress: 16.86%
# BIOME Amazonia progress: 16.87%
# BIOME Amazonia progress: 16.89%
# BIOME Amazonia progress: 16.90%
# BIOME Amazonia progress: 16.92%
# BIOME Amazonia progress: 16.93%
# BIOME Amazonia progress: 16.95%
# BIOME Amazonia progress: 16.96%
# BIOME Amazonia progress: 16.98%
# BIOME Amazonia progress: 16.99%
# BIOME Amazonia progress: 17.01%
# BIOME Amazonia progress: 17.02%
# BIOME Amazonia progress: 17.04%
# BIOME Amazonia progress: 17.05%
# BIOME Amazonia progress: 17.07%
# BIOME Amazonia progress: 17.08%
# BIOME Amazonia progress: 17.10%
# BIOME Amazonia progress: 17.12%
# BIOME Amazonia progress: 17.13%
# BIOME Amazonia progress: 17.15%
# BIOME Amazonia progress: 17.16%
# BIOME Amazonia progress: 17.18%
# BIOME Amazonia progress: 17.19%
# BIOME Amazonia progress: 17.21%
# BIOME Amazonia progress: 17.22%
# BIOME Amazonia progress: 17.24%
# BIOME Amazonia progress: 17.25%
# BIOME Amazonia progress: 17.27%
# BIOME Amazonia progress: 17.28%
# BIOME Amazonia progress: 17.30%
# BIOME Amazonia progress: 17.31%
# BIOME Amazonia progress: 17.33%
# BIOME Amazonia progress: 17.34%
# BIOME Amazonia progress: 17.36%
# BIOME Amazonia progress: 17.37%
# BIOME Amazonia progress: 17.39%
# BIOME Amazonia progress: 17.40%
# BIOME Amazonia progress: 17.42%
# BIOME Amazonia progress: 17.43%
# BIOME Amazonia progress: 17.45%
# BIOME Amazonia progress: 17.46%
# BIOME Amazonia progress: 17.48%
# BIOME Amazonia progress: 17.49%
# BIOME Amazonia progress: 17.51%
# BIOME Amazonia progress: 17.52%
# BIOME Amazonia progress: 17.54%
# BIOME Amazonia progress: 17.55%
# BIOME Amazonia progress: 17.57%
# BIOME Amazonia progress: 17.58%
# BIOME Amazonia progress: 17.60%
# BIOME Amazonia progress: 17.61%
# BIOME Amazonia progress: 17.63%
# BIOME Amazonia progress: 17.64%
# BIOME Amazonia progress: 17.66%
# BIOME Amazonia progress: 17.67%
# BIOME Amazonia progress: 17.69%
# BIOME Amazonia progress: 17.70%
# BIOME Amazonia progress: 17.72%
# BIOME Amazonia progress: 17.74%
# BIOME Amazonia progress: 17.75%
# BIOME Amazonia progress: 17.77%
# BIOME Amazonia progress: 17.78%
# BIOME Amazonia progress: 17.80%
# BIOME Amazonia progress: 17.81%
# BIOME Amazonia progress: 17.83%
# BIOME Amazonia progress: 17.84%
# BIOME Amazonia progress: 17.86%
# BIOME Amazonia progress: 17.87%
# BIOME Amazonia progress: 17.89%
# BIOME Amazonia progress: 17.90%
# BIOME Amazonia progress: 17.92%
# BIOME Amazonia progress: 17.93%
# BIOME Amazonia progress: 17.95%
# BIOME Amazonia progress: 17.96%
# BIOME Amazonia progress: 17.98%
# BIOME Amazonia progress: 17.99%
# BIOME Amazonia progress: 18.01%
# BIOME Amazonia progress: 18.02%
# BIOME Amazonia progress: 18.04%
# BIOME Amazonia progress: 18.05%
# BIOME Amazonia progress: 18.07%
# BIOME Amazonia progress: 18.08%
# BIOME Amazonia progress: 18.10%
# BIOME Amazonia progress: 18.11%
# BIOME Amazonia progress: 18.13%
# BIOME Amazonia progress: 18.14%
# BIOME Amazonia progress: 18.16%
# BIOME Amazonia progress: 18.17%
# BIOME Amazonia progress: 18.19%
# BIOME Amazonia progress: 18.20%
# BIOME Amazonia progress: 18.22%
# BIOME Amazonia progress: 18.23%
# BIOME Amazonia progress: 18.25%
# BIOME Amazonia progress: 18.26%
# BIOME Amazonia progress: 18.28%
# BIOME Amazonia progress: 18.29%
# BIOME Amazonia progress: 18.31%
# BIOME Amazonia progress: 18.32%
# BIOME Amazonia progress: 18.34%
# BIOME Amazonia progress: 18.36%
# BIOME Amazonia progress: 18.37%
# BIOME Amazonia progress: 18.39%
# BIOME Amazonia progress: 18.40%
# BIOME Amazonia progress: 18.42%
# BIOME Amazonia progress: 18.43%
# BIOME Amazonia progress: 18.45%
# BIOME Amazonia progress: 18.46%
# BIOME Amazonia progress: 18.48%
# BIOME Amazonia progress: 18.49%
# BIOME Amazonia progress: 18.51%
# BIOME Amazonia progress: 18.52%
# BIOME Amazonia progress: 18.54%
# BIOME Amazonia progress: 18.55%
# BIOME Amazonia progress: 18.57%
# BIOME Amazonia progress: 18.58%
# BIOME Amazonia progress: 18.60%
# BIOME Amazonia progress: 18.61%
# BIOME Amazonia progress: 18.63%
# BIOME Amazonia progress: 18.64%
# BIOME Amazonia progress: 18.66%
# BIOME Amazonia progress: 18.67%
# BIOME Amazonia progress: 18.69%
# BIOME Amazonia progress: 18.70%
# BIOME Amazonia progress: 18.72%
# BIOME Amazonia progress: 18.73%
# BIOME Amazonia progress: 18.75%
# BIOME Amazonia progress: 18.76%
# BIOME Amazonia progress: 18.78%
# BIOME Amazonia progress: 18.79%
# BIOME Amazonia progress: 18.81%
# BIOME Amazonia progress: 18.82%
# BIOME Amazonia progress: 18.84%
# BIOME Amazonia progress: 18.85%
# BIOME Amazonia progress: 18.87%
# BIOME Amazonia progress: 18.88%
# BIOME Amazonia progress: 18.90%
# BIOME Amazonia progress: 18.91%
# BIOME Amazonia progress: 18.93%
# BIOME Amazonia progress: 18.94%
# BIOME Amazonia progress: 18.96%
# BIOME Amazonia progress: 18.97%
# BIOME Amazonia progress: 18.99%
# BIOME Amazonia progress: 19.01%
# BIOME Amazonia progress: 19.02%
# BIOME Amazonia progress: 19.04%
# BIOME Amazonia progress: 19.05%
# BIOME Amazonia progress: 19.07%
# BIOME Amazonia progress: 19.08%
# BIOME Amazonia progress: 19.10%
# BIOME Amazonia progress: 19.11%
# BIOME Amazonia progress: 19.13%
# BIOME Amazonia progress: 19.14%
# BIOME Amazonia progress: 19.16%
# BIOME Amazonia progress: 19.17%
# BIOME Amazonia progress: 19.19%
# BIOME Amazonia progress: 19.20%
# BIOME Amazonia progress: 19.22%
# BIOME Amazonia progress: 19.23%
# BIOME Amazonia progress: 19.25%
# BIOME Amazonia progress: 19.26%
# BIOME Amazonia progress: 19.28%
# BIOME Amazonia progress: 19.29%
# BIOME Amazonia progress: 19.31%
# BIOME Amazonia progress: 19.32%
# BIOME Amazonia progress: 19.34%
# BIOME Amazonia progress: 19.35%
# BIOME Amazonia progress: 19.37%
# BIOME Amazonia progress: 19.38%
# BIOME Amazonia progress: 19.40%
# BIOME Amazonia progress: 19.41%
# BIOME Amazonia progress: 19.43%
# BIOME Amazonia progress: 19.44%
# BIOME Amazonia progress: 19.46%
# BIOME Amazonia progress: 19.47%
# BIOME Amazonia progress: 19.49%
# BIOME Amazonia progress: 19.50%
# BIOME Amazonia progress: 19.52%
# BIOME Amazonia progress: 19.53%
# BIOME Amazonia progress: 19.55%
# BIOME Amazonia progress: 19.56%
# BIOME Amazonia progress: 19.58%
# BIOME Amazonia progress: 19.59%
# BIOME Amazonia progress: 19.61%
# BIOME Amazonia progress: 19.63%
# BIOME Amazonia progress: 19.64%
# BIOME Amazonia progress: 19.66%
# BIOME Amazonia progress: 19.67%
# BIOME Amazonia progress: 19.69%
# BIOME Amazonia progress: 19.70%
# BIOME Amazonia progress: 19.72%
# BIOME Amazonia progress: 19.73%
# BIOME Amazonia progress: 19.75%
# BIOME Amazonia progress: 19.76%
# BIOME Amazonia progress: 19.78%
# BIOME Amazonia progress: 19.79%
# BIOME Amazonia progress: 19.81%
# BIOME Amazonia progress: 19.82%
# BIOME Amazonia progress: 19.84%
# BIOME Amazonia progress: 19.85%
# BIOME Amazonia progress: 19.87%
# BIOME Amazonia progress: 19.88%
# BIOME Amazonia progress: 19.90%
# BIOME Amazonia progress: 19.91%
# BIOME Amazonia progress: 19.93%
# BIOME Amazonia progress: 19.94%
# BIOME Amazonia progress: 19.96%
# BIOME Amazonia progress: 19.97%
# BIOME Amazonia progress: 19.99%
# BIOME Amazonia progress: 20.00%
# BIOME Amazonia progress: 20.02%
# BIOME Amazonia progress: 20.03%
# BIOME Amazonia progress: 20.05%
# BIOME Amazonia progress: 20.06%
# BIOME Amazonia progress: 20.08%
# BIOME Amazonia progress: 20.09%
# BIOME Amazonia progress: 20.11%
# BIOME Amazonia progress: 20.12%
# BIOME Amazonia progress: 20.14%
# BIOME Amazonia progress: 20.15%
# BIOME Amazonia progress: 20.17%
# BIOME Amazonia progress: 20.18%
# BIOME Amazonia progress: 20.20%
# BIOME Amazonia progress: 20.21%
# BIOME Amazonia progress: 20.23%
# BIOME Amazonia progress: 20.24%
# BIOME Amazonia progress: 20.26%
# BIOME Amazonia progress: 20.28%
# BIOME Amazonia progress: 20.29%
# BIOME Amazonia progress: 20.31%
# BIOME Amazonia progress: 20.32%
# BIOME Amazonia progress: 20.34%
# BIOME Amazonia progress: 20.35%
# BIOME Amazonia progress: 20.37%
# BIOME Amazonia progress: 20.38%
# BIOME Amazonia progress: 20.40%
# BIOME Amazonia progress: 20.41%
# BIOME Amazonia progress: 20.43%
# BIOME Amazonia progress: 20.44%
# BIOME Amazonia progress: 20.46%
# BIOME Amazonia progress: 20.47%
# BIOME Amazonia progress: 20.49%
# BIOME Amazonia progress: 20.50%
# BIOME Amazonia progress: 20.52%
# BIOME Amazonia progress: 20.53%
# BIOME Amazonia progress: 20.55%
# BIOME Amazonia progress: 20.56%
# BIOME Amazonia progress: 20.58%
# BIOME Amazonia progress: 20.59%
# BIOME Amazonia progress: 20.61%
# BIOME Amazonia progress: 20.62%
# BIOME Amazonia progress: 20.64%
# BIOME Amazonia progress: 20.65%
# BIOME Amazonia progress: 20.67%
# BIOME Amazonia progress: 20.68%
# BIOME Amazonia progress: 20.70%
# BIOME Amazonia progress: 20.71%
# BIOME Amazonia progress: 20.73%
# BIOME Amazonia progress: 20.74%
# BIOME Amazonia progress: 20.76%
# BIOME Amazonia progress: 20.77%
# BIOME Amazonia progress: 20.79%
# BIOME Amazonia progress: 20.80%
# BIOME Amazonia progress: 20.82%
# BIOME Amazonia progress: 20.83%
# BIOME Amazonia progress: 20.85%
# BIOME Amazonia progress: 20.86%
# BIOME Amazonia progress: 20.88%
# BIOME Amazonia progress: 20.90%
# BIOME Amazonia progress: 20.91%
# BIOME Amazonia progress: 20.93%
# BIOME Amazonia progress: 20.94%
# BIOME Amazonia progress: 20.96%
# BIOME Amazonia progress: 20.97%
# BIOME Amazonia progress: 20.99%
# BIOME Amazonia progress: 21.00%
# BIOME Amazonia progress: 21.02%
# BIOME Amazonia progress: 21.03%
# BIOME Amazonia progress: 21.05%
# BIOME Amazonia progress: 21.06%
# BIOME Amazonia progress: 21.08%
# BIOME Amazonia progress: 21.09%
# BIOME Amazonia progress: 21.11%
# BIOME Amazonia progress: 21.12%
# BIOME Amazonia progress: 21.14%
# BIOME Amazonia progress: 21.15%
# BIOME Amazonia progress: 21.17%
# BIOME Amazonia progress: 21.18%
# BIOME Amazonia progress: 21.20%
# BIOME Amazonia progress: 21.21%
# BIOME Amazonia progress: 21.23%
# BIOME Amazonia progress: 21.24%
# BIOME Amazonia progress: 21.26%
# BIOME Amazonia progress: 21.27%
# BIOME Amazonia progress: 21.29%
# BIOME Amazonia progress: 21.30%
# BIOME Amazonia progress: 21.32%
# BIOME Amazonia progress: 21.33%
# BIOME Amazonia progress: 21.35%
# BIOME Amazonia progress: 21.36%
# BIOME Amazonia progress: 21.38%
# BIOME Amazonia progress: 21.39%
# BIOME Amazonia progress: 21.41%
# BIOME Amazonia progress: 21.42%
# BIOME Amazonia progress: 21.44%
# BIOME Amazonia progress: 21.45%
# BIOME Amazonia progress: 21.47%
# BIOME Amazonia progress: 21.48%
# BIOME Amazonia progress: 21.50%
# BIOME Amazonia progress: 21.51%
# BIOME Amazonia progress: 21.53%
# BIOME Amazonia progress: 21.55%
# BIOME Amazonia progress: 21.56%
# BIOME Amazonia progress: 21.58%
# BIOME Amazonia progress: 21.59%
# BIOME Amazonia progress: 21.61%
# BIOME Amazonia progress: 21.62%
# BIOME Amazonia progress: 21.64%
# BIOME Amazonia progress: 21.65%
# BIOME Amazonia progress: 21.67%
# BIOME Amazonia progress: 21.68%
# BIOME Amazonia progress: 21.70%
# BIOME Amazonia progress: 21.71%
# BIOME Amazonia progress: 21.73%
# BIOME Amazonia progress: 21.74%
# BIOME Amazonia progress: 21.76%
# BIOME Amazonia progress: 21.77%
# BIOME Amazonia progress: 21.79%
# BIOME Amazonia progress: 21.80%
# BIOME Amazonia progress: 21.82%
# BIOME Amazonia progress: 21.83%
# BIOME Amazonia progress: 21.85%
# BIOME Amazonia progress: 21.86%
# BIOME Amazonia progress: 21.88%
# BIOME Amazonia progress: 21.89%
# BIOME Amazonia progress: 21.91%
# BIOME Amazonia progress: 21.92%
# BIOME Amazonia progress: 21.94%
# BIOME Amazonia progress: 21.95%
# BIOME Amazonia progress: 21.97%
# BIOME Amazonia progress: 21.98%
# BIOME Amazonia progress: 22.00%
# BIOME Amazonia progress: 22.01%
# BIOME Amazonia progress: 22.03%
# BIOME Amazonia progress: 22.04%
# BIOME Amazonia progress: 22.06%
# BIOME Amazonia progress: 22.07%
# BIOME Amazonia progress: 22.09%
# BIOME Amazonia progress: 22.10%
# BIOME Amazonia progress: 22.12%
# BIOME Amazonia progress: 22.13%
# BIOME Amazonia progress: 22.15%
# BIOME Amazonia progress: 22.17%
# BIOME Amazonia progress: 22.18%
# BIOME Amazonia progress: 22.20%
# BIOME Amazonia progress: 22.21%
# BIOME Amazonia progress: 22.23%
# BIOME Amazonia progress: 22.24%
# BIOME Amazonia progress: 22.26%
# BIOME Amazonia progress: 22.27%
# BIOME Amazonia progress: 22.29%
# BIOME Amazonia progress: 22.30%
# BIOME Amazonia progress: 22.32%
# BIOME Amazonia progress: 22.33%
# BIOME Amazonia progress: 22.35%
# BIOME Amazonia progress: 22.36%
# BIOME Amazonia progress: 22.38%
# BIOME Amazonia progress: 22.39%
# BIOME Amazonia progress: 22.41%
# BIOME Amazonia progress: 22.42%
# BIOME Amazonia progress: 22.44%
# BIOME Amazonia progress: 22.45%
# BIOME Amazonia progress: 22.47%
# BIOME Amazonia progress: 22.48%
# BIOME Amazonia progress: 22.50%
# BIOME Amazonia progress: 22.51%
# BIOME Amazonia progress: 22.53%
# BIOME Amazonia progress: 22.54%
# BIOME Amazonia progress: 22.56%
# BIOME Amazonia progress: 22.57%
# BIOME Amazonia progress: 22.59%
# BIOME Amazonia progress: 22.60%
# BIOME Amazonia progress: 22.62%
# BIOME Amazonia progress: 22.63%
# BIOME Amazonia progress: 22.65%
# BIOME Amazonia progress: 22.66%
# BIOME Amazonia progress: 22.68%
# BIOME Amazonia progress: 22.69%
# BIOME Amazonia progress: 22.71%
# BIOME Amazonia progress: 22.72%
# BIOME Amazonia progress: 22.74%
# BIOME Amazonia progress: 22.75%
# BIOME Amazonia progress: 22.77%
# BIOME Amazonia progress: 22.79%
# BIOME Amazonia progress: 22.80%
# BIOME Amazonia progress: 22.82%
# BIOME Amazonia progress: 22.83%
# BIOME Amazonia progress: 22.85%
# BIOME Amazonia progress: 22.86%
# BIOME Amazonia progress: 22.88%
# BIOME Amazonia progress: 22.89%
# BIOME Amazonia progress: 22.91%
# BIOME Amazonia progress: 22.92%
# ...
# BIOME Caatinga progress: 74.28%
# BIOME Caatinga progress: 74.33%
# BIOME Caatinga progress: 74.38%
# BIOME Caatinga progress: 74.43%
# BIOME Caatinga progress: 74.48%
# BIOME Caatinga progress: 74.54%
# BIOME Caatinga progress: 74.59%
# BIOME Caatinga progress: 74.64%
# BIOME Caatinga progress: 74.69%
# BIOME Caatinga progress: 74.74%
# BIOME Caatinga progress: 74.79%
# BIOME Caatinga progress: 74.85%
# BIOME Caatinga progress: 74.90%
# BIOME Caatinga progress: 74.95%
# BIOME Caatinga progress: 75.00%
# BIOME Caatinga progress: 75.05%
# BIOME Caatinga progress: 75.10%
# BIOME Caatinga progress: 75.15%
# BIOME Caatinga progress: 75.21%
# BIOME Caatinga progress: 75.26%
# BIOME Caatinga progress: 75.31%
# BIOME Caatinga progress: 75.36%
# BIOME Caatinga progress: 75.41%
# BIOME Caatinga progress: 75.46%
# BIOME Caatinga progress: 75.52%
# BIOME Caatinga progress: 75.57%
# BIOME Caatinga progress: 75.62%
# BIOME Caatinga progress: 75.67%
# BIOME Caatinga progress: 75.72%
# BIOME Caatinga progress: 75.77%
# BIOME Caatinga progress: 75.83%
# BIOME Caatinga progress: 75.88%
# BIOME Caatinga progress: 75.93%
# BIOME Caatinga progress: 75.98%
# BIOME Caatinga progress: 76.03%
# BIOME Caatinga progress: 76.08%
# BIOME Caatinga progress: 76.14%
# BIOME Caatinga progress: 76.19%
# BIOME Caatinga progress: 76.24%
# BIOME Caatinga progress: 76.29%
# BIOME Caatinga progress: 76.34%
# BIOME Caatinga progress: 76.39%
# BIOME Caatinga progress: 76.45%
# BIOME Caatinga progress: 76.50%
# BIOME Caatinga progress: 76.55%
# BIOME Caatinga progress: 76.60%
# BIOME Caatinga progress: 76.65%
# BIOME Caatinga progress: 76.70%
# BIOME Caatinga progress: 76.76%
# BIOME Caatinga progress: 76.81%
# BIOME Caatinga progress: 76.86%
# BIOME Caatinga progress: 76.91%
# BIOME Caatinga progress: 76.96%
# BIOME Caatinga progress: 77.01%
# BIOME Caatinga progress: 77.07%
# BIOME Caatinga progress: 77.12%
# BIOME Caatinga progress: 77.17%
# BIOME Caatinga progress: 77.22%
# BIOME Caatinga progress: 77.27%
# BIOME Caatinga progress: 77.32%
# BIOME Caatinga progress: 77.38%
# BIOME Caatinga progress: 77.43%
# BIOME Caatinga progress: 77.48%
# BIOME Caatinga progress: 77.53%
# BIOME Caatinga progress: 77.58%
# BIOME Caatinga progress: 77.63%
# BIOME Caatinga progress: 77.69%
# BIOME Caatinga progress: 77.74%
# BIOME Caatinga progress: 77.79%
# BIOME Caatinga progress: 77.84%
# BIOME Caatinga progress: 77.89%
# BIOME Caatinga progress: 77.94%
# BIOME Caatinga progress: 78.00%
# BIOME Caatinga progress: 78.05%
# BIOME Caatinga progress: 78.10%
# BIOME Caatinga progress: 78.15%
# BIOME Caatinga progress: 78.20%
# BIOME Caatinga progress: 78.25%
# BIOME Caatinga progress: 78.31%
# BIOME Caatinga progress: 78.36%
# BIOME Caatinga progress: 78.41%
# BIOME Caatinga progress: 78.46%
# BIOME Caatinga progress: 78.51%
# BIOME Caatinga progress: 78.56%
# BIOME Caatinga progress: 78.62%
# BIOME Caatinga progress: 78.67%
# BIOME Caatinga progress: 78.72%
# BIOME Caatinga progress: 78.77%
# BIOME Caatinga progress: 78.82%
# BIOME Caatinga progress: 78.87%
# BIOME Caatinga progress: 78.93%
# BIOME Caatinga progress: 78.98%
# BIOME Caatinga progress: 79.03%
# BIOME Caatinga progress: 79.08%
# BIOME Caatinga progress: 79.13%
# BIOME Caatinga progress: 79.18%
# BIOME Caatinga progress: 79.24%
# BIOME Caatinga progress: 79.29%
# BIOME Caatinga progress: 79.34%
# BIOME Caatinga progress: 79.39%
# BIOME Caatinga progress: 79.44%
# BIOME Caatinga progress: 79.49%
# BIOME Caatinga progress: 79.55%
# BIOME Caatinga progress: 79.60%
# BIOME Caatinga progress: 79.65%
# BIOME Caatinga progress: 79.70%
# BIOME Caatinga progress: 79.75%
# BIOME Caatinga progress: 79.80%
# BIOME Caatinga progress: 79.86%
# BIOME Caatinga progress: 79.91%
# BIOME Caatinga progress: 79.96%
# BIOME Caatinga progress: 80.01%
# BIOME Caatinga progress: 80.06%
# BIOME Caatinga progress: 80.11%
# BIOME Caatinga progress: 80.17%
# BIOME Caatinga progress: 80.22%
# BIOME Caatinga progress: 80.27%
# BIOME Caatinga progress: 80.32%
# BIOME Caatinga progress: 80.37%
# BIOME Caatinga progress: 80.42%
# BIOME Caatinga progress: 80.48%
# BIOME Caatinga progress: 80.53%
# BIOME Caatinga progress: 80.58%
# BIOME Caatinga progress: 80.63%
# BIOME Caatinga progress: 80.68%
# BIOME Caatinga progress: 80.73%
# BIOME Caatinga progress: 80.79%
# BIOME Caatinga progress: 80.84%
# BIOME Caatinga progress: 80.89%
# BIOME Caatinga progress: 80.94%
# BIOME Caatinga progress: 80.99%
# BIOME Caatinga progress: 81.04%
# BIOME Caatinga progress: 81.10%
# BIOME Caatinga progress: 81.15%
# BIOME Caatinga progress: 81.20%
# BIOME Caatinga progress: 81.25%
# BIOME Caatinga progress: 81.30%
# BIOME Caatinga progress: 81.35%
# BIOME Caatinga progress: 81.40%
# BIOME Caatinga progress: 81.46%
# BIOME Caatinga progress: 81.51%
# BIOME Caatinga progress: 81.56%
# BIOME Caatinga progress: 81.61%
# BIOME Caatinga progress: 81.66%
# BIOME Caatinga progress: 81.71%
# BIOME Caatinga progress: 81.77%
# BIOME Caatinga progress: 81.82%
# BIOME Caatinga progress: 81.87%
# BIOME Caatinga progress: 81.92%
# BIOME Caatinga progress: 81.97%
# BIOME Caatinga progress: 82.02%
# BIOME Caatinga progress: 82.08%
# BIOME Caatinga progress: 82.13%
# BIOME Caatinga progress: 82.18%
# BIOME Caatinga progress: 82.23%
# BIOME Caatinga progress: 82.28%
# BIOME Caatinga progress: 82.33%
# BIOME Caatinga progress: 82.39%
# BIOME Caatinga progress: 82.44%
# BIOME Caatinga progress: 82.49%
# BIOME Caatinga progress: 82.54%
# BIOME Caatinga progress: 82.59%
# BIOME Caatinga progress: 82.64%
# BIOME Caatinga progress: 82.70%
# BIOME Caatinga progress: 82.75%
# BIOME Caatinga progress: 82.80%
# BIOME Caatinga progress: 82.85%
# BIOME Caatinga progress: 82.90%
# BIOME Caatinga progress: 82.95%
# BIOME Caatinga progress: 83.01%
# BIOME Caatinga progress: 83.06%
# BIOME Caatinga progress: 83.11%
# BIOME Caatinga progress: 83.16%
# BIOME Caatinga progress: 83.21%
# BIOME Caatinga progress: 83.26%
# BIOME Caatinga progress: 83.32%
# BIOME Caatinga progress: 83.37%
# BIOME Caatinga progress: 83.42%
# BIOME Caatinga progress: 83.47%
# BIOME Caatinga progress: 83.52%
# BIOME Caatinga progress: 83.57%
# BIOME Caatinga progress: 83.63%
# BIOME Caatinga progress: 83.68%
# BIOME Caatinga progress: 83.73%
# BIOME Caatinga progress: 83.78%
# BIOME Caatinga progress: 83.83%
# BIOME Caatinga progress: 83.88%
# BIOME Caatinga progress: 83.94%
# BIOME Caatinga progress: 83.99%
# BIOME Caatinga progress: 84.04%
# BIOME Caatinga progress: 84.09%
# BIOME Caatinga progress: 84.14%
# BIOME Caatinga progress: 84.19%
# BIOME Caatinga progress: 84.25%
# BIOME Caatinga progress: 84.30%
# BIOME Caatinga progress: 84.35%
# BIOME Caatinga progress: 84.40%
# BIOME Caatinga progress: 84.45%
# BIOME Caatinga progress: 84.50%
# BIOME Caatinga progress: 84.56%
# BIOME Caatinga progress: 84.61%
# BIOME Caatinga progress: 84.66%
# BIOME Caatinga progress: 84.71%
# BIOME Caatinga progress: 84.76%
# BIOME Caatinga progress: 84.81%
# BIOME Caatinga progress: 84.87%
# BIOME Caatinga progress: 84.92%
# BIOME Caatinga progress: 84.97%
# BIOME Caatinga progress: 85.02%
# BIOME Caatinga progress: 85.07%
# BIOME Caatinga progress: 85.12%
# BIOME Caatinga progress: 85.18%
# BIOME Caatinga progress: 85.23%
# BIOME Caatinga progress: 85.28%
# BIOME Caatinga progress: 85.33%
# BIOME Caatinga progress: 85.38%
# BIOME Caatinga progress: 85.43%
# BIOME Caatinga progress: 85.49%
# BIOME Caatinga progress: 85.54%
# BIOME Caatinga progress: 85.59%
# BIOME Caatinga progress: 85.64%
# BIOME Caatinga progress: 85.69%
# BIOME Caatinga progress: 85.74%
# BIOME Caatinga progress: 85.80%
# BIOME Caatinga progress: 85.85%
# BIOME Caatinga progress: 85.90%
# BIOME Caatinga progress: 85.95%
# BIOME Caatinga progress: 86.00%
# BIOME Caatinga progress: 86.05%
# BIOME Caatinga progress: 86.11%
# BIOME Caatinga progress: 86.16%
# BIOME Caatinga progress: 86.21%
# BIOME Caatinga progress: 86.26%
# BIOME Caatinga progress: 86.31%
# BIOME Caatinga progress: 86.36%
# BIOME Caatinga progress: 86.42%
# BIOME Caatinga progress: 86.47%
# BIOME Caatinga progress: 86.52%
# BIOME Caatinga progress: 86.57%
# BIOME Caatinga progress: 86.62%
# BIOME Caatinga progress: 86.67%
# BIOME Caatinga progress: 86.73%
# BIOME Caatinga progress: 86.78%
# BIOME Caatinga progress: 86.83%
# BIOME Caatinga progress: 86.88%
# BIOME Caatinga progress: 86.93%
# BIOME Caatinga progress: 86.98%
# BIOME Caatinga progress: 87.04%
# BIOME Caatinga progress: 87.09%
# BIOME Caatinga progress: 87.14%
# BIOME Caatinga progress: 87.19%
# BIOME Caatinga progress: 87.24%
# BIOME Caatinga progress: 87.29%
# BIOME Caatinga progress: 87.35%
# BIOME Caatinga progress: 87.40%
# BIOME Caatinga progress: 87.45%
# BIOME Caatinga progress: 87.50%
# BIOME Caatinga progress: 87.55%
# BIOME Caatinga progress: 87.60%
# BIOME Caatinga progress: 87.65%
# BIOME Caatinga progress: 87.71%
# BIOME Caatinga progress: 87.76%
# BIOME Caatinga progress: 87.81%
# BIOME Caatinga progress: 87.86%
# BIOME Caatinga progress: 87.91%
# BIOME Caatinga progress: 87.96%
# BIOME Caatinga progress: 88.02%
# BIOME Caatinga progress: 88.07%
# BIOME Caatinga progress: 88.12%
# BIOME Caatinga progress: 88.17%
# BIOME Caatinga progress: 88.22%
# BIOME Caatinga progress: 88.27%
# BIOME Caatinga progress: 88.33%
# BIOME Caatinga progress: 88.38%
# BIOME Caatinga progress: 88.43%
# BIOME Caatinga progress: 88.48%
# BIOME Caatinga progress: 88.53%
# BIOME Caatinga progress: 88.58%
# BIOME Caatinga progress: 88.64%
# BIOME Caatinga progress: 88.69%
# BIOME Caatinga progress: 88.74%
# BIOME Caatinga progress: 88.79%
# BIOME Caatinga progress: 88.84%
# BIOME Caatinga progress: 88.89%
# BIOME Caatinga progress: 88.95%
# BIOME Caatinga progress: 89.00%
# BIOME Caatinga progress: 89.05%
# BIOME Caatinga progress: 89.10%
# BIOME Caatinga progress: 89.15%
# BIOME Caatinga progress: 89.20%
# BIOME Caatinga progress: 89.26%
# BIOME Caatinga progress: 89.31%
# BIOME Caatinga progress: 89.36%
# BIOME Caatinga progress: 89.41%
# BIOME Caatinga progress: 89.46%
# BIOME Caatinga progress: 89.51%
# BIOME Caatinga progress: 89.57%
# BIOME Caatinga progress: 89.62%
# BIOME Caatinga progress: 89.67%
# BIOME Caatinga progress: 89.72%
# BIOME Caatinga progress: 89.77%
# BIOME Caatinga progress: 89.82%
# BIOME Caatinga progress: 89.88%
# BIOME Caatinga progress: 89.93%
# BIOME Caatinga progress: 89.98%
# BIOME Caatinga progress: 90.03%
# BIOME Caatinga progress: 90.08%
# BIOME Caatinga progress: 90.13%
# BIOME Caatinga progress: 90.19%
# BIOME Caatinga progress: 90.24%
# BIOME Caatinga progress: 90.29%
# BIOME Caatinga progress: 90.34%
# BIOME Caatinga progress: 90.39%
# BIOME Caatinga progress: 90.44%
# BIOME Caatinga progress: 90.50%
# BIOME Caatinga progress: 90.55%
# BIOME Caatinga progress: 90.60%
# BIOME Caatinga progress: 90.65%
# BIOME Caatinga progress: 90.70%
# BIOME Caatinga progress: 90.75%
# BIOME Caatinga progress: 90.81%
# BIOME Caatinga progress: 90.86%
# BIOME Caatinga progress: 90.91%
# BIOME Caatinga progress: 90.96%
# BIOME Caatinga progress: 91.01%
# BIOME Caatinga progress: 91.06%
# BIOME Caatinga progress: 91.12%
# BIOME Caatinga progress: 91.17%
# BIOME Caatinga progress: 91.22%
# BIOME Caatinga progress: 91.27%
# BIOME Caatinga progress: 91.32%
# BIOME Caatinga progress: 91.37%
# BIOME Caatinga progress: 91.43%
# BIOME Caatinga progress: 91.48%
# BIOME Caatinga progress: 91.53%
# BIOME Caatinga progress: 91.58%
# BIOME Caatinga progress: 91.63%
# BIOME Caatinga progress: 91.68%
# BIOME Caatinga progress: 91.74%
# BIOME Caatinga progress: 91.79%
# BIOME Caatinga progress: 91.84%
# BIOME Caatinga progress: 91.89%
# BIOME Caatinga progress: 91.94%
# BIOME Caatinga progress: 91.99%
# BIOME Caatinga progress: 92.05%
# BIOME Caatinga progress: 92.10%
# BIOME Caatinga progress: 92.15%
# BIOME Caatinga progress: 92.20%
# BIOME Caatinga progress: 92.25%
# BIOME Caatinga progress: 92.30%
# BIOME Caatinga progress: 92.36%
# BIOME Caatinga progress: 92.41%
# BIOME Caatinga progress: 92.46%
# BIOME Caatinga progress: 92.51%
# BIOME Caatinga progress: 92.56%
# BIOME Caatinga progress: 92.61%
# BIOME Caatinga progress: 92.67%
# BIOME Caatinga progress: 92.72%
# BIOME Caatinga progress: 92.77%
# BIOME Caatinga progress: 92.82%
# BIOME Caatinga progress: 92.87%
# BIOME Caatinga progress: 92.92%
# BIOME Caatinga progress: 92.98%
# BIOME Caatinga progress: 93.03%
# BIOME Caatinga progress: 93.08%
# BIOME Caatinga progress: 93.13%
# BIOME Caatinga progress: 93.18%
# BIOME Caatinga progress: 93.23%
# BIOME Caatinga progress: 93.29%
# BIOME Caatinga progress: 93.34%
# BIOME Caatinga progress: 93.39%
# BIOME Caatinga progress: 93.44%
# BIOME Caatinga progress: 93.49%
# BIOME Caatinga progress: 93.54%
# BIOME Caatinga progress: 93.60%
# BIOME Caatinga progress: 93.65%
# BIOME Caatinga progress: 93.70%
# BIOME Caatinga progress: 93.75%
# BIOME Caatinga progress: 93.80%
# BIOME Caatinga progress: 93.85%
# BIOME Caatinga progress: 93.90%
# BIOME Caatinga progress: 93.96%
# BIOME Caatinga progress: 94.01%
# BIOME Caatinga progress: 94.06%
# BIOME Caatinga progress: 94.11%
# BIOME Caatinga progress: 94.16%
# BIOME Caatinga progress: 94.21%
# BIOME Caatinga progress: 94.27%
# BIOME Caatinga progress: 94.32%
# BIOME Caatinga progress: 94.37%
# BIOME Caatinga progress: 94.42%
# BIOME Caatinga progress: 94.47%
# BIOME Caatinga progress: 94.52%
# BIOME Caatinga progress: 94.58%
# BIOME Caatinga progress: 94.63%
# BIOME Caatinga progress: 94.68%
# BIOME Caatinga progress: 94.73%
# BIOME Caatinga progress: 94.78%
# BIOME Caatinga progress: 94.83%
# BIOME Caatinga progress: 94.89%
# BIOME Caatinga progress: 94.94%
# BIOME Caatinga progress: 94.99%
# BIOME Caatinga progress: 95.04%
# BIOME Caatinga progress: 95.09%
# BIOME Caatinga progress: 95.14%
# BIOME Caatinga progress: 95.20%
# BIOME Caatinga progress: 95.25%
# BIOME Caatinga progress: 95.30%
# BIOME Caatinga progress: 95.35%
# BIOME Caatinga progress: 95.40%
# BIOME Caatinga progress: 95.45%
# BIOME Caatinga progress: 95.51%
# BIOME Caatinga progress: 95.56%
# BIOME Caatinga progress: 95.61%
# BIOME Caatinga progress: 95.66%
# BIOME Caatinga progress: 95.71%
# BIOME Caatinga progress: 95.76%
# BIOME Caatinga progress: 95.82%
# BIOME Caatinga progress: 95.87%
# BIOME Caatinga progress: 95.92%
# BIOME Caatinga progress: 95.97%
# BIOME Caatinga progress: 96.02%
# BIOME Caatinga progress: 96.07%
# BIOME Caatinga progress: 96.13%
# BIOME Caatinga progress: 96.18%
# BIOME Caatinga progress: 96.23%
# BIOME Caatinga progress: 96.28%
# BIOME Caatinga progress: 96.33%
# BIOME Caatinga progress: 96.38%
# BIOME Caatinga progress: 96.44%
# BIOME Caatinga progress: 96.49%
# BIOME Caatinga progress: 96.54%
# BIOME Caatinga progress: 96.59%
# BIOME Caatinga progress: 96.64%
# BIOME Caatinga progress: 96.69%
# BIOME Caatinga progress: 96.75%
# BIOME Caatinga progress: 96.80%
# BIOME Caatinga progress: 96.85%
# BIOME Caatinga progress: 96.90%
# BIOME Caatinga progress: 96.95%
# BIOME Caatinga progress: 97.00%
# BIOME Caatinga progress: 97.06%
# BIOME Caatinga progress: 97.11%
# BIOME Caatinga progress: 97.16%
# BIOME Caatinga progress: 97.21%
# BIOME Caatinga progress: 97.26%
# BIOME Caatinga progress: 97.31%
# BIOME Caatinga progress: 97.37%
# BIOME Caatinga progress: 97.42%
# BIOME Caatinga progress: 97.47%
# BIOME Caatinga progress: 97.52%
# BIOME Caatinga progress: 97.57%
# BIOME Caatinga progress: 97.62%
# BIOME Caatinga progress: 97.68%
# BIOME Caatinga progress: 97.73%
# BIOME Caatinga progress: 97.78%
# BIOME Caatinga progress: 97.83%
# BIOME Caatinga progress: 97.88%
# BIOME Caatinga progress: 97.93%
# BIOME Caatinga progress: 97.99%
# BIOME Caatinga progress: 98.04%
# BIOME Caatinga progress: 98.09%
# BIOME Caatinga progress: 98.14%
# BIOME Caatinga progress: 98.19%
# BIOME Caatinga progress: 98.24%
# BIOME Caatinga progress: 98.30%
# BIOME Caatinga progress: 98.35%
# BIOME Caatinga progress: 98.40%
# BIOME Caatinga progress: 98.45%
# BIOME Caatinga progress: 98.50%
# BIOME Caatinga progress: 98.55%
# BIOME Caatinga progress: 98.61%
# BIOME Caatinga progress: 98.66%
# BIOME Caatinga progress: 98.71%
# BIOME Caatinga progress: 98.76%
# BIOME Caatinga progress: 98.81%
# BIOME Caatinga progress: 98.86%
# BIOME Caatinga progress: 98.92%
# BIOME Caatinga progress: 98.97%
# BIOME Caatinga progress: 99.02%
# BIOME Caatinga progress: 99.07%
# BIOME Caatinga progress: 99.12%
# BIOME Caatinga progress: 99.17%
# BIOME Caatinga progress: 99.23%
# BIOME Caatinga progress: 99.28%
# BIOME Caatinga progress: 99.33%
# BIOME Caatinga progress: 99.38%
# BIOME Caatinga progress: 99.43%
# BIOME Caatinga progress: 99.48%
# BIOME Caatinga progress: 99.54%
# BIOME Caatinga progress: 99.59%
# BIOME Caatinga progress: 99.64%
# BIOME Caatinga progress: 99.69%
# BIOME Caatinga progress: 99.74%
# BIOME Caatinga progress: 99.79%
# BIOME Caatinga progress: 99.85%
# BIOME Caatinga progress: 99.90%
# BIOME Caatinga progress: 99.95%
# BIOME Caatinga progress: 100.00%

# %%
x = np.array([[10,20,30], [40,50,60]])
x = np.random.rand(51,50, 3)
y = np.ones((51,1, 3))
mean = np.mean(x)
y = np.full((51,1,3), mean)

#y = np.array([[9], [200]])
print (x.shape)
print (y.shape)
z = np.append(x, y, axis=1)
print (z.shape)

print (z[0][-1])
print (z[0][0])
print (z[10][-1])
print (z[10][0])
# Out:
# (51, 50, 3)
# (51, 1, 3)
# (51, 51, 3)
# [0.50209104 0.50209104 0.50209104]
# [0.65033893 0.54809118 0.56506487]
# [0.50209104 0.50209104 0.50209104]
# [0.77898821 0.54560003 0.94404827]

# %% [markdown]
# ## Visualize some tiles!

# %% [markdown]
# Looks like we got what we wanted. The anchor and neighbor tiles look like they belong to the same class, and are different from the distant tile.

# %% [markdown]
# ## Compare tiles made to original tiles

# %%
nan_removed_tile_dir = '/Users/calummcmeekin/Documents/GitHub/MInf-Project/SatelliteSegmentation/tile2vec/data/nan_removed_tiles/'
original_tile_dir = '/Users/calummcmeekin/Downloads/tile2vec-master-original/data/triplets/' 
new_tile_dir = '../data/new_tiles' 
tao_tile_dir = '../data/toa_triplets'

# %%
tile_dir = '../data/example_tiles_amazonia/'
tile_dir = tao_tile_dir
#tile_dir = new_tile_dir
n_triplets = 2
plt.rcParams['figure.figsize'] = (12,4)
for i in range(n_triplets):
    tile = np.load(os.path.join(tile_dir, str(i)+'anchor.npy'))
    neighbor = np.load(os.path.join(tile_dir, str(i)+'neighbor.npy'))
    distant = np.load(os.path.join(tile_dir, str(i)+'distant.npy'))
    
    vmin = np.array([tile, neighbor, distant]).min()
    vmax = np.array([tile, neighbor, distant]).max()
    
    plt.figure()
    plt.subplot(1,3,1)
    plt.imshow(tile[:,:,[0,1,2]])
    plt.title('Anchor '+str(i))
    plt.subplot(1,3,2)
    plt.imshow(neighbor[:,:,[0,1,2]])
    plt.title('Neighbor '+str(i))
    plt.subplot(1,3,3)
    plt.imshow(distant[:,:,[0,1,2]])
    plt.title('Distant '+str(i))

# %%
for i in range(10):
    
    new_tile = np.load(os.path.join(nan_removed_tile_dir, str(i)+'anchor.npy'))
    new_tile_shape = new_tile.shape

    org_tile = np.load(os.path.join(tao_tile_dir, str(i)+'anchor.npy'))
    org_tile_shape = org_tile.shape
    
    print ("NEW: " + str(new_tile_shape) + " ORG: " + str(org_tile_shape))
    
print ("OLD TILES")
print (org_tile[0][0])
print (org_tile[0][1])
print (org_tile[0][2])
print (org_tile[0][3])
print (org_tile[0][4])
print (org_tile[-1][-1])

print ("NEW TILES")
print (new_tile[0][0][0])
print (new_tile[0][0])
print (new_tile[0][0])
print (len(new_tile[0]))
print (new_tile[0][4])
print (new_tile[-1][-1])
# Out:
# NEW: (51, 51, 3) ORG: (51, 51, 3)
# NEW: (51, 51, 3) ORG: (51, 51, 3)
# NEW: (51, 51, 3) ORG: (51, 51, 3)
# NEW: (51, 51, 3) ORG: (51, 51, 3)
# NEW: (51, 51, 3) ORG: (51, 51, 3)
# NEW: (51, 51, 3) ORG: (51, 51, 3)
# NEW: (51, 51, 3) ORG: (51, 51, 3)
# NEW: (51, 51, 3) ORG: (51, 51, 3)
# NEW: (51, 51, 3) ORG: (51, 51, 3)
# NEW: (51, 51, 3) ORG: (51, 51, 3)
# OLD TILES
# [0.07801479 0.06121901 0.03912298]
# [0.07948569 0.05956391 0.03912298]
# [0.07801479 0.05790882 0.03755536]
# [0.07801479 0.05956391 0.03755536]
# [0.07801479 0.06121901 0.03755536]
# [0.07948569 0.05790882 0.03598774]
# NEW TILES
# 0.19780271
# [0.19780271 0.19780271 0.19780271]
# [0.19780271 0.19780271 0.19780271]
# 51
# [0.04166667 0.30810812 0.0199005 ]
# [0.04861111 0.31351352 0.2238806 ]

# %%
def remove_nan_2(new_tile):
    """
    Takes a tile and replaces any nan values with the mean
    of the column the nan appears in
    """
    
    #Obtain mean of columns as you need, nanmean is convenient.
    tile_mean = np.nanmean(new_tile, axis=0)

    #Find indices that you need to replace
    inds = np.where(np.isnan(new_tile))
    
    #Place column means in the indices. Align the arrays using take
    new_tile[inds] = np.take(tile_mean, inds[1])
    
    return new_tile

# %%
import math
for i in range(1000):
    
    new_tile = np.load(os.path.join(nan_removed_tile_dir, str(i)+'anchor.npy'))
    new_tile_shape = new_tile.shape
    
    mean = np.nanmean(new_tile)
    #new_tile = remove_nan(new_tile)
    new_tile = np.nan_to_num(new_tile, nan=mean, posinf=mean, neginf=mean)
    """
    #Obtain mean of columns as you need, nanmean is convenient.
    tile_mean = np.nanmean(new_tile, axis=1)

    #Find indices that you need to replace
    inds = np.where(np.isnan(new_tile))
    
    #Place column means in the indices. Align the arrays using take
    new_tile[inds] = np.take(tile_mean, inds[1])
    """
    array_sum = np.sum(new_tile)
    if (np.isnan(array_sum)):
        print (i)
    
    """
    org_tile = np.load(os.path.join(original_tile_dir, str(i)+'anchor.npy'))
    org_tile_shape = org_tile.shape
    
    print ("NEW: " + str(new_tile_shape) + " ORG: " + str(org_tile_shape))
    
    print ("OLD TILES")
    print (org_tile[0][0])
    print (org_tile[0][0])
    print (org_tile[0][0])


    print ("NEW TILES")
    print (new_tile[0][0])
    print (new_tile[0][0])
    print (new_tile[0][0])
    """

# %% [markdown]
# ## Create tiles for testing

# %% [markdown]
# Get each biomes test tiles

# %%
amazonia_test_imgs = get_triplet_imgs_quad("Amazonia", quads=[4])[0]

cerrado_test_imgs = get_triplet_imgs_quad("Cerrado", quads=[4])[0]

caatinga_test_imgs = get_triplet_imgs_quad("Caatinga", quads=[4])[0]

# %%
amazonia_img_dir = '../data/Amazonia Quads/Quad 4'

cerrado_img_dir = '../data/Cerrado Quads/Quad 4'

caatinga_img_dir = '../data/Caatinga Quads/Quad 4'

toa_test_tiles = '../data/toa_test_tiles'

# %%
print ("\n\nAmazonia:\n")
last_ama_tile_num = generate_test_tiles(toa_test_tiles, amazonia_img_dir, amazonia_test_imgs, verbose=True)

print ("\n\nCerrado:\n")
last_cer_tile_num = generate_test_tiles(toa_test_tiles, cerrado_img_dir, cerrado_test_imgs, last_ama_tile_num, verbose=True)

print ("\n\nCaatinga:\n")
last_cat_tile_num = generate_test_tiles(toa_test_tiles, caatinga_img_dir, caatinga_test_imgs, last_cer_tile_num, verbose=True)
# Out:
# Amazonia:
#
# Beginning Extract of 6887 images
# ../src/sample_tiles.py:247: RuntimeWarning: Mean of empty slice
#   bands_only=bands_only)
# Progress: 14.52%
# Progress: 29.04%
# Progress: 43.56%
# Progress: 58.08%
# Progress: 72.60%
# Progress: 87.12%
#
#
# Cerrado:
#
# Beginning Extract of 6900 images
# Progress: 1.45%
# Progress: 15.94%
# Progress: 30.43%
# Progress: 44.93%
# Progress: 59.42%
# Progress: 73.91%
# Progress: 88.41%
#
#
# Caatinga:
#
# Beginning Extract of 6900 images
# Progress: 2.90%
# Progress: 17.39%
# Progress: 31.88%
# Progress: 46.38%
# Progress: 60.87%
# Progress: 75.36%
# Progress: 89.86%

# %% [markdown]
# Generate Test Labels

# %%
amazonia_labels = np.array([0]*last_ama_tile_num)
print (len(amazonia_labels))

cerrado_labels = np.array([1]*(last_cer_tile_num-last_ama_tile_num))
print (len(cerrado_labels))


caatinga_labels = np.array([2]*(last_cat_tile_num-last_cer_tile_num))
print (len(caatinga_labels))


test_labels = np.concatenate([amazonia_labels, cerrado_labels, caatinga_labels])

print ("Number of tiles: {}".format(len(test_labels)))

np.save(os.path.join(toa_test_tiles, 'y.npy'), test_labels)
# Out:
# 6772
# 6796
# 6710
# Number of tiles: 20278

# %%
import math
tao_tile_dir = '../data/toa_triplets'
tao_test_tiles = '../data/toa_test_tiles'

for i in range(1000):
    
    new_tile = np.load(os.path.join(tao_test_tiles, str(i)+'tile.npy'))
        
    mean = np.nanmean(new_tile.astype('float64'))
    
    if np.isnan(mean):
        print (i)
    #new_tile = np.nan_to_num(new_tile, nan=100, posinf=100, neginf=100)
    
    mean = np.nanmean(new_tile)
    
    #print (mean)
    
    #print (new_tile.shape)
    #new_tile =  np.swapaxes(new_tile, 0, 2)
    
    #new_col = np.full((51,51,1), mean)
    #tile = np.append(new_tile, new_col, axis=2)
    
    #np.save(os.path.join(new_tile_dir, str(i)+'tile.npy'), new_tile)

# %%
tao_test_tiles = '../data/toa_test_tiles'

#y = np.load(os.path.join(tile_dir, 'y.npy'))

y = [1]*1000

np.save(os.path.join(tile_dir, 'y.npy'), y)

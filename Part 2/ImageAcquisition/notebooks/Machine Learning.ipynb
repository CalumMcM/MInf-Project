# %% [markdown]
# # Data Preparation

# %% [markdown]
# Loads the formatted data into a training and testing matrix. This had to be done in a notebook otherwise my computer would crash.

# %%
import numpy as np
import time
from time import time
from torch.autograd import Variable
import os
import sys
sys.path.append('../')
import matplotlib.pyplot as plt
import rasterio as rs
from src.sample_tiles import *
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras import layers

import torch
from img2vec_pytorch import Img2Vec
from PIL import Image
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# %% [markdown]
# ## Step 1. Sample image names

# %% [markdown]
# For each biome store the names of each image in an array

# %% [markdown]
# ### Organise structure for directory iteration

# %%
POS_to_CODE = {
    0: 1,
    1: 2,
    2: 3,
}

# %%
def one_ugly_encoding(hot_arr):
    hot_arr = np.array(hot_arr)
    ugly_arr = []
    for arr in hot_arr:
        code = POS_to_CODE[np.argmax(arr)]
        ugly_arr.append(code)
    return np.array(ugly_arr)

# %%
def normalize_red(array):
    return (array - array.min()) / (array.max() - array.min())
def normalize_green(array):
    return (array - array.min()) / (array.max() - array.min())
def normalize_blue(array):
    return (array - array.min()) / (array.max() - array.min())

# %%
def load_Processed_Data(DIR):

    X_data = np.zeros((1,4,51,51))

    image_PATHS = [f.path for f in os.scandir(DIR) if 'npy' in f.path]
    failed_images = []
    idx = 1
    previous_progress = 0
    start = time()

    for image_PATH in image_PATHS[:-1]:
        
        try:
            image = np.load(image_PATH)

            X_data = np.append(X_data, np.array([image]), axis = 0)

            if (idx%10 == 0):
                progress = (idx/len(image_PATHS[:-1]))*100
                end = time()
                time_remaining = ((end - start)/(progress-previous_progress)) * (100-progress)

                print ("Progress: {:.2f}% Cur Image: {} TIME REMAINING: {:.2f} seconds ".format(progress, image_PATH.split('/')[-1], time_remaining))
                previous_progress= progress
                start = time()
        except:
            image_name = image_PATH.split('/')[-1].split('.')[0]

            failed_images.append(image_name)

            print ("FAILED: {} \t {}".format(image_name, image_PATH))
            
            image = np.load(image_PATH)
            print (np.sum(image))
            
            
        idx += 1

        
        
    return X_data, failed_images

# %%
src_DIR = '/Volumes/GoogleDrive-103278653964135897318/My Drive/TemporalData-Processed-Eval-SNDVI'
X_data, y_data = load_Processed_Data(src_DIR)
y_data = y_data[0:4]
print (X_data.shape)
print (len(y_data))
# Out:
# Progress: 0.36% Cur Image: 9.npy TIME REMAINING: 19.13 seconds
# Progress: 0.73% Cur Image: 19.npy TIME REMAINING: 14.12 seconds
# Progress: 1.09% Cur Image: 29.npy TIME REMAINING: 18.82 seconds
# Progress: 1.45% Cur Image: 39.npy TIME REMAINING: 23.13 seconds
# Progress: 1.82% Cur Image: 49.npy TIME REMAINING: 26.08 seconds
# Progress: 2.18% Cur Image: 59.npy TIME REMAINING: 24.07 seconds
# Progress: 2.54% Cur Image: 69.npy TIME REMAINING: 28.71 seconds
# Progress: 2.91% Cur Image: 79.npy TIME REMAINING: 27.03 seconds
# Progress: 3.27% Cur Image: 89.npy TIME REMAINING: 29.49 seconds
# Progress: 3.64% Cur Image: 99.npy TIME REMAINING: 37.06 seconds
# Progress: 4.00% Cur Image: 109.npy TIME REMAINING: 33.72 seconds
# Progress: 4.36% Cur Image: 119.npy TIME REMAINING: 37.42 seconds
# Progress: 4.73% Cur Image: 129.npy TIME REMAINING: 37.18 seconds
# Progress: 5.09% Cur Image: 139.npy TIME REMAINING: 43.32 seconds
# Progress: 5.45% Cur Image: 149.npy TIME REMAINING: 49.03 seconds
# Progress: 5.82% Cur Image: 159.npy TIME REMAINING: 45.14 seconds
# Progress: 6.18% Cur Image: 169.npy TIME REMAINING: 46.23 seconds
# Progress: 6.54% Cur Image: 179.npy TIME REMAINING: 43.49 seconds
# Progress: 6.91% Cur Image: 189.npy TIME REMAINING: 51.26 seconds
# Progress: 7.27% Cur Image: 199.npy TIME REMAINING: 50.67 seconds
# Progress: 7.63% Cur Image: 209.npy TIME REMAINING: 49.07 seconds
# Progress: 8.00% Cur Image: 219.npy TIME REMAINING: 48.45 seconds
# Progress: 8.36% Cur Image: 229.npy TIME REMAINING: 56.54 seconds
# Progress: 8.72% Cur Image: 239.npy TIME REMAINING: 54.62 seconds
# Progress: 9.09% Cur Image: 249.npy TIME REMAINING: 61.15 seconds
# Progress: 9.45% Cur Image: 259.npy TIME REMAINING: 61.10 seconds
# Progress: 9.81% Cur Image: 269.npy TIME REMAINING: 76.90 seconds
# Progress: 10.18% Cur Image: 279.npy TIME REMAINING: 154.74 seconds
# Progress: 10.54% Cur Image: 289.npy TIME REMAINING: 68.20 seconds
# Progress: 10.91% Cur Image: 299.npy TIME REMAINING: 68.04 seconds
# Progress: 11.27% Cur Image: 309.npy TIME REMAINING: 73.06 seconds
# Progress: 11.63% Cur Image: 319.npy TIME REMAINING: 124.27 seconds
# Progress: 12.00% Cur Image: 329.npy TIME REMAINING: 94.18 seconds
# Progress: 12.36% Cur Image: 339.npy TIME REMAINING: 78.41 seconds
# Progress: 12.72% Cur Image: 349.npy TIME REMAINING: 80.79 seconds
# Progress: 13.09% Cur Image: 359.npy TIME REMAINING: 287.00 seconds
# Progress: 13.45% Cur Image: 369.npy TIME REMAINING: 98.04 seconds
# Progress: 13.81% Cur Image: 379.npy TIME REMAINING: 102.02 seconds
# Progress: 14.18% Cur Image: 389.npy TIME REMAINING: 127.78 seconds
# Progress: 14.54% Cur Image: 399.npy TIME REMAINING: 106.45 seconds
# Progress: 14.90% Cur Image: 409.npy TIME REMAINING: 110.97 seconds
# Progress: 15.27% Cur Image: 419.npy TIME REMAINING: 86.05 seconds
# Progress: 15.63% Cur Image: 429.npy TIME REMAINING: 90.74 seconds
# Progress: 15.99% Cur Image: 439.npy TIME REMAINING: 88.28 seconds
# Progress: 16.36% Cur Image: 449.npy TIME REMAINING: 99.17 seconds
# Progress: 16.72% Cur Image: 459.npy TIME REMAINING: 110.16 seconds
# Progress: 17.08% Cur Image: 469.npy TIME REMAINING: 97.62 seconds
# Progress: 17.45% Cur Image: 479.npy TIME REMAINING: 109.82 seconds
# Progress: 17.81% Cur Image: 489.npy TIME REMAINING: 115.19 seconds
# Progress: 18.18% Cur Image: 499.npy TIME REMAINING: 110.88 seconds
# Progress: 18.54% Cur Image: 509.npy TIME REMAINING: 105.20 seconds
# Progress: 18.90% Cur Image: 519.npy TIME REMAINING: 100.86 seconds
# Progress: 19.27% Cur Image: 529.npy TIME REMAINING: 95.39 seconds
# Progress: 19.63% Cur Image: 539.npy TIME REMAINING: 118.10 seconds
# Progress: 19.99% Cur Image: 549.npy TIME REMAINING: 110.86 seconds
# Progress: 20.36% Cur Image: 559.npy TIME REMAINING: 115.91 seconds
# Progress: 20.72% Cur Image: 569.npy TIME REMAINING: 107.46 seconds
# Progress: 21.08% Cur Image: 579.npy TIME REMAINING: 119.87 seconds
# Progress: 21.45% Cur Image: 589.npy TIME REMAINING: 110.46 seconds
# Progress: 21.81% Cur Image: 599.npy TIME REMAINING: 115.43 seconds
# Progress: 22.17% Cur Image: 609.npy TIME REMAINING: 114.27 seconds
# Progress: 22.54% Cur Image: 619.npy TIME REMAINING: 109.55 seconds
# Progress: 22.90% Cur Image: 629.npy TIME REMAINING: 118.60 seconds
# Progress: 23.26% Cur Image: 639.npy TIME REMAINING: 118.57 seconds
# Progress: 23.63% Cur Image: 649.npy TIME REMAINING: 118.76 seconds
# Progress: 23.99% Cur Image: 659.npy TIME REMAINING: 115.13 seconds
# Progress: 24.35% Cur Image: 669.npy TIME REMAINING: 125.19 seconds
# Progress: 24.72% Cur Image: 679.npy TIME REMAINING: 163.17 seconds
# Progress: 25.08% Cur Image: 689.npy TIME REMAINING: 146.87 seconds
# Progress: 25.45% Cur Image: 699.npy TIME REMAINING: 139.10 seconds
# Progress: 25.81% Cur Image: 709.npy TIME REMAINING: 132.70 seconds
# Progress: 26.17% Cur Image: 719.npy TIME REMAINING: 123.16 seconds
# Progress: 26.54% Cur Image: 729.npy TIME REMAINING: 198.45 seconds
# Progress: 26.90% Cur Image: 739.npy TIME REMAINING: 134.01 seconds
# Progress: 27.26% Cur Image: 749.npy TIME REMAINING: 127.51 seconds
# Progress: 27.63% Cur Image: 759.npy TIME REMAINING: 155.58 seconds
# Progress: 27.99% Cur Image: 769.npy TIME REMAINING: 145.87 seconds
# Progress: 28.35% Cur Image: 779.npy TIME REMAINING: 133.54 seconds
# Progress: 28.72% Cur Image: 789.npy TIME REMAINING: 131.96 seconds
# Progress: 29.08% Cur Image: 799.npy TIME REMAINING: 140.21 seconds
# Progress: 29.44% Cur Image: 809.npy TIME REMAINING: 174.31 seconds
# Progress: 29.81% Cur Image: 819.npy TIME REMAINING: 144.02 seconds
# Progress: 30.17% Cur Image: 829.npy TIME REMAINING: 146.46 seconds
# Progress: 30.53% Cur Image: 839.npy TIME REMAINING: 172.97 seconds
# Progress: 30.90% Cur Image: 849.npy TIME REMAINING: 144.66 seconds
# Progress: 31.26% Cur Image: 859.npy TIME REMAINING: 145.90 seconds
# Progress: 31.62% Cur Image: 869.npy TIME REMAINING: 137.22 seconds
# Progress: 31.99% Cur Image: 879.npy TIME REMAINING: 124.31 seconds
# Progress: 32.35% Cur Image: 889.npy TIME REMAINING: 141.41 seconds
# Progress: 32.72% Cur Image: 899.npy TIME REMAINING: 123.07 seconds
# Progress: 33.08% Cur Image: 909.npy TIME REMAINING: 143.87 seconds
# Progress: 33.44% Cur Image: 919.npy TIME REMAINING: 127.56 seconds
# Progress: 33.81% Cur Image: 929.npy TIME REMAINING: 138.29 seconds
# Progress: 34.17% Cur Image: 939.npy TIME REMAINING: 137.76 seconds
# Progress: 34.53% Cur Image: 949.npy TIME REMAINING: 147.44 seconds
# Progress: 34.90% Cur Image: 959.npy TIME REMAINING: 146.64 seconds
# Progress: 35.26% Cur Image: 969.npy TIME REMAINING: 140.32 seconds
# Progress: 35.62% Cur Image: 979.npy TIME REMAINING: 142.56 seconds
# Progress: 35.99% Cur Image: 989.npy TIME REMAINING: 143.65 seconds
# Progress: 36.35% Cur Image: 999.npy TIME REMAINING: 144.77 seconds
# Progress: 36.71% Cur Image: 1009.npy TIME REMAINING: 145.66 seconds
# Progress: 37.08% Cur Image: 1019.npy TIME REMAINING: 140.08 seconds
# Progress: 37.44% Cur Image: 1029.npy TIME REMAINING: 133.30 seconds
# Progress: 37.80% Cur Image: 1039.npy TIME REMAINING: 131.06 seconds
# Progress: 38.17% Cur Image: 1049.npy TIME REMAINING: 142.96 seconds
# Progress: 38.53% Cur Image: 1059.npy TIME REMAINING: 129.00 seconds
# Progress: 38.89% Cur Image: 1069.npy TIME REMAINING: 141.81 seconds
# Progress: 39.26% Cur Image: 1079.npy TIME REMAINING: 142.13 seconds
# Progress: 39.62% Cur Image: 1089.npy TIME REMAINING: 142.21 seconds
# Progress: 39.99% Cur Image: 1099.npy TIME REMAINING: 186.50 seconds
# Progress: 40.35% Cur Image: 1109.npy TIME REMAINING: 162.57 seconds
# Progress: 40.71% Cur Image: 1119.npy TIME REMAINING: 186.31 seconds
# Progress: 41.08% Cur Image: 1129.npy TIME REMAINING: 211.20 seconds
# Progress: 41.44% Cur Image: 1139.npy TIME REMAINING: 182.32 seconds
# Progress: 41.80% Cur Image: 1149.npy TIME REMAINING: 132.08 seconds
# Progress: 42.17% Cur Image: 1159.npy TIME REMAINING: 130.94 seconds
# Progress: 42.53% Cur Image: 1169.npy TIME REMAINING: 133.25 seconds
# Progress: 42.89% Cur Image: 1179.npy TIME REMAINING: 130.19 seconds
# Progress: 43.26% Cur Image: 1189.npy TIME REMAINING: 129.06 seconds
# Progress: 43.62% Cur Image: 1199.npy TIME REMAINING: 133.06 seconds
# Progress: 43.98% Cur Image: 1209.npy TIME REMAINING: 135.93 seconds
# Progress: 44.35% Cur Image: 1219.npy TIME REMAINING: 133.54 seconds
# Progress: 44.71% Cur Image: 1229.npy TIME REMAINING: 135.73 seconds
# Progress: 45.07% Cur Image: 1239.npy TIME REMAINING: 162.30 seconds
# Progress: 45.44% Cur Image: 1249.npy TIME REMAINING: 195.98 seconds
# Progress: 45.80% Cur Image: 1259.npy TIME REMAINING: 153.31 seconds
# Progress: 46.17% Cur Image: 1269.npy TIME REMAINING: 131.87 seconds
# Progress: 46.53% Cur Image: 1279.npy TIME REMAINING: 158.37 seconds
# Progress: 46.89% Cur Image: 1289.npy TIME REMAINING: 141.36 seconds
# Progress: 47.26% Cur Image: 1299.npy TIME REMAINING: 138.26 seconds
# Progress: 47.62% Cur Image: 1309.npy TIME REMAINING: 146.17 seconds
# Progress: 47.98% Cur Image: 1319.npy TIME REMAINING: 142.86 seconds
# Progress: 48.35% Cur Image: 1329.npy TIME REMAINING: 148.63 seconds
# Progress: 48.71% Cur Image: 1339.npy TIME REMAINING: 143.33 seconds
# Progress: 49.07% Cur Image: 1349.npy TIME REMAINING: 146.66 seconds
# Progress: 49.44% Cur Image: 1359.npy TIME REMAINING: 143.09 seconds
# Progress: 49.80% Cur Image: 1369.npy TIME REMAINING: 146.30 seconds
# Progress: 50.16% Cur Image: 1379.npy TIME REMAINING: 134.89 seconds
# Progress: 50.53% Cur Image: 1389.npy TIME REMAINING: 147.98 seconds
# Progress: 50.89% Cur Image: 1399.npy TIME REMAINING: 142.68 seconds
# Progress: 51.25% Cur Image: 1409.npy TIME REMAINING: 148.71 seconds
# Progress: 51.62% Cur Image: 1419.npy TIME REMAINING: 143.09 seconds
# Progress: 51.98% Cur Image: 1429.npy TIME REMAINING: 140.90 seconds
# Progress: 52.34% Cur Image: 1439.npy TIME REMAINING: 143.16 seconds
# Progress: 52.71% Cur Image: 1449.npy TIME REMAINING: 147.27 seconds
# Progress: 53.07% Cur Image: 1459.npy TIME REMAINING: 148.94 seconds
# Progress: 53.44% Cur Image: 1469.npy TIME REMAINING: 150.49 seconds
# Progress: 53.80% Cur Image: 1479.npy TIME REMAINING: 157.53 seconds
# Progress: 54.16% Cur Image: 1489.npy TIME REMAINING: 158.58 seconds
# Progress: 54.53% Cur Image: 1499.npy TIME REMAINING: 164.38 seconds
# Progress: 54.89% Cur Image: 1509.npy TIME REMAINING: 167.62 seconds
# Progress: 55.25% Cur Image: 1519.npy TIME REMAINING: 199.38 seconds
# Progress: 55.62% Cur Image: 1529.npy TIME REMAINING: 169.37 seconds
# Progress: 55.98% Cur Image: 1539.npy TIME REMAINING: 158.36 seconds
# Progress: 56.34% Cur Image: 1549.npy TIME REMAINING: 159.85 seconds
# Progress: 56.71% Cur Image: 1559.npy TIME REMAINING: 158.00 seconds
# Progress: 57.07% Cur Image: 1569.npy TIME REMAINING: 162.90 seconds
# Progress: 57.43% Cur Image: 1579.npy TIME REMAINING: 183.72 seconds
# Progress: 57.80% Cur Image: 1589.npy TIME REMAINING: 163.46 seconds
# Progress: 58.16% Cur Image: 1599.npy TIME REMAINING: 160.43 seconds
# Progress: 58.52% Cur Image: 1609.npy TIME REMAINING: 236.95 seconds
# Progress: 58.89% Cur Image: 1619.npy TIME REMAINING: 134.99 seconds
# Progress: 59.25% Cur Image: 1629.npy TIME REMAINING: 123.42 seconds
# Progress: 59.61% Cur Image: 1639.npy TIME REMAINING: 123.41 seconds
# Progress: 59.98% Cur Image: 1649.npy TIME REMAINING: 119.13 seconds
# Progress: 60.34% Cur Image: 1659.npy TIME REMAINING: 125.18 seconds
# Progress: 60.71% Cur Image: 1669.npy TIME REMAINING: 121.79 seconds
# Progress: 61.07% Cur Image: 1679.npy TIME REMAINING: 171.02 seconds
# Progress: 61.43% Cur Image: 1689.npy TIME REMAINING: 163.41 seconds
# Progress: 61.80% Cur Image: 1699.npy TIME REMAINING: 133.24 seconds
# Progress: 62.16% Cur Image: 1709.npy TIME REMAINING: 143.42 seconds
# Progress: 62.52% Cur Image: 1719.npy TIME REMAINING: 176.91 seconds
# Progress: 62.89% Cur Image: 1729.npy TIME REMAINING: 131.22 seconds
# Progress: 63.25% Cur Image: 1739.npy TIME REMAINING: 119.36 seconds
# Progress: 63.61% Cur Image: 1749.npy TIME REMAINING: 120.65 seconds
# Progress: 63.98% Cur Image: 1759.npy TIME REMAINING: 141.17 seconds
# Progress: 64.34% Cur Image: 1769.npy TIME REMAINING: 129.68 seconds
# Progress: 64.70% Cur Image: 1779.npy TIME REMAINING: 134.82 seconds
# Progress: 65.07% Cur Image: 1789.npy TIME REMAINING: 133.05 seconds
# Progress: 65.43% Cur Image: 1799.npy TIME REMAINING: 127.77 seconds
# Progress: 65.79% Cur Image: 1809.npy TIME REMAINING: 150.87 seconds
# Progress: 66.16% Cur Image: 1819.npy TIME REMAINING: 129.04 seconds
# Progress: 66.52% Cur Image: 1829.npy TIME REMAINING: 135.45 seconds
# Progress: 66.88% Cur Image: 1839.npy TIME REMAINING: 120.36 seconds
# Progress: 67.25% Cur Image: 1849.npy TIME REMAINING: 150.33 seconds
# Progress: 67.61% Cur Image: 1859.npy TIME REMAINING: 125.68 seconds
# Progress: 67.98% Cur Image: 1869.npy TIME REMAINING: 132.19 seconds
# Progress: 68.34% Cur Image: 1879.npy TIME REMAINING: 109.18 seconds
# Progress: 68.70% Cur Image: 1889.npy TIME REMAINING: 120.48 seconds
# Progress: 69.07% Cur Image: 1899.npy TIME REMAINING: 120.33 seconds
# Progress: 69.43% Cur Image: 1909.npy TIME REMAINING: 124.41 seconds
# Progress: 69.79% Cur Image: 1919.npy TIME REMAINING: 108.67 seconds
# Progress: 70.16% Cur Image: 1929.npy TIME REMAINING: 106.84 seconds
# Progress: 70.52% Cur Image: 1939.npy TIME REMAINING: 109.28 seconds
# Progress: 70.88% Cur Image: 1949.npy TIME REMAINING: 111.55 seconds
# Progress: 71.25% Cur Image: 1959.npy TIME REMAINING: 124.67 seconds
# Progress: 71.61% Cur Image: 1969.npy TIME REMAINING: 107.58 seconds
# Progress: 71.97% Cur Image: 1979.npy TIME REMAINING: 99.24 seconds
# Progress: 72.34% Cur Image: 1989.npy TIME REMAINING: 101.15 seconds
# Progress: 72.70% Cur Image: 1999.npy TIME REMAINING: 115.02 seconds
# Progress: 73.06% Cur Image: 2009.npy TIME REMAINING: 146.74 seconds
# Progress: 73.43% Cur Image: 2019.npy TIME REMAINING: 153.02 seconds
# Progress: 73.79% Cur Image: 2029.npy TIME REMAINING: 151.69 seconds
# Progress: 74.15% Cur Image: 2039.npy TIME REMAINING: 96.85 seconds
# Progress: 74.52% Cur Image: 2049.npy TIME REMAINING: 96.05 seconds
# Progress: 74.88% Cur Image: 2059.npy TIME REMAINING: 112.85 seconds
# Progress: 75.25% Cur Image: 2069.npy TIME REMAINING: 92.44 seconds
# Progress: 75.61% Cur Image: 2079.npy TIME REMAINING: 104.19 seconds
# Progress: 75.97% Cur Image: 2089.npy TIME REMAINING: 112.62 seconds
# Progress: 76.34% Cur Image: 2099.npy TIME REMAINING: 93.15 seconds
# Progress: 76.70% Cur Image: 2109.npy TIME REMAINING: 91.96 seconds
# Progress: 77.06% Cur Image: 2119.npy TIME REMAINING: 88.34 seconds
# Progress: 77.43% Cur Image: 2129.npy TIME REMAINING: 97.75 seconds
# Progress: 77.79% Cur Image: 2139.npy TIME REMAINING: 92.05 seconds
# Progress: 78.15% Cur Image: 2149.npy TIME REMAINING: 87.44 seconds
# Progress: 78.52% Cur Image: 2159.npy TIME REMAINING: 86.25 seconds
# Progress: 78.88% Cur Image: 2169.npy TIME REMAINING: 81.53 seconds
# Progress: 79.24% Cur Image: 2179.npy TIME REMAINING: 87.18 seconds
# Progress: 79.61% Cur Image: 2189.npy TIME REMAINING: 96.18 seconds
# Progress: 79.97% Cur Image: 2199.npy TIME REMAINING: 82.66 seconds
# Progress: 80.33% Cur Image: 2209.npy TIME REMAINING: 80.13 seconds
# Progress: 80.70% Cur Image: 2219.npy TIME REMAINING: 75.06 seconds
# Progress: 81.06% Cur Image: 2229.npy TIME REMAINING: 74.83 seconds
# Progress: 81.42% Cur Image: 2239.npy TIME REMAINING: 72.29 seconds
# Progress: 81.79% Cur Image: 2249.npy TIME REMAINING: 71.83 seconds
# Progress: 82.15% Cur Image: 2259.npy TIME REMAINING: 72.42 seconds
# Progress: 82.52% Cur Image: 2269.npy TIME REMAINING: 70.56 seconds
# Progress: 82.88% Cur Image: 2279.npy TIME REMAINING: 69.81 seconds
# Progress: 83.24% Cur Image: 2289.npy TIME REMAINING: 69.67 seconds
# Progress: 83.61% Cur Image: 2299.npy TIME REMAINING: 70.95 seconds
# Progress: 83.97% Cur Image: 2309.npy TIME REMAINING: 74.69 seconds
# Progress: 84.33% Cur Image: 2319.npy TIME REMAINING: 76.08 seconds
# Progress: 84.70% Cur Image: 2329.npy TIME REMAINING: 73.49 seconds
# Progress: 85.06% Cur Image: 2339.npy TIME REMAINING: 67.60 seconds
# Progress: 85.42% Cur Image: 2349.npy TIME REMAINING: 78.45 seconds
# Progress: 85.79% Cur Image: 2359.npy TIME REMAINING: 64.81 seconds
# Progress: 86.15% Cur Image: 2369.npy TIME REMAINING: 65.79 seconds
# Progress: 86.51% Cur Image: 2379.npy TIME REMAINING: 63.55 seconds
# Progress: 86.88% Cur Image: 2389.npy TIME REMAINING: 60.16 seconds
# Progress: 87.24% Cur Image: 2399.npy TIME REMAINING: 56.75 seconds
# Progress: 87.60% Cur Image: 2409.npy TIME REMAINING: 55.41 seconds
# Progress: 87.97% Cur Image: 2419.npy TIME REMAINING: 66.98 seconds
# Progress: 88.33% Cur Image: 2429.npy TIME REMAINING: 98.08 seconds
# Progress: 88.70% Cur Image: 2439.npy TIME REMAINING: 64.00 seconds
# Progress: 89.06% Cur Image: 2449.npy TIME REMAINING: 48.89 seconds
# Progress: 89.42% Cur Image: 2459.npy TIME REMAINING: 47.45 seconds
# Progress: 89.79% Cur Image: 2469.npy TIME REMAINING: 47.13 seconds
# Progress: 90.15% Cur Image: 2479.npy TIME REMAINING: 46.39 seconds
# Progress: 90.51% Cur Image: 2489.npy TIME REMAINING: 43.05 seconds
# Progress: 90.88% Cur Image: 2499.npy TIME REMAINING: 40.38 seconds
# Progress: 91.24% Cur Image: 2509.npy TIME REMAINING: 39.00 seconds
# Progress: 91.60% Cur Image: 2519.npy TIME REMAINING: 53.95 seconds
# Progress: 91.97% Cur Image: 2529.npy TIME REMAINING: 42.12 seconds
# Progress: 92.33% Cur Image: 2539.npy TIME REMAINING: 35.09 seconds
# Progress: 92.69% Cur Image: 2549.npy TIME REMAINING: 32.77 seconds
# Progress: 93.06% Cur Image: 2559.npy TIME REMAINING: 35.99 seconds
# Progress: 93.42% Cur Image: 2569.npy TIME REMAINING: 33.38 seconds
# Progress: 93.78% Cur Image: 2579.npy TIME REMAINING: 28.82 seconds
# Progress: 94.15% Cur Image: 2589.npy TIME REMAINING: 26.28 seconds
# Progress: 94.51% Cur Image: 2599.npy TIME REMAINING: 26.22 seconds
# Progress: 94.87% Cur Image: 2609.npy TIME REMAINING: 22.52 seconds
# Progress: 95.24% Cur Image: 2619.npy TIME REMAINING: 22.09 seconds
# Progress: 95.60% Cur Image: 2629.npy TIME REMAINING: 21.99 seconds
# Progress: 95.97% Cur Image: 2639.npy TIME REMAINING: 20.75 seconds
# Progress: 96.33% Cur Image: 2649.npy TIME REMAINING: 18.53 seconds
# Progress: 96.69% Cur Image: 2659.npy TIME REMAINING: 16.18 seconds
# Progress: 97.06% Cur Image: 2669.npy TIME REMAINING: 13.60 seconds
# Progress: 97.42% Cur Image: 2679.npy TIME REMAINING: 12.27 seconds
# Progress: 97.78% Cur Image: 2689.npy TIME REMAINING: 11.58 seconds
# Progress: 98.15% Cur Image: 2699.npy TIME REMAINING: 9.34 seconds
# Progress: 98.51% Cur Image: 2709.npy TIME REMAINING: 7.00 seconds
# Progress: 98.87% Cur Image: 2719.npy TIME REMAINING: 5.25 seconds
# Progress: 99.24% Cur Image: 2729.npy TIME REMAINING: 3.48 seconds
# Progress: 99.60% Cur Image: 2739.npy TIME REMAINING: 1.89 seconds
# Progress: 99.96% Cur Image: 2749.npy TIME REMAINING: 0.17 seconds
# (2752, 4, 51, 51)
# 0

# %%
np.save(os.path.join(src_DIR, 'Collated.npy'), X_data)

# %%
#X_data = np.load('/Volumes/GoogleDrive/My Drive/TemporalData-Processed-Train/Collated.npy')
#y_data = np.load('/Volumes/GoogleDrive/My Drive/TemporalData-Processed-Train/labels.npy')
X_test = np.load('/Volumes/GoogleDrive/My Drive/TemporalData-Processed-Eval/Collated.npy')
y_test = np.load('/Volumes/GoogleDrive/My Drive/TemporalData-Processed-Eval/labels.npy')

# %%
X_train, X_val, y_train, y_val = train_test_split(X_data[:-1], y_data, test_size=0.20, random_state=42)

# %% [markdown]
# Total Images for Temporal: 43,652
#
# Total Images for Spatial: 35,340
#
# Temporal:
#
# Training: (6528, 4, 51, 51, 3), (6528, 3)
#
# Validation: (1633, 4, 51, 51, 3), (1633, 3)
#
# Testing: (2752, 4, 51, 51, 3), (2751, 3)
#
# Spatial:

# %%
print ("Training: {}, {}".format(X_train.shape, y_train.shape))
print ("Validation: {}, {}".format(X_val.shape, y_val.shape))
print ("Testing: {}, {}".format(X_test.shape, y_test.shape))
# Out:
# Training: (6528, 4, 51, 51, 3), (6528, 3)
# Validation: (1633, 4, 51, 51, 3), (1633, 3)
# Testing: (2752, 4, 51, 51, 3), (2751, 3)

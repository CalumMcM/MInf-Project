# %% [markdown]
# # Data Preparation

# %%
import numpy as np
import time
from time import time
from torch.autograd import Variable
import os
import sys
sys.path.append('../')
import matplotlib.pyplot as plt
import rasterio as rs
from src.sample_tiles import *
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras import layers

import torch
from img2vec_pytorch import Img2Vec
from PIL import Image
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Step 1. Sample image names

# %% [markdown]
# For each biome store the names of each image in an array

# %% [markdown]
# ### Organise structure for directory iteration

# %%
POS_to_CODE = {
    0: 1,
    1: 2,
    2: 3,
}

# %%
def one_ugly_encoding(hot_arr):
    hot_arr = np.array(hot_arr)
    ugly_arr = []
    for arr in hot_arr:
        code = POS_to_CODE[np.argmax(arr)]
        ugly_arr.append(code)
    return np.array(ugly_arr)

# %%
def normalize_red(array):
    return (array - array.min()) / (array.max() - array.min())
def normalize_green(array):
    return (array - array.min()) / (array.max() - array.min())
def normalize_blue(array):
    return (array - array.min()) / (array.max() - array.min())

# %%
def biome_numerator(biome_DIR):
    biome = biome_DIR.split('/')[-1]

    if biome == "TemporalAmazonia":
        return [1,0,0]
    if biome == "TemporalCerrado":
        return [0,1,0]
    if biome == "TemporalCaatinga":
        return [0,0,1]

    # if biome == "TemporalAmazonia":
    #     return np.zeros((4,51,51,1))
    # if biome == "TemporalCerrado":
    #     return np.ones((4,51,51,1))
    # if biome == "TemporalCaatinga":
    #     return np.full((4,51,51,1), 2)

def get_data():
    X_data = np.zeros((1,4,51,51,3))
    y_data = np.zeros((1,3))
    head_DIR = '/Volumes/GoogleDrive/My Drive/TemporalData-old'

    subfolders = [f.path for f in os.scandir(head_DIR) if f.is_dir()]
    idx = 0
    for biome_DIR in subfolders:
        print ("CUR BIOME: {}".format(biome_DIR.split('/')[-1]))
        cur_biome_label = biome_numerator(biome_DIR)

        biome_quads = [f.path for f in os.scandir(biome_DIR) if f.is_dir()]

        for quad_DIR in biome_quads:
            print ("CUR QUAD: {}".format(quad_DIR.split('/')[-1]))
            quad_images = [f.path for f in os.scandir(quad_DIR) if f.is_dir()]

            for image_DIR in quad_images:
                years = [f.path for f in os.scandir(image_DIR) if f.is_file() and '.tif' in f.path]

                # Create array to store each set of images
                years_array = np.zeros((4, 51, 51, 3))
                cur_year = 0
                for year_DIR in years:
                    # Open the iamge
                    raster = rs.open(year_DIR)

                    red = raster.read(4)
                    green = raster.read(3)
                    blue = raster.read(2)
                    
                    #red_norm = normalize_red(red)
                    #green_norm = normalize_green(green)
                    #blue_norm = normalize_blue(blue)
                    
                    # Stack bands
                    img = []
                    img = np.dstack((red, green, blue))
                    
                    # Ignore images that are mishapen
                    x, y, z  = img.shape

                    if (x > 48 and x < 54) and (y > 48 and y < 54):
                        reset_img = reset_shape(img)

                        clean_img = remove_nan(reset_img)

                        if clean_img.shape == (51,51,3):
                            years_array[cur_year,:] = clean_img

                        cur_year += 1
                
                # Save each series of images as a numpy array
                
                # Create training and label matrices
                #X_data = np.append(X_data, np.array([years_array]), axis = 0)
                #y_data = np.append(y_data, np.array([cur_biome_label]), axis = 0)
                
                progress = img_processed/len(image_DIR)*100
                print ("Progress: {.2f}%".format(progress))
                # Method to stop early after idx number of images
                # idx += 1
                # if idx == 30:
                #     # Remove first set of zeros 
                #     X_data = np.delete(X_data, (0), axis=0)
                #     y_data = np.delete(y_data, (0), axis=0)
                #     return X_data, y_data

# %%
def load_Processed_Data(DIR):

    X_data = np.zeros((1,4,51,51))
    y_data = np.zeros((1,3))

    image_PATHS = [f.path for f in os.scandir(DIR) if 'npy' in f.path]
    failed_images = []
    idx = 1
    previous_progress = 0
    start = time.time()

    for image_PATH in image_PATHS[:-1]:
        
        try:
            image = np.load(image_PATH)

            X_data = np.append(X_data, np.array([image]), axis = 0)

            if (idx%10 == 0):
                progress = (idx/len(image_PATHS[:-1]))*100
                end = time.time()
                time_remaining = ((end - start)/(progress-previous_progress)) * (100-progress)

                print ("Progress: {:.2f}% Cur Image: {} TIME REMAINING: {:.2f} seconds ".format(progress, image_PATH.split('/')[-1], time_remaining))
                previous_progress= progress
                start = time.time()
        except:
            image_name = image_PATH.split('/')[-1].split('.')[0]

            failed_images.append(image_name)

            print ("FAILED: {} \t {}".format(image_name, image_PATH))

        idx += 1

    print (image_PATHS[-1])
    y_data = np.append(y_data, np.array(np.load(image_PATHS[-1])), axis = 0)

    return X_data, y_data

# %%
src_DIR = '/Volumes/GoogleDrive/My Drive/TemporalData-Processed-Train-SWIR'
X_data, y_data = load_Processed_Data(src_DIR)
y_data = y_data[0:4]
print (X_data.shape)
print (y_data.shape)
# Out:
# Progress: 0.06% Cur Image: 4.npy TIME REMAINING: 287.29 seconds
# Progress: 0.12% Cur Image: 9.npy TIME REMAINING: 138.38 seconds
# Progress: 0.18% Cur Image: 14.npy TIME REMAINING: 125.18 seconds
# Progress: 0.25% Cur Image: 19.npy TIME REMAINING: 133.49 seconds
# Progress: 0.31% Cur Image: 24.npy TIME REMAINING: 284.04 seconds
# Progress: 0.37% Cur Image: 29.npy TIME REMAINING: 159.10 seconds
# Progress: 0.43% Cur Image: 34.npy TIME REMAINING: 170.28 seconds
# Progress: 0.49% Cur Image: 39.npy TIME REMAINING: 145.59 seconds
# Progress: 0.55% Cur Image: 44.npy TIME REMAINING: 185.29 seconds
# Progress: 0.61% Cur Image: 49.npy TIME REMAINING: 152.41 seconds
# Progress: 0.67% Cur Image: 54.npy TIME REMAINING: 129.51 seconds
# Progress: 0.74% Cur Image: 59.npy TIME REMAINING: 408.02 seconds
# Progress: 0.80% Cur Image: 64.npy TIME REMAINING: 163.43 seconds
# Progress: 0.86% Cur Image: 69.npy TIME REMAINING: 162.14 seconds
# Progress: 0.92% Cur Image: 74.npy TIME REMAINING: 210.10 seconds
# Progress: 0.98% Cur Image: 79.npy TIME REMAINING: 175.92 seconds
# Progress: 1.04% Cur Image: 84.npy TIME REMAINING: 175.84 seconds
# Progress: 1.10% Cur Image: 89.npy TIME REMAINING: 200.20 seconds
# Progress: 1.16% Cur Image: 94.npy TIME REMAINING: 184.80 seconds
# Progress: 1.23% Cur Image: 99.npy TIME REMAINING: 180.01 seconds
# Progress: 1.29% Cur Image: 104.npy TIME REMAINING: 157.27 seconds
# Progress: 1.35% Cur Image: 109.npy TIME REMAINING: 170.00 seconds
# Progress: 1.41% Cur Image: 114.npy TIME REMAINING: 172.30 seconds
# Progress: 1.47% Cur Image: 119.npy TIME REMAINING: 190.82 seconds
# Progress: 1.53% Cur Image: 124.npy TIME REMAINING: 164.29 seconds
# Progress: 1.59% Cur Image: 129.npy TIME REMAINING: 195.49 seconds
# Progress: 1.65% Cur Image: 134.npy TIME REMAINING: 263.69 seconds
# Progress: 1.72% Cur Image: 139.npy TIME REMAINING: 199.53 seconds
# Progress: 1.78% Cur Image: 144.npy TIME REMAINING: 210.07 seconds
# Progress: 1.84% Cur Image: 149.npy TIME REMAINING: 184.73 seconds
# Progress: 1.90% Cur Image: 154.npy TIME REMAINING: 226.81 seconds
# Progress: 1.96% Cur Image: 159.npy TIME REMAINING: 544.68 seconds
# Progress: 2.02% Cur Image: 164.npy TIME REMAINING: 426.39 seconds
# Progress: 2.08% Cur Image: 169.npy TIME REMAINING: 313.09 seconds
# Progress: 2.14% Cur Image: 174.npy TIME REMAINING: 268.59 seconds
# Progress: 2.21% Cur Image: 179.npy TIME REMAINING: 197.14 seconds
# Progress: 2.27% Cur Image: 184.npy TIME REMAINING: 256.91 seconds
# Progress: 2.33% Cur Image: 189.npy TIME REMAINING: 238.04 seconds
# Progress: 2.39% Cur Image: 194.npy TIME REMAINING: 199.83 seconds
# Progress: 2.45% Cur Image: 199.npy TIME REMAINING: 273.47 seconds
# Progress: 2.51% Cur Image: 204.npy TIME REMAINING: 243.86 seconds
# Progress: 2.57% Cur Image: 209.npy TIME REMAINING: 218.18 seconds
# Progress: 2.63% Cur Image: 214.npy TIME REMAINING: 210.72 seconds
# Progress: 2.70% Cur Image: 219.npy TIME REMAINING: 243.43 seconds
# Progress: 2.76% Cur Image: 224.npy TIME REMAINING: 241.30 seconds
# Progress: 2.82% Cur Image: 229.npy TIME REMAINING: 242.30 seconds
# Progress: 2.88% Cur Image: 234.npy TIME REMAINING: 233.52 seconds
# Progress: 2.94% Cur Image: 239.npy TIME REMAINING: 208.14 seconds
# Progress: 3.00% Cur Image: 244.npy TIME REMAINING: 351.60 seconds
# Progress: 3.06% Cur Image: 249.npy TIME REMAINING: 208.21 seconds
# Progress: 3.12% Cur Image: 254.npy TIME REMAINING: 239.17 seconds
# Progress: 3.19% Cur Image: 259.npy TIME REMAINING: 248.33 seconds
# Progress: 3.25% Cur Image: 264.npy TIME REMAINING: 251.67 seconds
# Progress: 3.31% Cur Image: 269.npy TIME REMAINING: 219.49 seconds
# Progress: 3.37% Cur Image: 274.npy TIME REMAINING: 237.07 seconds
# Progress: 3.43% Cur Image: 279.npy TIME REMAINING: 278.90 seconds
# Progress: 3.49% Cur Image: 284.npy TIME REMAINING: 280.92 seconds
# Progress: 3.55% Cur Image: 289.npy TIME REMAINING: 250.81 seconds
# Progress: 3.61% Cur Image: 294.npy TIME REMAINING: 276.65 seconds
# Progress: 3.68% Cur Image: 299.npy TIME REMAINING: 454.09 seconds
# Progress: 3.74% Cur Image: 304.npy TIME REMAINING: 467.30 seconds
# Progress: 3.80% Cur Image: 309.npy TIME REMAINING: 407.97 seconds
# Progress: 3.86% Cur Image: 314.npy TIME REMAINING: 267.55 seconds
# Progress: 3.92% Cur Image: 319.npy TIME REMAINING: 257.62 seconds
# Progress: 3.98% Cur Image: 324.npy TIME REMAINING: 349.87 seconds
# Progress: 4.04% Cur Image: 329.npy TIME REMAINING: 278.82 seconds
# Progress: 4.10% Cur Image: 334.npy TIME REMAINING: 297.46 seconds
# Progress: 4.17% Cur Image: 339.npy TIME REMAINING: 281.33 seconds
# Progress: 4.23% Cur Image: 344.npy TIME REMAINING: 343.11 seconds
# Progress: 4.29% Cur Image: 349.npy TIME REMAINING: 304.65 seconds
# Progress: 4.35% Cur Image: 354.npy TIME REMAINING: 420.46 seconds
# Progress: 4.41% Cur Image: 359.npy TIME REMAINING: 268.05 seconds
# Progress: 4.47% Cur Image: 364.npy TIME REMAINING: 305.81 seconds
# Progress: 4.53% Cur Image: 369.npy TIME REMAINING: 307.61 seconds
# Progress: 4.60% Cur Image: 374.npy TIME REMAINING: 337.60 seconds
# Progress: 4.66% Cur Image: 379.npy TIME REMAINING: 328.64 seconds
# Progress: 4.72% Cur Image: 384.npy TIME REMAINING: 333.81 seconds
# Progress: 4.78% Cur Image: 389.npy TIME REMAINING: 302.43 seconds
# Progress: 4.84% Cur Image: 394.npy TIME REMAINING: 309.14 seconds
# Progress: 4.90% Cur Image: 399.npy TIME REMAINING: 309.22 seconds
# Progress: 4.96% Cur Image: 404.npy TIME REMAINING: 322.54 seconds
# Progress: 5.02% Cur Image: 409.npy TIME REMAINING: 342.70 seconds
# Progress: 5.09% Cur Image: 414.npy TIME REMAINING: 327.26 seconds
# Progress: 5.15% Cur Image: 419.npy TIME REMAINING: 317.64 seconds
# Progress: 5.21% Cur Image: 424.npy TIME REMAINING: 353.00 seconds
# Progress: 5.27% Cur Image: 429.npy TIME REMAINING: 441.87 seconds
# Progress: 5.33% Cur Image: 434.npy TIME REMAINING: 356.59 seconds
# Progress: 5.39% Cur Image: 439.npy TIME REMAINING: 398.07 seconds
# Progress: 5.45% Cur Image: 444.npy TIME REMAINING: 334.03 seconds
# Progress: 5.51% Cur Image: 449.npy TIME REMAINING: 328.53 seconds
# Progress: 5.58% Cur Image: 454.npy TIME REMAINING: 337.12 seconds
# Progress: 5.64% Cur Image: 459.npy TIME REMAINING: 378.30 seconds
# Progress: 5.70% Cur Image: 464.npy TIME REMAINING: 331.89 seconds
# Progress: 5.76% Cur Image: 469.npy TIME REMAINING: 392.38 seconds
# Progress: 5.82% Cur Image: 474.npy TIME REMAINING: 513.65 seconds
# Progress: 5.88% Cur Image: 479.npy TIME REMAINING: 585.16 seconds
# Progress: 5.94% Cur Image: 484.npy TIME REMAINING: 429.15 seconds
# Progress: 6.00% Cur Image: 489.npy TIME REMAINING: 380.28 seconds
# Progress: 6.07% Cur Image: 494.npy TIME REMAINING: 387.69 seconds
# Progress: 6.13% Cur Image: 499.npy TIME REMAINING: 322.14 seconds
# Progress: 6.19% Cur Image: 504.npy TIME REMAINING: 395.63 seconds
# Progress: 6.25% Cur Image: 509.npy TIME REMAINING: 356.75 seconds
# Progress: 6.31% Cur Image: 514.npy TIME REMAINING: 343.98 seconds
# Progress: 6.37% Cur Image: 519.npy TIME REMAINING: 369.74 seconds
# Progress: 6.43% Cur Image: 524.npy TIME REMAINING: 366.15 seconds
# Progress: 6.49% Cur Image: 529.npy TIME REMAINING: 336.49 seconds
# Progress: 6.56% Cur Image: 534.npy TIME REMAINING: 445.02 seconds
# Progress: 6.62% Cur Image: 539.npy TIME REMAINING: 338.42 seconds
# Progress: 6.68% Cur Image: 544.npy TIME REMAINING: 347.69 seconds
# Progress: 6.74% Cur Image: 549.npy TIME REMAINING: 401.54 seconds
# Progress: 6.80% Cur Image: 554.npy TIME REMAINING: 354.96 seconds
# Progress: 6.86% Cur Image: 559.npy TIME REMAINING: 413.66 seconds
# Progress: 6.92% Cur Image: 564.npy TIME REMAINING: 420.52 seconds
# Progress: 6.98% Cur Image: 569.npy TIME REMAINING: 376.95 seconds
# Progress: 7.05% Cur Image: 574.npy TIME REMAINING: 386.38 seconds
# Progress: 7.11% Cur Image: 579.npy TIME REMAINING: 367.00 seconds
# Progress: 7.17% Cur Image: 584.npy TIME REMAINING: 357.75 seconds
# Progress: 7.23% Cur Image: 589.npy TIME REMAINING: 378.23 seconds
# Progress: 7.29% Cur Image: 594.npy TIME REMAINING: 372.70 seconds
# Progress: 7.35% Cur Image: 599.npy TIME REMAINING: 376.75 seconds
# Progress: 7.41% Cur Image: 604.npy TIME REMAINING: 383.11 seconds
# Progress: 7.47% Cur Image: 609.npy TIME REMAINING: 378.48 seconds
# Progress: 7.54% Cur Image: 614.npy TIME REMAINING: 390.76 seconds
# Progress: 7.60% Cur Image: 619.npy TIME REMAINING: 381.42 seconds
# Progress: 7.66% Cur Image: 624.npy TIME REMAINING: 395.49 seconds
# Progress: 7.72% Cur Image: 629.npy TIME REMAINING: 388.95 seconds
# Progress: 7.78% Cur Image: 634.npy TIME REMAINING: 389.73 seconds
# Progress: 7.84% Cur Image: 639.npy TIME REMAINING: 393.30 seconds
# Progress: 7.90% Cur Image: 644.npy TIME REMAINING: 384.73 seconds
# Progress: 7.96% Cur Image: 649.npy TIME REMAINING: 396.09 seconds
# Progress: 8.03% Cur Image: 654.npy TIME REMAINING: 390.35 seconds
# Progress: 8.09% Cur Image: 659.npy TIME REMAINING: 411.64 seconds
# Progress: 8.15% Cur Image: 664.npy TIME REMAINING: 408.00 seconds
# Progress: 8.21% Cur Image: 669.npy TIME REMAINING: 400.08 seconds
# Progress: 8.27% Cur Image: 674.npy TIME REMAINING: 400.81 seconds
# Progress: 8.33% Cur Image: 679.npy TIME REMAINING: 564.22 seconds
# Progress: 8.39% Cur Image: 684.npy TIME REMAINING: 521.14 seconds
# Progress: 8.45% Cur Image: 689.npy TIME REMAINING: 779.78 seconds
# Progress: 8.52% Cur Image: 694.npy TIME REMAINING: 707.83 seconds
# Progress: 8.58% Cur Image: 699.npy TIME REMAINING: 709.53 seconds
# Progress: 8.64% Cur Image: 704.npy TIME REMAINING: 664.75 seconds
# Progress: 8.70% Cur Image: 709.npy TIME REMAINING: 764.09 seconds
# Progress: 8.76% Cur Image: 714.npy TIME REMAINING: 817.20 seconds
# Progress: 8.82% Cur Image: 719.npy TIME REMAINING: 575.53 seconds
# Progress: 8.88% Cur Image: 724.npy TIME REMAINING: 569.96 seconds
# Progress: 8.94% Cur Image: 729.npy TIME REMAINING: 510.43 seconds
# Progress: 9.01% Cur Image: 734.npy TIME REMAINING: 462.73 seconds
# Progress: 9.07% Cur Image: 739.npy TIME REMAINING: 459.59 seconds
# Progress: 9.13% Cur Image: 744.npy TIME REMAINING: 441.90 seconds
# Progress: 9.19% Cur Image: 749.npy TIME REMAINING: 418.97 seconds
# Progress: 9.25% Cur Image: 754.npy TIME REMAINING: 513.99 seconds
# Progress: 9.31% Cur Image: 759.npy TIME REMAINING: 477.09 seconds
# Progress: 9.37% Cur Image: 764.npy TIME REMAINING: 435.76 seconds
# Progress: 9.44% Cur Image: 769.npy TIME REMAINING: 446.07 seconds
# Progress: 9.50% Cur Image: 774.npy TIME REMAINING: 445.97 seconds
# Progress: 9.56% Cur Image: 779.npy TIME REMAINING: 458.53 seconds
# Progress: 9.62% Cur Image: 784.npy TIME REMAINING: 448.60 seconds
# Progress: 9.68% Cur Image: 789.npy TIME REMAINING: 468.14 seconds
# Progress: 9.74% Cur Image: 794.npy TIME REMAINING: 446.08 seconds
# Progress: 9.80% Cur Image: 799.npy TIME REMAINING: 465.10 seconds
# Progress: 9.86% Cur Image: 804.npy TIME REMAINING: 479.60 seconds
# Progress: 9.93% Cur Image: 809.npy TIME REMAINING: 478.74 seconds
# Progress: 9.99% Cur Image: 814.npy TIME REMAINING: 504.39 seconds
# Progress: 10.05% Cur Image: 819.npy TIME REMAINING: 489.81 seconds
# Progress: 10.11% Cur Image: 824.npy TIME REMAINING: 522.36 seconds
# Progress: 10.17% Cur Image: 829.npy TIME REMAINING: 504.70 seconds
# Progress: 10.23% Cur Image: 834.npy TIME REMAINING: 484.98 seconds
# Progress: 10.29% Cur Image: 839.npy TIME REMAINING: 481.26 seconds
# Progress: 10.35% Cur Image: 844.npy TIME REMAINING: 475.41 seconds
# Progress: 10.42% Cur Image: 849.npy TIME REMAINING: 503.33 seconds
# Progress: 10.48% Cur Image: 854.npy TIME REMAINING: 571.91 seconds
# Progress: 10.54% Cur Image: 859.npy TIME REMAINING: 485.74 seconds
# Progress: 10.60% Cur Image: 864.npy TIME REMAINING: 507.32 seconds
# Progress: 10.66% Cur Image: 869.npy TIME REMAINING: 469.10 seconds
# Progress: 10.72% Cur Image: 874.npy TIME REMAINING: 477.03 seconds
# Progress: 10.78% Cur Image: 879.npy TIME REMAINING: 480.52 seconds
# Progress: 10.84% Cur Image: 884.npy TIME REMAINING: 501.28 seconds
# Progress: 10.91% Cur Image: 889.npy TIME REMAINING: 506.56 seconds
# Progress: 10.97% Cur Image: 894.npy TIME REMAINING: 496.83 seconds
# Progress: 11.03% Cur Image: 899.npy TIME REMAINING: 507.22 seconds
# Progress: 11.09% Cur Image: 904.npy TIME REMAINING: 496.22 seconds
# Progress: 11.15% Cur Image: 909.npy TIME REMAINING: 524.41 seconds
# Progress: 11.21% Cur Image: 914.npy TIME REMAINING: 486.66 seconds
# Progress: 11.27% Cur Image: 919.npy TIME REMAINING: 511.49 seconds
# Progress: 11.33% Cur Image: 924.npy TIME REMAINING: 512.88 seconds
# Progress: 11.40% Cur Image: 929.npy TIME REMAINING: 520.30 seconds
# Progress: 11.46% Cur Image: 934.npy TIME REMAINING: 516.25 seconds
# Progress: 11.52% Cur Image: 939.npy TIME REMAINING: 520.13 seconds
# Progress: 11.58% Cur Image: 944.npy TIME REMAINING: 536.50 seconds
# Progress: 11.64% Cur Image: 949.npy TIME REMAINING: 546.42 seconds
# Progress: 11.70% Cur Image: 954.npy TIME REMAINING: 620.08 seconds
# Progress: 11.76% Cur Image: 959.npy TIME REMAINING: 552.47 seconds
# Progress: 11.82% Cur Image: 964.npy TIME REMAINING: 542.02 seconds
# Progress: 11.89% Cur Image: 969.npy TIME REMAINING: 535.85 seconds
# Progress: 11.95% Cur Image: 974.npy TIME REMAINING: 538.16 seconds
# Progress: 12.01% Cur Image: 979.npy TIME REMAINING: 541.53 seconds
# Progress: 12.07% Cur Image: 984.npy TIME REMAINING: 528.09 seconds
# Progress: 12.13% Cur Image: 989.npy TIME REMAINING: 584.47 seconds
# Progress: 12.19% Cur Image: 994.npy TIME REMAINING: 544.96 seconds
# Progress: 12.25% Cur Image: 999.npy TIME REMAINING: 588.01 seconds
# Progress: 12.31% Cur Image: 1004.npy TIME REMAINING: 572.26 seconds
# Progress: 12.38% Cur Image: 1009.npy TIME REMAINING: 527.14 seconds
# Progress: 12.44% Cur Image: 1014.npy TIME REMAINING: 575.54 seconds
# Progress: 12.50% Cur Image: 1019.npy TIME REMAINING: 592.94 seconds
# Progress: 12.56% Cur Image: 1024.npy TIME REMAINING: 540.01 seconds
# Progress: 12.62% Cur Image: 1029.npy TIME REMAINING: 589.33 seconds
# Progress: 12.68% Cur Image: 1034.npy TIME REMAINING: 532.94 seconds
# Progress: 12.74% Cur Image: 1039.npy TIME REMAINING: 559.72 seconds
# Progress: 12.80% Cur Image: 1044.npy TIME REMAINING: 579.61 seconds
# Progress: 12.87% Cur Image: 1049.npy TIME REMAINING: 631.70 seconds
# Progress: 12.93% Cur Image: 1054.npy TIME REMAINING: 680.05 seconds
# Progress: 12.99% Cur Image: 1059.npy TIME REMAINING: 596.35 seconds
# Progress: 13.05% Cur Image: 1064.npy TIME REMAINING: 696.40 seconds
# Progress: 13.11% Cur Image: 1069.npy TIME REMAINING: 591.74 seconds
# Progress: 13.17% Cur Image: 1074.npy TIME REMAINING: 593.01 seconds
# Progress: 13.23% Cur Image: 1079.npy TIME REMAINING: 530.29 seconds
# Progress: 13.29% Cur Image: 1084.npy TIME REMAINING: 563.12 seconds
# Progress: 13.36% Cur Image: 1089.npy TIME REMAINING: 556.05 seconds
# Progress: 13.42% Cur Image: 1094.npy TIME REMAINING: 623.97 seconds
# Progress: 13.48% Cur Image: 1099.npy TIME REMAINING: 579.22 seconds
# Progress: 13.54% Cur Image: 1104.npy TIME REMAINING: 561.45 seconds
# Progress: 13.60% Cur Image: 1109.npy TIME REMAINING: 597.52 seconds
# Progress: 13.66% Cur Image: 1114.npy TIME REMAINING: 582.07 seconds
# Progress: 13.72% Cur Image: 1119.npy TIME REMAINING: 601.32 seconds
# Progress: 13.79% Cur Image: 1124.npy TIME REMAINING: 589.95 seconds
# Progress: 13.85% Cur Image: 1129.npy TIME REMAINING: 538.10 seconds
# Progress: 13.91% Cur Image: 1134.npy TIME REMAINING: 602.51 seconds
# Progress: 13.97% Cur Image: 1139.npy TIME REMAINING: 627.95 seconds
# Progress: 14.03% Cur Image: 1144.npy TIME REMAINING: 584.24 seconds
# Progress: 14.09% Cur Image: 1149.npy TIME REMAINING: 612.09 seconds
# Progress: 14.15% Cur Image: 1154.npy TIME REMAINING: 602.87 seconds
# Progress: 14.21% Cur Image: 1159.npy TIME REMAINING: 614.21 seconds
# Progress: 14.28% Cur Image: 1164.npy TIME REMAINING: 612.01 seconds
# Progress: 14.34% Cur Image: 1169.npy TIME REMAINING: 606.60 seconds
# Progress: 14.40% Cur Image: 1174.npy TIME REMAINING: 609.39 seconds
# Progress: 14.46% Cur Image: 1179.npy TIME REMAINING: 581.95 seconds
# Progress: 14.52% Cur Image: 1184.npy TIME REMAINING: 604.02 seconds
# Progress: 14.58% Cur Image: 1189.npy TIME REMAINING: 645.90 seconds
# Progress: 14.64% Cur Image: 1194.npy TIME REMAINING: 608.63 seconds
# Progress: 14.70% Cur Image: 1199.npy TIME REMAINING: 635.58 seconds
# Progress: 14.77% Cur Image: 1204.npy TIME REMAINING: 637.64 seconds
# Progress: 14.83% Cur Image: 1209.npy TIME REMAINING: 608.25 seconds
# Progress: 14.89% Cur Image: 1214.npy TIME REMAINING: 649.39 seconds
# Progress: 14.95% Cur Image: 1219.npy TIME REMAINING: 603.58 seconds
# Progress: 15.01% Cur Image: 1224.npy TIME REMAINING: 632.43 seconds
# Progress: 15.07% Cur Image: 1229.npy TIME REMAINING: 633.38 seconds
# Progress: 15.13% Cur Image: 1234.npy TIME REMAINING: 629.97 seconds
# Progress: 15.19% Cur Image: 1239.npy TIME REMAINING: 643.20 seconds
# Progress: 15.26% Cur Image: 1244.npy TIME REMAINING: 659.00 seconds
# Progress: 15.32% Cur Image: 1249.npy TIME REMAINING: 612.67 seconds
# Progress: 15.38% Cur Image: 1254.npy TIME REMAINING: 681.91 seconds
# Progress: 15.44% Cur Image: 1259.npy TIME REMAINING: 615.76 seconds
# Progress: 15.50% Cur Image: 1264.npy TIME REMAINING: 652.46 seconds
# Progress: 15.56% Cur Image: 1269.npy TIME REMAINING: 671.08 seconds
# Progress: 15.62% Cur Image: 1274.npy TIME REMAINING: 609.64 seconds
# Progress: 15.68% Cur Image: 1279.npy TIME REMAINING: 638.75 seconds
# Progress: 15.75% Cur Image: 1284.npy TIME REMAINING: 649.99 seconds
# Progress: 15.81% Cur Image: 1289.npy TIME REMAINING: 630.39 seconds
# Progress: 15.87% Cur Image: 1294.npy TIME REMAINING: 635.08 seconds
# Progress: 15.93% Cur Image: 1299.npy TIME REMAINING: 657.19 seconds
# Progress: 15.99% Cur Image: 1304.npy TIME REMAINING: 655.52 seconds
# Progress: 16.05% Cur Image: 1309.npy TIME REMAINING: 645.88 seconds
# Progress: 16.11% Cur Image: 1314.npy TIME REMAINING: 653.50 seconds
# Progress: 16.17% Cur Image: 1319.npy TIME REMAINING: 662.26 seconds
# Progress: 16.24% Cur Image: 1324.npy TIME REMAINING: 643.74 seconds
# Progress: 16.30% Cur Image: 1329.npy TIME REMAINING: 675.22 seconds
# Progress: 16.36% Cur Image: 1334.npy TIME REMAINING: 642.92 seconds
# Progress: 16.42% Cur Image: 1339.npy TIME REMAINING: 667.71 seconds
# Progress: 16.48% Cur Image: 1344.npy TIME REMAINING: 684.11 seconds
# Progress: 16.54% Cur Image: 1349.npy TIME REMAINING: 650.39 seconds
# Progress: 16.60% Cur Image: 1354.npy TIME REMAINING: 712.99 seconds
# Progress: 16.66% Cur Image: 1359.npy TIME REMAINING: 673.66 seconds
# Progress: 16.73% Cur Image: 1364.npy TIME REMAINING: 645.98 seconds
# Progress: 16.79% Cur Image: 1369.npy TIME REMAINING: 659.54 seconds
# Progress: 16.85% Cur Image: 1374.npy TIME REMAINING: 672.86 seconds
# Progress: 16.91% Cur Image: 1379.npy TIME REMAINING: 646.10 seconds
# Progress: 16.97% Cur Image: 1384.npy TIME REMAINING: 706.47 seconds
# Progress: 17.03% Cur Image: 1389.npy TIME REMAINING: 741.63 seconds
# Progress: 17.09% Cur Image: 1394.npy TIME REMAINING: 701.94 seconds
# Progress: 17.15% Cur Image: 1399.npy TIME REMAINING: 719.30 seconds
# Progress: 17.22% Cur Image: 1404.npy TIME REMAINING: 682.64 seconds
# Progress: 17.28% Cur Image: 1409.npy TIME REMAINING: 713.38 seconds
# Progress: 17.34% Cur Image: 1414.npy TIME REMAINING: 704.70 seconds
# Progress: 17.40% Cur Image: 1419.npy TIME REMAINING: 782.89 seconds
# Progress: 17.46% Cur Image: 1424.npy TIME REMAINING: 805.74 seconds
# Progress: 17.52% Cur Image: 1429.npy TIME REMAINING: 716.78 seconds
# Progress: 17.58% Cur Image: 1434.npy TIME REMAINING: 771.62 seconds
# Progress: 17.64% Cur Image: 1439.npy TIME REMAINING: 757.58 seconds
# Progress: 17.71% Cur Image: 1444.npy TIME REMAINING: 719.36 seconds
# Progress: 17.77% Cur Image: 1449.npy TIME REMAINING: 758.37 seconds
# Progress: 17.83% Cur Image: 1454.npy TIME REMAINING: 812.26 seconds
# Progress: 17.89% Cur Image: 1459.npy TIME REMAINING: 761.91 seconds
# Progress: 17.95% Cur Image: 1464.npy TIME REMAINING: 786.18 seconds
# Progress: 18.01% Cur Image: 1469.npy TIME REMAINING: 758.90 seconds
# Progress: 18.07% Cur Image: 1474.npy TIME REMAINING: 748.07 seconds
# Progress: 18.14% Cur Image: 1479.npy TIME REMAINING: 788.70 seconds
# Progress: 18.20% Cur Image: 1484.npy TIME REMAINING: 745.56 seconds
# Progress: 18.26% Cur Image: 1489.npy TIME REMAINING: 724.09 seconds
# Progress: 18.32% Cur Image: 1494.npy TIME REMAINING: 913.28 seconds
# Progress: 18.38% Cur Image: 1499.npy TIME REMAINING: 772.78 seconds
# Progress: 18.44% Cur Image: 1504.npy TIME REMAINING: 772.38 seconds
# Progress: 18.50% Cur Image: 1509.npy TIME REMAINING: 793.49 seconds
# Progress: 18.56% Cur Image: 1514.npy TIME REMAINING: 737.44 seconds
# Progress: 18.63% Cur Image: 1519.npy TIME REMAINING: 785.88 seconds
# Progress: 18.69% Cur Image: 1524.npy TIME REMAINING: 770.30 seconds
# Progress: 18.75% Cur Image: 1529.npy TIME REMAINING: 780.70 seconds
# Progress: 18.81% Cur Image: 1534.npy TIME REMAINING: 782.73 seconds
# Progress: 18.87% Cur Image: 1539.npy TIME REMAINING: 738.35 seconds
# Progress: 18.93% Cur Image: 1544.npy TIME REMAINING: 893.12 seconds
# Progress: 18.99% Cur Image: 1549.npy TIME REMAINING: 768.65 seconds
# Progress: 19.05% Cur Image: 1554.npy TIME REMAINING: 844.78 seconds
# Progress: 19.12% Cur Image: 1559.npy TIME REMAINING: 819.15 seconds
# Progress: 19.18% Cur Image: 1564.npy TIME REMAINING: 806.32 seconds
# Progress: 19.24% Cur Image: 1569.npy TIME REMAINING: 837.77 seconds
# Progress: 19.30% Cur Image: 1574.npy TIME REMAINING: 785.31 seconds
# Progress: 19.36% Cur Image: 1579.npy TIME REMAINING: 794.56 seconds
# Progress: 19.42% Cur Image: 1584.npy TIME REMAINING: 823.31 seconds
# Progress: 19.48% Cur Image: 1589.npy TIME REMAINING: 822.90 seconds
# Progress: 19.54% Cur Image: 1594.npy TIME REMAINING: 833.14 seconds
# Progress: 19.61% Cur Image: 1599.npy TIME REMAINING: 830.40 seconds
# Progress: 19.67% Cur Image: 1604.npy TIME REMAINING: 829.95 seconds
# Progress: 19.73% Cur Image: 1609.npy TIME REMAINING: 800.94 seconds
# Progress: 19.79% Cur Image: 1614.npy TIME REMAINING: 786.21 seconds
# Progress: 19.85% Cur Image: 1619.npy TIME REMAINING: 692.75 seconds
# Progress: 19.91% Cur Image: 1624.npy TIME REMAINING: 725.45 seconds
# Progress: 19.97% Cur Image: 1629.npy TIME REMAINING: 744.28 seconds
# Progress: 20.03% Cur Image: 1634.npy TIME REMAINING: 711.45 seconds
# Progress: 20.10% Cur Image: 1639.npy TIME REMAINING: 821.82 seconds
# Progress: 20.16% Cur Image: 1644.npy TIME REMAINING: 746.47 seconds
# Progress: 20.22% Cur Image: 1649.npy TIME REMAINING: 726.01 seconds
# Progress: 20.28% Cur Image: 1654.npy TIME REMAINING: 760.47 seconds
# Progress: 20.34% Cur Image: 1659.npy TIME REMAINING: 699.91 seconds
# Progress: 20.40% Cur Image: 1664.npy TIME REMAINING: 682.48 seconds
# Progress: 20.46% Cur Image: 1669.npy TIME REMAINING: 752.21 seconds
# Progress: 20.52% Cur Image: 1674.npy TIME REMAINING: 721.76 seconds
# Progress: 20.59% Cur Image: 1679.npy TIME REMAINING: 703.24 seconds
# Progress: 20.65% Cur Image: 1684.npy TIME REMAINING: 709.98 seconds
# Progress: 20.71% Cur Image: 1689.npy TIME REMAINING: 738.00 seconds
# Progress: 20.77% Cur Image: 1694.npy TIME REMAINING: 771.13 seconds
# Progress: 20.83% Cur Image: 1699.npy TIME REMAINING: 740.29 seconds
# Progress: 20.89% Cur Image: 1704.npy TIME REMAINING: 728.85 seconds
# Progress: 20.95% Cur Image: 1709.npy TIME REMAINING: 759.76 seconds
# Progress: 21.01% Cur Image: 1714.npy TIME REMAINING: 721.16 seconds
# Progress: 21.08% Cur Image: 1719.npy TIME REMAINING: 751.93 seconds
# Progress: 21.14% Cur Image: 1724.npy TIME REMAINING: 729.04 seconds
# Progress: 21.20% Cur Image: 1729.npy TIME REMAINING: 726.62 seconds
# Progress: 21.26% Cur Image: 1734.npy TIME REMAINING: 729.29 seconds
# Progress: 21.32% Cur Image: 1739.npy TIME REMAINING: 753.31 seconds
# Progress: 21.38% Cur Image: 1744.npy TIME REMAINING: 743.89 seconds
# Progress: 21.44% Cur Image: 1749.npy TIME REMAINING: 738.21 seconds
# Progress: 21.50% Cur Image: 1754.npy TIME REMAINING: 762.63 seconds
# Progress: 21.57% Cur Image: 1759.npy TIME REMAINING: 771.49 seconds
# Progress: 21.63% Cur Image: 1764.npy TIME REMAINING: 733.07 seconds
# Progress: 21.69% Cur Image: 1769.npy TIME REMAINING: 759.39 seconds
# Progress: 21.75% Cur Image: 1774.npy TIME REMAINING: 717.38 seconds
# Progress: 21.81% Cur Image: 1779.npy TIME REMAINING: 724.69 seconds
# Progress: 21.87% Cur Image: 1784.npy TIME REMAINING: 719.09 seconds
# Progress: 21.93% Cur Image: 1789.npy TIME REMAINING: 721.73 seconds
# Progress: 21.99% Cur Image: 1794.npy TIME REMAINING: 746.40 seconds
# Progress: 22.06% Cur Image: 1799.npy TIME REMAINING: 736.21 seconds
# Progress: 22.12% Cur Image: 1804.npy TIME REMAINING: 759.54 seconds
# Progress: 22.18% Cur Image: 1809.npy TIME REMAINING: 752.93 seconds
# Progress: 22.24% Cur Image: 1814.npy TIME REMAINING: 775.81 seconds
# Progress: 22.30% Cur Image: 1819.npy TIME REMAINING: 780.29 seconds
# Progress: 22.36% Cur Image: 1824.npy TIME REMAINING: 743.19 seconds
# Progress: 22.42% Cur Image: 1829.npy TIME REMAINING: 739.45 seconds
# Progress: 22.48% Cur Image: 1834.npy TIME REMAINING: 765.10 seconds
# Progress: 22.55% Cur Image: 1839.npy TIME REMAINING: 752.76 seconds
# Progress: 22.61% Cur Image: 1844.npy TIME REMAINING: 756.85 seconds
# Progress: 22.67% Cur Image: 1849.npy TIME REMAINING: 785.67 seconds
# Progress: 22.73% Cur Image: 1854.npy TIME REMAINING: 801.78 seconds
# Progress: 22.79% Cur Image: 1859.npy TIME REMAINING: 771.63 seconds
# Progress: 22.85% Cur Image: 1864.npy TIME REMAINING: 771.37 seconds
# Progress: 22.91% Cur Image: 1869.npy TIME REMAINING: 776.71 seconds
# Progress: 22.98% Cur Image: 1874.npy TIME REMAINING: 761.25 seconds
# Progress: 23.04% Cur Image: 1879.npy TIME REMAINING: 786.94 seconds
# Progress: 23.10% Cur Image: 1884.npy TIME REMAINING: 782.03 seconds
# Progress: 23.16% Cur Image: 1889.npy TIME REMAINING: 788.77 seconds
# Progress: 23.22% Cur Image: 1894.npy TIME REMAINING: 794.34 seconds
# Progress: 23.28% Cur Image: 1899.npy TIME REMAINING: 773.32 seconds
# Progress: 23.34% Cur Image: 1904.npy TIME REMAINING: 806.40 seconds
# Progress: 23.40% Cur Image: 1909.npy TIME REMAINING: 778.57 seconds
# Progress: 23.47% Cur Image: 1914.npy TIME REMAINING: 799.81 seconds
# Progress: 23.53% Cur Image: 1919.npy TIME REMAINING: 1099.33 seconds
# Progress: 23.59% Cur Image: 1924.npy TIME REMAINING: 1090.02 seconds
# Progress: 23.65% Cur Image: 1929.npy TIME REMAINING: 1013.83 seconds
# Progress: 23.71% Cur Image: 1934.npy TIME REMAINING: 1042.45 seconds
# Progress: 23.77% Cur Image: 1939.npy TIME REMAINING: 813.69 seconds
# Progress: 23.83% Cur Image: 1944.npy TIME REMAINING: 820.34 seconds
# Progress: 23.89% Cur Image: 1949.npy TIME REMAINING: 772.81 seconds
# Progress: 23.96% Cur Image: 1954.npy TIME REMAINING: 823.22 seconds
# Progress: 24.02% Cur Image: 1959.npy TIME REMAINING: 784.86 seconds
# Progress: 24.08% Cur Image: 1964.npy TIME REMAINING: 797.38 seconds
# Progress: 24.14% Cur Image: 1969.npy TIME REMAINING: 794.86 seconds
# Progress: 24.20% Cur Image: 1974.npy TIME REMAINING: 808.31 seconds
# Progress: 24.26% Cur Image: 1979.npy TIME REMAINING: 809.15 seconds
# Progress: 24.32% Cur Image: 1984.npy TIME REMAINING: 770.04 seconds
# Progress: 24.38% Cur Image: 1989.npy TIME REMAINING: 795.67 seconds
# Progress: 24.45% Cur Image: 1994.npy TIME REMAINING: 796.39 seconds
# Progress: 24.51% Cur Image: 1999.npy TIME REMAINING: 786.50 seconds
# Progress: 24.57% Cur Image: 2004.npy TIME REMAINING: 815.03 seconds
# Progress: 24.63% Cur Image: 2009.npy TIME REMAINING: 803.78 seconds
# Progress: 24.69% Cur Image: 2014.npy TIME REMAINING: 787.35 seconds
# Progress: 24.75% Cur Image: 2019.npy TIME REMAINING: 882.04 seconds
# Progress: 24.81% Cur Image: 2024.npy TIME REMAINING: 782.71 seconds
# Progress: 24.87% Cur Image: 2029.npy TIME REMAINING: 802.43 seconds
# Progress: 24.94% Cur Image: 2034.npy TIME REMAINING: 857.54 seconds
# Progress: 25.00% Cur Image: 2039.npy TIME REMAINING: 807.61 seconds
# Progress: 25.06% Cur Image: 2044.npy TIME REMAINING: 820.88 seconds
# Progress: 25.12% Cur Image: 2049.npy TIME REMAINING: 817.99 seconds
# Progress: 25.18% Cur Image: 2054.npy TIME REMAINING: 847.99 seconds
# Progress: 25.24% Cur Image: 2059.npy TIME REMAINING: 784.08 seconds
# Progress: 25.30% Cur Image: 2064.npy TIME REMAINING: 823.10 seconds
# Progress: 25.36% Cur Image: 2069.npy TIME REMAINING: 805.40 seconds
# Progress: 25.43% Cur Image: 2074.npy TIME REMAINING: 811.91 seconds
# Progress: 25.49% Cur Image: 2079.npy TIME REMAINING: 829.63 seconds
# Progress: 25.55% Cur Image: 2084.npy TIME REMAINING: 835.94 seconds
# Progress: 25.61% Cur Image: 2089.npy TIME REMAINING: 797.29 seconds
# Progress: 25.67% Cur Image: 2094.npy TIME REMAINING: 798.43 seconds
# Progress: 25.73% Cur Image: 2099.npy TIME REMAINING: 829.26 seconds
# Progress: 25.79% Cur Image: 2104.npy TIME REMAINING: 815.67 seconds
# Progress: 25.85% Cur Image: 2109.npy TIME REMAINING: 825.82 seconds
# Progress: 25.92% Cur Image: 2114.npy TIME REMAINING: 885.00 seconds
# Progress: 25.98% Cur Image: 2119.npy TIME REMAINING: 803.25 seconds
# Progress: 26.04% Cur Image: 2124.npy TIME REMAINING: 804.81 seconds
# Progress: 26.10% Cur Image: 2129.npy TIME REMAINING: 791.97 seconds
# Progress: 26.16% Cur Image: 2134.npy TIME REMAINING: 791.50 seconds
# Progress: 26.22% Cur Image: 2139.npy TIME REMAINING: 791.35 seconds
# Progress: 26.28% Cur Image: 2144.npy TIME REMAINING: 818.39 seconds
# Progress: 26.34% Cur Image: 2149.npy TIME REMAINING: 781.17 seconds
# Progress: 26.41% Cur Image: 2154.npy TIME REMAINING: 869.39 seconds
# Progress: 26.47% Cur Image: 2159.npy TIME REMAINING: 819.10 seconds
# Progress: 26.53% Cur Image: 2164.npy TIME REMAINING: 807.80 seconds
# Progress: 26.59% Cur Image: 2169.npy TIME REMAINING: 825.04 seconds
# Progress: 26.65% Cur Image: 2174.npy TIME REMAINING: 823.07 seconds
# Progress: 26.71% Cur Image: 2179.npy TIME REMAINING: 814.98 seconds
# Progress: 26.77% Cur Image: 2184.npy TIME REMAINING: 856.30 seconds
# Progress: 26.83% Cur Image: 2189.npy TIME REMAINING: 816.06 seconds
# Progress: 26.90% Cur Image: 2194.npy TIME REMAINING: 813.45 seconds
# Progress: 26.96% Cur Image: 2199.npy TIME REMAINING: 840.46 seconds
# Progress: 27.02% Cur Image: 2204.npy TIME REMAINING: 838.23 seconds
# Progress: 27.08% Cur Image: 2209.npy TIME REMAINING: 843.42 seconds
# Progress: 27.14% Cur Image: 2214.npy TIME REMAINING: 808.10 seconds
# Progress: 27.20% Cur Image: 2219.npy TIME REMAINING: 847.28 seconds
# Progress: 27.26% Cur Image: 2224.npy TIME REMAINING: 830.64 seconds
# Progress: 27.33% Cur Image: 2229.npy TIME REMAINING: 838.38 seconds
# Progress: 27.39% Cur Image: 2234.npy TIME REMAINING: 812.66 seconds
# Progress: 27.45% Cur Image: 2239.npy TIME REMAINING: 835.04 seconds
# Progress: 27.51% Cur Image: 2244.npy TIME REMAINING: 838.57 seconds
# Progress: 27.57% Cur Image: 2249.npy TIME REMAINING: 819.66 seconds
# Progress: 27.63% Cur Image: 2254.npy TIME REMAINING: 873.49 seconds
# Progress: 27.69% Cur Image: 2259.npy TIME REMAINING: 869.88 seconds
# Progress: 27.75% Cur Image: 2264.npy TIME REMAINING: 863.33 seconds
# Progress: 27.82% Cur Image: 2269.npy TIME REMAINING: 818.13 seconds
# Progress: 27.88% Cur Image: 2274.npy TIME REMAINING: 815.95 seconds
# Progress: 27.94% Cur Image: 2279.npy TIME REMAINING: 855.85 seconds
# Progress: 28.00% Cur Image: 2284.npy TIME REMAINING: 833.03 seconds
# Progress: 28.06% Cur Image: 2289.npy TIME REMAINING: 872.57 seconds
# Progress: 28.12% Cur Image: 2294.npy TIME REMAINING: 877.90 seconds
# Progress: 28.18% Cur Image: 2299.npy TIME REMAINING: 841.68 seconds
# Progress: 28.24% Cur Image: 2304.npy TIME REMAINING: 870.46 seconds
# Progress: 28.31% Cur Image: 2309.npy TIME REMAINING: 831.05 seconds
# Progress: 28.37% Cur Image: 2314.npy TIME REMAINING: 844.07 seconds
# Progress: 28.43% Cur Image: 2319.npy TIME REMAINING: 870.87 seconds
# Progress: 28.49% Cur Image: 2324.npy TIME REMAINING: 840.75 seconds
# Progress: 28.55% Cur Image: 2329.npy TIME REMAINING: 852.83 seconds
# Progress: 28.61% Cur Image: 2334.npy TIME REMAINING: 893.66 seconds
# Progress: 28.67% Cur Image: 2339.npy TIME REMAINING: 901.18 seconds
# Progress: 28.73% Cur Image: 2344.npy TIME REMAINING: 891.23 seconds
# Progress: 28.80% Cur Image: 2349.npy TIME REMAINING: 875.64 seconds
# Progress: 28.86% Cur Image: 2354.npy TIME REMAINING: 937.34 seconds
# Progress: 28.92% Cur Image: 2359.npy TIME REMAINING: 886.55 seconds
# Progress: 28.98% Cur Image: 2364.npy TIME REMAINING: 902.39 seconds
# Progress: 29.04% Cur Image: 2369.npy TIME REMAINING: 879.28 seconds
# Progress: 29.10% Cur Image: 2374.npy TIME REMAINING: 880.80 seconds
# Progress: 29.16% Cur Image: 2379.npy TIME REMAINING: 888.81 seconds
# Progress: 29.22% Cur Image: 2384.npy TIME REMAINING: 841.30 seconds
# Progress: 29.29% Cur Image: 2389.npy TIME REMAINING: 878.53 seconds
# Progress: 29.35% Cur Image: 2394.npy TIME REMAINING: 887.55 seconds
# Progress: 29.41% Cur Image: 2399.npy TIME REMAINING: 871.43 seconds
# Progress: 29.47% Cur Image: 2404.npy TIME REMAINING: 847.67 seconds
# Progress: 29.53% Cur Image: 2409.npy TIME REMAINING: 855.87 seconds
# Progress: 29.59% Cur Image: 2414.npy TIME REMAINING: 900.62 seconds
# Progress: 29.65% Cur Image: 2419.npy TIME REMAINING: 882.47 seconds
# Progress: 29.71% Cur Image: 2424.npy TIME REMAINING: 862.85 seconds
# Progress: 29.78% Cur Image: 2429.npy TIME REMAINING: 844.22 seconds
# Progress: 29.84% Cur Image: 2434.npy TIME REMAINING: 877.70 seconds
# Progress: 29.90% Cur Image: 2439.npy TIME REMAINING: 892.51 seconds
# Progress: 29.96% Cur Image: 2444.npy TIME REMAINING: 879.77 seconds
# Progress: 30.02% Cur Image: 2449.npy TIME REMAINING: 908.27 seconds
# Progress: 30.08% Cur Image: 2454.npy TIME REMAINING: 949.03 seconds
# Progress: 30.14% Cur Image: 2459.npy TIME REMAINING: 898.22 seconds
# Progress: 30.20% Cur Image: 2464.npy TIME REMAINING: 929.93 seconds
# Progress: 30.27% Cur Image: 2469.npy TIME REMAINING: 877.89 seconds
# Progress: 30.33% Cur Image: 2474.npy TIME REMAINING: 893.67 seconds
# Progress: 30.39% Cur Image: 2479.npy TIME REMAINING: 883.12 seconds
# Progress: 30.45% Cur Image: 2484.npy TIME REMAINING: 896.74 seconds
# Progress: 30.51% Cur Image: 2489.npy TIME REMAINING: 907.74 seconds
# Progress: 30.57% Cur Image: 2494.npy TIME REMAINING: 920.89 seconds
# Progress: 30.63% Cur Image: 2499.npy TIME REMAINING: 918.89 seconds
# Progress: 30.69% Cur Image: 2504.npy TIME REMAINING: 908.10 seconds
# Progress: 30.76% Cur Image: 2509.npy TIME REMAINING: 918.90 seconds
# Progress: 30.82% Cur Image: 2514.npy TIME REMAINING: 905.61 seconds
# Progress: 30.88% Cur Image: 2519.npy TIME REMAINING: 926.90 seconds
# Progress: 30.94% Cur Image: 2524.npy TIME REMAINING: 984.97 seconds
# Progress: 31.00% Cur Image: 2529.npy TIME REMAINING: 937.47 seconds
# Progress: 31.06% Cur Image: 2534.npy TIME REMAINING: 888.10 seconds
# Progress: 31.12% Cur Image: 2539.npy TIME REMAINING: 922.65 seconds
# Progress: 31.18% Cur Image: 2544.npy TIME REMAINING: 909.91 seconds
# Progress: 31.25% Cur Image: 2549.npy TIME REMAINING: 947.56 seconds
# Progress: 31.31% Cur Image: 2554.npy TIME REMAINING: 907.37 seconds
# Progress: 31.37% Cur Image: 2559.npy TIME REMAINING: 920.78 seconds
# Progress: 31.43% Cur Image: 2564.npy TIME REMAINING: 924.18 seconds
# Progress: 31.49% Cur Image: 2569.npy TIME REMAINING: 923.83 seconds
# Progress: 31.55% Cur Image: 2574.npy TIME REMAINING: 892.24 seconds
# Progress: 31.61% Cur Image: 2579.npy TIME REMAINING: 926.88 seconds
# Progress: 31.68% Cur Image: 2584.npy TIME REMAINING: 931.45 seconds
# Progress: 31.74% Cur Image: 2589.npy TIME REMAINING: 889.55 seconds
# Progress: 31.80% Cur Image: 2594.npy TIME REMAINING: 903.96 seconds
# Progress: 31.86% Cur Image: 2599.npy TIME REMAINING: 916.02 seconds
# Progress: 31.92% Cur Image: 2604.npy TIME REMAINING: 928.42 seconds
# Progress: 31.98% Cur Image: 2609.npy TIME REMAINING: 903.53 seconds
# Progress: 32.04% Cur Image: 2614.npy TIME REMAINING: 890.49 seconds
# Progress: 32.10% Cur Image: 2619.npy TIME REMAINING: 890.22 seconds
# Progress: 32.17% Cur Image: 2624.npy TIME REMAINING: 895.17 seconds
# Progress: 32.23% Cur Image: 2629.npy TIME REMAINING: 913.25 seconds
# Progress: 32.29% Cur Image: 2634.npy TIME REMAINING: 894.74 seconds
# Progress: 32.35% Cur Image: 2639.npy TIME REMAINING: 880.23 seconds
# Progress: 32.41% Cur Image: 2644.npy TIME REMAINING: 905.93 seconds
# Progress: 32.47% Cur Image: 2649.npy TIME REMAINING: 943.52 seconds
# Progress: 32.53% Cur Image: 2654.npy TIME REMAINING: 928.60 seconds
# Progress: 32.59% Cur Image: 2659.npy TIME REMAINING: 902.51 seconds
# Progress: 32.66% Cur Image: 2664.npy TIME REMAINING: 901.65 seconds
# Progress: 32.72% Cur Image: 2669.npy TIME REMAINING: 912.41 seconds
# Progress: 32.78% Cur Image: 2674.npy TIME REMAINING: 910.93 seconds
# Progress: 32.84% Cur Image: 2679.npy TIME REMAINING: 898.79 seconds
# Progress: 32.90% Cur Image: 2684.npy TIME REMAINING: 907.92 seconds
# Progress: 32.96% Cur Image: 2689.npy TIME REMAINING: 899.04 seconds
# Progress: 33.02% Cur Image: 2694.npy TIME REMAINING: 903.54 seconds
# Progress: 33.08% Cur Image: 2699.npy TIME REMAINING: 893.10 seconds
# Progress: 33.15% Cur Image: 2704.npy TIME REMAINING: 931.67 seconds
# Progress: 33.21% Cur Image: 2709.npy TIME REMAINING: 927.86 seconds
# Progress: 33.27% Cur Image: 2714.npy TIME REMAINING: 937.69 seconds
# Progress: 33.33% Cur Image: 2719.npy TIME REMAINING: 926.85 seconds
# Progress: 33.39% Cur Image: 2724.npy TIME REMAINING: 1106.54 seconds
# Progress: 33.45% Cur Image: 2729.npy TIME REMAINING: 1194.45 seconds
# Progress: 33.51% Cur Image: 2734.npy TIME REMAINING: 1195.12 seconds
# Progress: 33.57% Cur Image: 2739.npy TIME REMAINING: 1054.38 seconds
# Progress: 33.64% Cur Image: 2744.npy TIME REMAINING: 931.51 seconds
# Progress: 33.70% Cur Image: 2749.npy TIME REMAINING: 934.51 seconds
# Progress: 33.76% Cur Image: 2754.npy TIME REMAINING: 921.98 seconds
# Progress: 33.82% Cur Image: 2759.npy TIME REMAINING: 898.35 seconds
# Progress: 33.88% Cur Image: 2764.npy TIME REMAINING: 903.29 seconds
# Progress: 33.94% Cur Image: 2769.npy TIME REMAINING: 908.67 seconds
# Progress: 34.00% Cur Image: 2774.npy TIME REMAINING: 918.07 seconds
# Progress: 34.06% Cur Image: 2779.npy TIME REMAINING: 917.67 seconds
# Progress: 34.13% Cur Image: 2784.npy TIME REMAINING: 934.49 seconds
# Progress: 34.19% Cur Image: 2789.npy TIME REMAINING: 902.43 seconds
# Progress: 34.25% Cur Image: 2794.npy TIME REMAINING: 918.82 seconds
# Progress: 34.31% Cur Image: 2799.npy TIME REMAINING: 934.96 seconds
# Progress: 34.37% Cur Image: 2804.npy TIME REMAINING: 920.32 seconds
# Progress: 34.43% Cur Image: 2809.npy TIME REMAINING: 898.84 seconds
# Progress: 34.49% Cur Image: 2814.npy TIME REMAINING: 942.49 seconds
# Progress: 34.55% Cur Image: 2819.npy TIME REMAINING: 942.04 seconds
# Progress: 34.62% Cur Image: 2824.npy TIME REMAINING: 941.62 seconds
# Progress: 34.68% Cur Image: 2829.npy TIME REMAINING: 919.18 seconds
# Progress: 34.74% Cur Image: 2834.npy TIME REMAINING: 934.74 seconds
# Progress: 34.80% Cur Image: 2839.npy TIME REMAINING: 962.97 seconds
# Progress: 34.86% Cur Image: 2844.npy TIME REMAINING: 974.96 seconds
# Progress: 34.92% Cur Image: 2849.npy TIME REMAINING: 962.81 seconds
# Progress: 34.98% Cur Image: 2854.npy TIME REMAINING: 934.60 seconds
# Progress: 35.04% Cur Image: 2859.npy TIME REMAINING: 924.81 seconds
# Progress: 35.11% Cur Image: 2864.npy TIME REMAINING: 927.77 seconds
# Progress: 35.17% Cur Image: 2869.npy TIME REMAINING: 933.46 seconds
# Progress: 35.23% Cur Image: 2874.npy TIME REMAINING: 978.20 seconds
# Progress: 35.29% Cur Image: 2879.npy TIME REMAINING: 888.42 seconds
# Progress: 35.35% Cur Image: 2884.npy TIME REMAINING: 877.31 seconds
# Progress: 35.41% Cur Image: 2889.npy TIME REMAINING: 884.22 seconds
# Progress: 35.47% Cur Image: 2894.npy TIME REMAINING: 912.67 seconds
# Progress: 35.53% Cur Image: 2899.npy TIME REMAINING: 892.99 seconds
# Progress: 35.60% Cur Image: 2904.npy TIME REMAINING: 898.29 seconds
# Progress: 35.66% Cur Image: 2909.npy TIME REMAINING: 908.00 seconds
# Progress: 35.72% Cur Image: 2914.npy TIME REMAINING: 895.93 seconds
# Progress: 35.78% Cur Image: 2919.npy TIME REMAINING: 902.20 seconds
# Progress: 35.84% Cur Image: 2924.npy TIME REMAINING: 904.50 seconds
# Progress: 35.90% Cur Image: 2929.npy TIME REMAINING: 889.31 seconds
# Progress: 35.96% Cur Image: 2934.npy TIME REMAINING: 897.33 seconds
# Progress: 36.02% Cur Image: 2939.npy TIME REMAINING: 908.23 seconds
# Progress: 36.09% Cur Image: 2944.npy TIME REMAINING: 895.78 seconds
# Progress: 36.15% Cur Image: 2949.npy TIME REMAINING: 943.53 seconds
# Progress: 36.21% Cur Image: 2954.npy TIME REMAINING: 919.56 seconds
# Progress: 36.27% Cur Image: 2959.npy TIME REMAINING: 914.05 seconds
# Progress: 36.33% Cur Image: 2964.npy TIME REMAINING: 927.51 seconds
# Progress: 36.39% Cur Image: 2969.npy TIME REMAINING: 892.31 seconds
# Progress: 36.45% Cur Image: 2974.npy TIME REMAINING: 901.36 seconds
# Progress: 36.52% Cur Image: 2979.npy TIME REMAINING: 905.83 seconds
# Progress: 36.58% Cur Image: 2984.npy TIME REMAINING: 894.53 seconds
# Progress: 36.64% Cur Image: 2989.npy TIME REMAINING: 901.21 seconds
# Progress: 36.70% Cur Image: 2994.npy TIME REMAINING: 918.10 seconds
# Progress: 36.76% Cur Image: 2999.npy TIME REMAINING: 911.13 seconds
# Progress: 36.82% Cur Image: 3004.npy TIME REMAINING: 900.11 seconds
# Progress: 36.88% Cur Image: 3009.npy TIME REMAINING: 905.36 seconds
# Progress: 36.94% Cur Image: 3014.npy TIME REMAINING: 938.83 seconds
# Progress: 37.01% Cur Image: 3019.npy TIME REMAINING: 914.62 seconds
# Progress: 37.07% Cur Image: 3024.npy TIME REMAINING: 903.41 seconds
# Progress: 37.13% Cur Image: 3029.npy TIME REMAINING: 944.56 seconds
# Progress: 37.19% Cur Image: 3034.npy TIME REMAINING: 907.73 seconds
# Progress: 37.25% Cur Image: 3039.npy TIME REMAINING: 939.32 seconds
# Progress: 37.31% Cur Image: 3044.npy TIME REMAINING: 986.45 seconds
# Progress: 37.37% Cur Image: 3049.npy TIME REMAINING: 1129.48 seconds
# Progress: 37.43% Cur Image: 3054.npy TIME REMAINING: 1038.92 seconds
# Progress: 37.50% Cur Image: 3059.npy TIME REMAINING: 1035.11 seconds
# Progress: 37.56% Cur Image: 3064.npy TIME REMAINING: 1042.66 seconds
# Progress: 37.62% Cur Image: 3069.npy TIME REMAINING: 1058.65 seconds
# Progress: 37.68% Cur Image: 3074.npy TIME REMAINING: 1011.01 seconds
# Progress: 37.74% Cur Image: 3079.npy TIME REMAINING: 1017.17 seconds
# Progress: 37.80% Cur Image: 3084.npy TIME REMAINING: 985.62 seconds
# Progress: 37.86% Cur Image: 3089.npy TIME REMAINING: 1019.88 seconds
# Progress: 37.92% Cur Image: 3094.npy TIME REMAINING: 975.65 seconds
# Progress: 37.99% Cur Image: 3099.npy TIME REMAINING: 1028.48 seconds
# Progress: 38.05% Cur Image: 3104.npy TIME REMAINING: 1009.54 seconds
# Progress: 38.11% Cur Image: 3109.npy TIME REMAINING: 1011.13 seconds
# Progress: 38.17% Cur Image: 3114.npy TIME REMAINING: 1068.82 seconds
# Progress: 38.23% Cur Image: 3119.npy TIME REMAINING: 1058.50 seconds
# Progress: 38.29% Cur Image: 3124.npy TIME REMAINING: 1066.51 seconds
# Progress: 38.35% Cur Image: 3129.npy TIME REMAINING: 1026.32 seconds
# Progress: 38.41% Cur Image: 3134.npy TIME REMAINING: 987.67 seconds
# Progress: 38.48% Cur Image: 3139.npy TIME REMAINING: 1000.99 seconds
# Progress: 38.54% Cur Image: 3144.npy TIME REMAINING: 1011.10 seconds
# Progress: 38.60% Cur Image: 3149.npy TIME REMAINING: 1082.30 seconds
# Progress: 38.66% Cur Image: 3154.npy TIME REMAINING: 1115.71 seconds
# Progress: 38.72% Cur Image: 3159.npy TIME REMAINING: 1013.46 seconds
# Progress: 38.78% Cur Image: 3164.npy TIME REMAINING: 1020.04 seconds
# Progress: 38.84% Cur Image: 3169.npy TIME REMAINING: 1018.87 seconds
# Progress: 38.90% Cur Image: 3174.npy TIME REMAINING: 1034.73 seconds
# Progress: 38.97% Cur Image: 3179.npy TIME REMAINING: 1042.73 seconds
# Progress: 39.03% Cur Image: 3184.npy TIME REMAINING: 1047.17 seconds
# Progress: 39.09% Cur Image: 3189.npy TIME REMAINING: 1123.87 seconds
# Progress: 39.15% Cur Image: 3194.npy TIME REMAINING: 1057.97 seconds
# Progress: 39.21% Cur Image: 3199.npy TIME REMAINING: 1118.21 seconds
# Progress: 39.27% Cur Image: 3204.npy TIME REMAINING: 1040.06 seconds
# Progress: 39.33% Cur Image: 3209.npy TIME REMAINING: 1017.69 seconds
# Progress: 39.39% Cur Image: 3214.npy TIME REMAINING: 1012.89 seconds
# Progress: 39.46% Cur Image: 3219.npy TIME REMAINING: 1081.04 seconds
# Progress: 39.52% Cur Image: 3224.npy TIME REMAINING: 1069.48 seconds
# Progress: 39.58% Cur Image: 3229.npy TIME REMAINING: 1103.39 seconds
# Progress: 39.64% Cur Image: 3234.npy TIME REMAINING: 1130.22 seconds
# Progress: 39.70% Cur Image: 3239.npy TIME REMAINING: 1088.06 seconds
# Progress: 39.76% Cur Image: 3244.npy TIME REMAINING: 1151.74 seconds
# Progress: 39.82% Cur Image: 3249.npy TIME REMAINING: 1141.73 seconds
# Progress: 39.88% Cur Image: 3254.npy TIME REMAINING: 1069.23 seconds
# Progress: 39.95% Cur Image: 3259.npy TIME REMAINING: 1081.01 seconds
# Progress: 40.01% Cur Image: 3264.npy TIME REMAINING: 1046.09 seconds
# Progress: 40.07% Cur Image: 3269.npy TIME REMAINING: 977.56 seconds
# Progress: 40.13% Cur Image: 3274.npy TIME REMAINING: 965.09 seconds
# Progress: 40.19% Cur Image: 3279.npy TIME REMAINING: 989.60 seconds
# Progress: 40.25% Cur Image: 3284.npy TIME REMAINING: 974.95 seconds
# Progress: 40.31% Cur Image: 3289.npy TIME REMAINING: 975.26 seconds
# Progress: 40.37% Cur Image: 3294.npy TIME REMAINING: 982.07 seconds
# Progress: 40.44% Cur Image: 3299.npy TIME REMAINING: 985.84 seconds
# Progress: 40.50% Cur Image: 3304.npy TIME REMAINING: 985.90 seconds
# Progress: 40.56% Cur Image: 3309.npy TIME REMAINING: 986.95 seconds
# Progress: 40.62% Cur Image: 3314.npy TIME REMAINING: 1012.93 seconds
# Progress: 40.68% Cur Image: 3319.npy TIME REMAINING: 980.78 seconds
# Progress: 40.74% Cur Image: 3324.npy TIME REMAINING: 984.06 seconds
# Progress: 40.80% Cur Image: 3329.npy TIME REMAINING: 985.45 seconds
# Progress: 40.87% Cur Image: 3334.npy TIME REMAINING: 978.86 seconds
# Progress: 40.93% Cur Image: 3339.npy TIME REMAINING: 1035.07 seconds
# Progress: 40.99% Cur Image: 3344.npy TIME REMAINING: 1033.20 seconds
# Progress: 41.05% Cur Image: 3349.npy TIME REMAINING: 1443.46 seconds
# Progress: 41.11% Cur Image: 3354.npy TIME REMAINING: 1829.53 seconds
# Progress: 41.17% Cur Image: 3359.npy TIME REMAINING: 1245.32 seconds
# Progress: 41.23% Cur Image: 3364.npy TIME REMAINING: 980.41 seconds
# Progress: 41.29% Cur Image: 3369.npy TIME REMAINING: 887.58 seconds
# Progress: 41.36% Cur Image: 3374.npy TIME REMAINING: 888.71 seconds
# Progress: 41.42% Cur Image: 3379.npy TIME REMAINING: 877.35 seconds
# Progress: 41.48% Cur Image: 3384.npy TIME REMAINING: 880.25 seconds
# Progress: 41.54% Cur Image: 3389.npy TIME REMAINING: 865.84 seconds
# Progress: 41.60% Cur Image: 3394.npy TIME REMAINING: 886.34 seconds
# Progress: 41.66% Cur Image: 3399.npy TIME REMAINING: 883.26 seconds
# Progress: 41.72% Cur Image: 3404.npy TIME REMAINING: 869.10 seconds
# Progress: 41.78% Cur Image: 3409.npy TIME REMAINING: 881.97 seconds
# Progress: 41.85% Cur Image: 3414.npy TIME REMAINING: 896.37 seconds
# Progress: 41.91% Cur Image: 3419.npy TIME REMAINING: 881.73 seconds
# Progress: 41.97% Cur Image: 3424.npy TIME REMAINING: 878.76 seconds
# Progress: 42.03% Cur Image: 3429.npy TIME REMAINING: 867.86 seconds
# Progress: 42.09% Cur Image: 3434.npy TIME REMAINING: 897.60 seconds
# Progress: 42.15% Cur Image: 3439.npy TIME REMAINING: 890.66 seconds
# Progress: 42.21% Cur Image: 3444.npy TIME REMAINING: 907.33 seconds
# Progress: 42.27% Cur Image: 3449.npy TIME REMAINING: 935.08 seconds
# Progress: 42.34% Cur Image: 3454.npy TIME REMAINING: 888.99 seconds
# Progress: 42.40% Cur Image: 3459.npy TIME REMAINING: 913.73 seconds
# Progress: 42.46% Cur Image: 3464.npy TIME REMAINING: 890.00 seconds
# Progress: 42.52% Cur Image: 3469.npy TIME REMAINING: 878.58 seconds
# Progress: 42.58% Cur Image: 3474.npy TIME REMAINING: 895.51 seconds
# Progress: 42.64% Cur Image: 3479.npy TIME REMAINING: 939.65 seconds
# Progress: 42.70% Cur Image: 3484.npy TIME REMAINING: 870.79 seconds
# Progress: 42.76% Cur Image: 3489.npy TIME REMAINING: 855.28 seconds
# Progress: 42.83% Cur Image: 3494.npy TIME REMAINING: 871.53 seconds
# Progress: 42.89% Cur Image: 3499.npy TIME REMAINING: 861.81 seconds
# ...
# Progress: 85.90% Cur Image: 7009.npy TIME REMAINING: 437.17 seconds
# Progress: 85.96% Cur Image: 7014.npy TIME REMAINING: 427.35 seconds
# Progress: 86.02% Cur Image: 7019.npy TIME REMAINING: 443.22 seconds
# Progress: 86.08% Cur Image: 7024.npy TIME REMAINING: 484.27 seconds
# Progress: 86.14% Cur Image: 7029.npy TIME REMAINING: 445.89 seconds
# Progress: 86.20% Cur Image: 7034.npy TIME REMAINING: 424.08 seconds
# Progress: 86.26% Cur Image: 7039.npy TIME REMAINING: 409.57 seconds
# Progress: 86.33% Cur Image: 7044.npy TIME REMAINING: 416.79 seconds
# Progress: 86.39% Cur Image: 7049.npy TIME REMAINING: 409.78 seconds
# Progress: 86.45% Cur Image: 7054.npy TIME REMAINING: 414.89 seconds
# Progress: 86.51% Cur Image: 7059.npy TIME REMAINING: 405.62 seconds
# Progress: 86.57% Cur Image: 7064.npy TIME REMAINING: 413.29 seconds
# Progress: 86.63% Cur Image: 7069.npy TIME REMAINING: 391.99 seconds
# Progress: 86.69% Cur Image: 7074.npy TIME REMAINING: 398.93 seconds
# Progress: 86.75% Cur Image: 7079.npy TIME REMAINING: 402.24 seconds
# Progress: 86.82% Cur Image: 7084.npy TIME REMAINING: 405.44 seconds
# Progress: 86.88% Cur Image: 7089.npy TIME REMAINING: 400.22 seconds
# Progress: 86.94% Cur Image: 7094.npy TIME REMAINING: 412.33 seconds
# Progress: 87.00% Cur Image: 7099.npy TIME REMAINING: 407.57 seconds
# Progress: 87.06% Cur Image: 7104.npy TIME REMAINING: 394.27 seconds
# Progress: 87.12% Cur Image: 7109.npy TIME REMAINING: 382.40 seconds
# Progress: 87.18% Cur Image: 7114.npy TIME REMAINING: 418.92 seconds
# Progress: 87.24% Cur Image: 7119.npy TIME REMAINING: 404.90 seconds
# Progress: 87.31% Cur Image: 7124.npy TIME REMAINING: 402.47 seconds
# Progress: 87.37% Cur Image: 7129.npy TIME REMAINING: 459.14 seconds
# Progress: 87.43% Cur Image: 7134.npy TIME REMAINING: 415.26 seconds
# Progress: 87.49% Cur Image: 7139.npy TIME REMAINING: 410.38 seconds
# Progress: 87.55% Cur Image: 7144.npy TIME REMAINING: 419.04 seconds
# Progress: 87.61% Cur Image: 7149.npy TIME REMAINING: 390.14 seconds
# Progress: 87.67% Cur Image: 7154.npy TIME REMAINING: 426.72 seconds
# Progress: 87.73% Cur Image: 7159.npy TIME REMAINING: 398.00 seconds
# Progress: 87.80% Cur Image: 7164.npy TIME REMAINING: 408.71 seconds
# Progress: 87.86% Cur Image: 7169.npy TIME REMAINING: 395.34 seconds
# Progress: 87.92% Cur Image: 7174.npy TIME REMAINING: 382.98 seconds
# Progress: 87.98% Cur Image: 7179.npy TIME REMAINING: 383.08 seconds
# Progress: 88.04% Cur Image: 7184.npy TIME REMAINING: 378.37 seconds
# Progress: 88.10% Cur Image: 7189.npy TIME REMAINING: 378.14 seconds
# Progress: 88.16% Cur Image: 7194.npy TIME REMAINING: 380.99 seconds
# Progress: 88.22% Cur Image: 7199.npy TIME REMAINING: 378.40 seconds
# Progress: 88.29% Cur Image: 7204.npy TIME REMAINING: 395.37 seconds
# Progress: 88.35% Cur Image: 7209.npy TIME REMAINING: 391.69 seconds
# Progress: 88.41% Cur Image: 7214.npy TIME REMAINING: 375.57 seconds
# Progress: 88.47% Cur Image: 7219.npy TIME REMAINING: 382.59 seconds
# Progress: 88.53% Cur Image: 7224.npy TIME REMAINING: 369.90 seconds
# Progress: 88.59% Cur Image: 7229.npy TIME REMAINING: 374.35 seconds
# Progress: 88.65% Cur Image: 7234.npy TIME REMAINING: 380.86 seconds
# Progress: 88.71% Cur Image: 7239.npy TIME REMAINING: 433.37 seconds
# Progress: 88.78% Cur Image: 7244.npy TIME REMAINING: 657.68 seconds
# Progress: 88.84% Cur Image: 7249.npy TIME REMAINING: 350.16 seconds
# Progress: 88.90% Cur Image: 7254.npy TIME REMAINING: 352.54 seconds
# Progress: 88.96% Cur Image: 7259.npy TIME REMAINING: 337.33 seconds
# Progress: 89.02% Cur Image: 7264.npy TIME REMAINING: 338.17 seconds
# Progress: 89.08% Cur Image: 7269.npy TIME REMAINING: 338.13 seconds
# Progress: 89.14% Cur Image: 7274.npy TIME REMAINING: 325.13 seconds
# Progress: 89.20% Cur Image: 7279.npy TIME REMAINING: 337.40 seconds
# Progress: 89.27% Cur Image: 7284.npy TIME REMAINING: 329.69 seconds
# Progress: 89.33% Cur Image: 7289.npy TIME REMAINING: 328.29 seconds
# Progress: 89.39% Cur Image: 7294.npy TIME REMAINING: 345.46 seconds
# Progress: 89.45% Cur Image: 7299.npy TIME REMAINING: 326.74 seconds
# Progress: 89.51% Cur Image: 7304.npy TIME REMAINING: 339.16 seconds
# Progress: 89.57% Cur Image: 7309.npy TIME REMAINING: 307.53 seconds
# Progress: 89.63% Cur Image: 7314.npy TIME REMAINING: 356.76 seconds
# Progress: 89.69% Cur Image: 7319.npy TIME REMAINING: 434.63 seconds
# Progress: 89.76% Cur Image: 7324.npy TIME REMAINING: 446.48 seconds
# Progress: 89.82% Cur Image: 7329.npy TIME REMAINING: 349.68 seconds
# Progress: 89.88% Cur Image: 7334.npy TIME REMAINING: 337.66 seconds
# Progress: 89.94% Cur Image: 7339.npy TIME REMAINING: 337.13 seconds
# Progress: 90.00% Cur Image: 7344.npy TIME REMAINING: 674.28 seconds
# Progress: 90.06% Cur Image: 7349.npy TIME REMAINING: 410.96 seconds
# Progress: 90.12% Cur Image: 7354.npy TIME REMAINING: 332.78 seconds
# Progress: 90.19% Cur Image: 7359.npy TIME REMAINING: 340.57 seconds
# Progress: 90.25% Cur Image: 7364.npy TIME REMAINING: 361.01 seconds
# Progress: 90.31% Cur Image: 7369.npy TIME REMAINING: 372.30 seconds
# Progress: 90.37% Cur Image: 7374.npy TIME REMAINING: 359.69 seconds
# Progress: 90.43% Cur Image: 7379.npy TIME REMAINING: 342.54 seconds
# Progress: 90.49% Cur Image: 7384.npy TIME REMAINING: 330.45 seconds
# Progress: 90.55% Cur Image: 7389.npy TIME REMAINING: 328.24 seconds
# Progress: 90.61% Cur Image: 7394.npy TIME REMAINING: 339.27 seconds
# Progress: 90.68% Cur Image: 7399.npy TIME REMAINING: 339.46 seconds
# Progress: 90.74% Cur Image: 7404.npy TIME REMAINING: 313.81 seconds
# Progress: 90.80% Cur Image: 7409.npy TIME REMAINING: 334.08 seconds
# Progress: 90.86% Cur Image: 7414.npy TIME REMAINING: 315.14 seconds
# Progress: 90.92% Cur Image: 7419.npy TIME REMAINING: 314.56 seconds
# Progress: 90.98% Cur Image: 7424.npy TIME REMAINING: 324.80 seconds
# Progress: 91.04% Cur Image: 7429.npy TIME REMAINING: 309.03 seconds
# Progress: 91.10% Cur Image: 7434.npy TIME REMAINING: 318.97 seconds
# Progress: 91.17% Cur Image: 7439.npy TIME REMAINING: 308.48 seconds
# Progress: 91.23% Cur Image: 7444.npy TIME REMAINING: 313.13 seconds
# Progress: 91.29% Cur Image: 7449.npy TIME REMAINING: 303.24 seconds
# Progress: 91.35% Cur Image: 7454.npy TIME REMAINING: 303.25 seconds
# Progress: 91.41% Cur Image: 7459.npy TIME REMAINING: 296.03 seconds
# Progress: 91.47% Cur Image: 7464.npy TIME REMAINING: 286.79 seconds
# Progress: 91.53% Cur Image: 7469.npy TIME REMAINING: 297.00 seconds
# Progress: 91.59% Cur Image: 7474.npy TIME REMAINING: 295.43 seconds
# Progress: 91.66% Cur Image: 7479.npy TIME REMAINING: 296.51 seconds
# Progress: 91.72% Cur Image: 7484.npy TIME REMAINING: 292.26 seconds
# Progress: 91.78% Cur Image: 7489.npy TIME REMAINING: 289.00 seconds
# Progress: 91.84% Cur Image: 7494.npy TIME REMAINING: 288.15 seconds
# Progress: 91.90% Cur Image: 7499.npy TIME REMAINING: 290.69 seconds
# Progress: 91.96% Cur Image: 7504.npy TIME REMAINING: 287.90 seconds
# Progress: 92.02% Cur Image: 7509.npy TIME REMAINING: 286.36 seconds
# Progress: 92.08% Cur Image: 7514.npy TIME REMAINING: 350.43 seconds
# Progress: 92.15% Cur Image: 7519.npy TIME REMAINING: 466.34 seconds
# Progress: 92.21% Cur Image: 7524.npy TIME REMAINING: 248.94 seconds
# Progress: 92.27% Cur Image: 7529.npy TIME REMAINING: 254.82 seconds
# Progress: 92.33% Cur Image: 7534.npy TIME REMAINING: 239.22 seconds
# Progress: 92.39% Cur Image: 7539.npy TIME REMAINING: 244.50 seconds
# Progress: 92.45% Cur Image: 7544.npy TIME REMAINING: 241.99 seconds
# Progress: 92.51% Cur Image: 7549.npy TIME REMAINING: 242.82 seconds
# Progress: 92.57% Cur Image: 7554.npy TIME REMAINING: 242.65 seconds
# Progress: 92.64% Cur Image: 7559.npy TIME REMAINING: 239.88 seconds
# Progress: 92.70% Cur Image: 7564.npy TIME REMAINING: 236.61 seconds
# Progress: 92.76% Cur Image: 7569.npy TIME REMAINING: 245.19 seconds
# Progress: 92.82% Cur Image: 7574.npy TIME REMAINING: 239.12 seconds
# Progress: 92.88% Cur Image: 7579.npy TIME REMAINING: 228.05 seconds
# Progress: 92.94% Cur Image: 7584.npy TIME REMAINING: 224.44 seconds
# Progress: 93.00% Cur Image: 7589.npy TIME REMAINING: 225.85 seconds
# Progress: 93.06% Cur Image: 7594.npy TIME REMAINING: 224.37 seconds
# Progress: 93.13% Cur Image: 7599.npy TIME REMAINING: 217.38 seconds
# Progress: 93.19% Cur Image: 7604.npy TIME REMAINING: 224.15 seconds
# Progress: 93.25% Cur Image: 7609.npy TIME REMAINING: 244.63 seconds
# Progress: 93.31% Cur Image: 7614.npy TIME REMAINING: 236.56 seconds
# Progress: 93.37% Cur Image: 7619.npy TIME REMAINING: 226.64 seconds
# Progress: 93.43% Cur Image: 7624.npy TIME REMAINING: 236.56 seconds
# Progress: 93.49% Cur Image: 7629.npy TIME REMAINING: 228.90 seconds
# Progress: 93.55% Cur Image: 7634.npy TIME REMAINING: 225.58 seconds
# Progress: 93.62% Cur Image: 7639.npy TIME REMAINING: 234.10 seconds
# Progress: 93.68% Cur Image: 7644.npy TIME REMAINING: 225.57 seconds
# Progress: 93.74% Cur Image: 7649.npy TIME REMAINING: 217.55 seconds
# Progress: 93.80% Cur Image: 7654.npy TIME REMAINING: 224.12 seconds
# Progress: 93.86% Cur Image: 7659.npy TIME REMAINING: 220.35 seconds
# Progress: 93.92% Cur Image: 7664.npy TIME REMAINING: 213.53 seconds
# Progress: 93.98% Cur Image: 7669.npy TIME REMAINING: 213.05 seconds
# Progress: 94.04% Cur Image: 7674.npy TIME REMAINING: 203.46 seconds
# Progress: 94.11% Cur Image: 7679.npy TIME REMAINING: 210.10 seconds
# Progress: 94.17% Cur Image: 7684.npy TIME REMAINING: 204.85 seconds
# Progress: 94.23% Cur Image: 7689.npy TIME REMAINING: 207.68 seconds
# Progress: 94.29% Cur Image: 7694.npy TIME REMAINING: 210.02 seconds
# Progress: 94.35% Cur Image: 7699.npy TIME REMAINING: 201.41 seconds
# Progress: 94.41% Cur Image: 7704.npy TIME REMAINING: 206.28 seconds
# Progress: 94.47% Cur Image: 7709.npy TIME REMAINING: 196.45 seconds
# Progress: 94.53% Cur Image: 7714.npy TIME REMAINING: 203.17 seconds
# Progress: 94.60% Cur Image: 7719.npy TIME REMAINING: 203.85 seconds
# Progress: 94.66% Cur Image: 7724.npy TIME REMAINING: 194.79 seconds
# Progress: 94.72% Cur Image: 7729.npy TIME REMAINING: 196.73 seconds
# Progress: 94.78% Cur Image: 7734.npy TIME REMAINING: 190.36 seconds
# Progress: 94.84% Cur Image: 7739.npy TIME REMAINING: 192.72 seconds
# Progress: 94.90% Cur Image: 7744.npy TIME REMAINING: 190.37 seconds
# Progress: 94.96% Cur Image: 7749.npy TIME REMAINING: 190.89 seconds
# Progress: 95.03% Cur Image: 7754.npy TIME REMAINING: 183.78 seconds
# Progress: 95.09% Cur Image: 7759.npy TIME REMAINING: 179.69 seconds
# Progress: 95.15% Cur Image: 7764.npy TIME REMAINING: 181.76 seconds
# Progress: 95.21% Cur Image: 7769.npy TIME REMAINING: 174.64 seconds
# Progress: 95.27% Cur Image: 7774.npy TIME REMAINING: 172.42 seconds
# Progress: 95.33% Cur Image: 7779.npy TIME REMAINING: 178.50 seconds
# Progress: 95.39% Cur Image: 7784.npy TIME REMAINING: 169.04 seconds
# Progress: 95.45% Cur Image: 7789.npy TIME REMAINING: 178.56 seconds
# Progress: 95.52% Cur Image: 7794.npy TIME REMAINING: 349.25 seconds
# Progress: 95.58% Cur Image: 7799.npy TIME REMAINING: 164.59 seconds
# Progress: 95.64% Cur Image: 7804.npy TIME REMAINING: 153.58 seconds
# Progress: 95.70% Cur Image: 7809.npy TIME REMAINING: 145.72 seconds
# Progress: 95.76% Cur Image: 7814.npy TIME REMAINING: 149.85 seconds
# Progress: 95.82% Cur Image: 7819.npy TIME REMAINING: 138.96 seconds
# Progress: 95.88% Cur Image: 7824.npy TIME REMAINING: 134.01 seconds
# Progress: 95.94% Cur Image: 7829.npy TIME REMAINING: 130.08 seconds
# Progress: 96.01% Cur Image: 7834.npy TIME REMAINING: 135.15 seconds
# Progress: 96.07% Cur Image: 7839.npy TIME REMAINING: 132.75 seconds
# Progress: 96.13% Cur Image: 7844.npy TIME REMAINING: 135.01 seconds
# Progress: 96.19% Cur Image: 7849.npy TIME REMAINING: 124.42 seconds
# Progress: 96.25% Cur Image: 7854.npy TIME REMAINING: 130.53 seconds
# Progress: 96.31% Cur Image: 7859.npy TIME REMAINING: 141.54 seconds
# Progress: 96.37% Cur Image: 7864.npy TIME REMAINING: 128.89 seconds
# Progress: 96.43% Cur Image: 7869.npy TIME REMAINING: 137.95 seconds
# Progress: 96.50% Cur Image: 7874.npy TIME REMAINING: 144.57 seconds
# Progress: 96.56% Cur Image: 7879.npy TIME REMAINING: 144.21 seconds
# Progress: 96.62% Cur Image: 7884.npy TIME REMAINING: 131.32 seconds
# Progress: 96.68% Cur Image: 7889.npy TIME REMAINING: 125.43 seconds
# Progress: 96.74% Cur Image: 7894.npy TIME REMAINING: 115.26 seconds
# Progress: 96.80% Cur Image: 7899.npy TIME REMAINING: 115.82 seconds
# Progress: 96.86% Cur Image: 7904.npy TIME REMAINING: 117.92 seconds
# Progress: 96.92% Cur Image: 7909.npy TIME REMAINING: 122.50 seconds
# Progress: 96.99% Cur Image: 7914.npy TIME REMAINING: 127.71 seconds
# Progress: 97.05% Cur Image: 7919.npy TIME REMAINING: 124.64 seconds
# Progress: 97.11% Cur Image: 7924.npy TIME REMAINING: 111.47 seconds
# Progress: 97.17% Cur Image: 7929.npy TIME REMAINING: 116.47 seconds
# Progress: 97.23% Cur Image: 7934.npy TIME REMAINING: 100.57 seconds
# Progress: 97.29% Cur Image: 7939.npy TIME REMAINING: 99.96 seconds
# Progress: 97.35% Cur Image: 7944.npy TIME REMAINING: 97.64 seconds
# Progress: 97.41% Cur Image: 7949.npy TIME REMAINING: 99.36 seconds
# Progress: 97.48% Cur Image: 7954.npy TIME REMAINING: 95.35 seconds
# Progress: 97.54% Cur Image: 7959.npy TIME REMAINING: 105.37 seconds
# Progress: 97.60% Cur Image: 7964.npy TIME REMAINING: 91.46 seconds
# Progress: 97.66% Cur Image: 7969.npy TIME REMAINING: 86.04 seconds
# Progress: 97.72% Cur Image: 7974.npy TIME REMAINING: 81.99 seconds
# Progress: 97.78% Cur Image: 7979.npy TIME REMAINING: 80.44 seconds
# Progress: 97.84% Cur Image: 7984.npy TIME REMAINING: 75.19 seconds
# Progress: 97.90% Cur Image: 7989.npy TIME REMAINING: 76.53 seconds
# Progress: 97.97% Cur Image: 7994.npy TIME REMAINING: 74.16 seconds
# Progress: 98.03% Cur Image: 7999.npy TIME REMAINING: 72.86 seconds
# Progress: 98.09% Cur Image: 8004.npy TIME REMAINING: 72.20 seconds
# Progress: 98.15% Cur Image: 8009.npy TIME REMAINING: 71.64 seconds
# Progress: 98.21% Cur Image: 8014.npy TIME REMAINING: 65.42 seconds
# Progress: 98.27% Cur Image: 8019.npy TIME REMAINING: 62.46 seconds
# Progress: 98.33% Cur Image: 8024.npy TIME REMAINING: 59.56 seconds
# Progress: 98.39% Cur Image: 8029.npy TIME REMAINING: 57.22 seconds
# Progress: 98.46% Cur Image: 8034.npy TIME REMAINING: 57.18 seconds
# Progress: 98.52% Cur Image: 8039.npy TIME REMAINING: 54.24 seconds
# Progress: 98.58% Cur Image: 8044.npy TIME REMAINING: 56.17 seconds
# Progress: 98.64% Cur Image: 8049.npy TIME REMAINING: 72.99 seconds
# Progress: 98.70% Cur Image: 8054.npy TIME REMAINING: 64.68 seconds
# Progress: 98.76% Cur Image: 8059.npy TIME REMAINING: 46.25 seconds
# Progress: 98.82% Cur Image: 8064.npy TIME REMAINING: 43.76 seconds
# Progress: 98.88% Cur Image: 8069.npy TIME REMAINING: 40.76 seconds
# Progress: 98.95% Cur Image: 8074.npy TIME REMAINING: 38.33 seconds
# Progress: 99.01% Cur Image: 8079.npy TIME REMAINING: 36.15 seconds
# Progress: 99.07% Cur Image: 8084.npy TIME REMAINING: 36.54 seconds
# Progress: 99.13% Cur Image: 8089.npy TIME REMAINING: 36.00 seconds
# Progress: 99.19% Cur Image: 8094.npy TIME REMAINING: 29.52 seconds
# Progress: 99.25% Cur Image: 8099.npy TIME REMAINING: 28.91 seconds
# Progress: 99.31% Cur Image: 8104.npy TIME REMAINING: 27.14 seconds
# Progress: 99.38% Cur Image: 8109.npy TIME REMAINING: 22.42 seconds
# Progress: 99.44% Cur Image: 8114.npy TIME REMAINING: 21.33 seconds
# Progress: 99.50% Cur Image: 8119.npy TIME REMAINING: 18.27 seconds
# Progress: 99.56% Cur Image: 8124.npy TIME REMAINING: 17.41 seconds
# Progress: 99.62% Cur Image: 8129.npy TIME REMAINING: 14.40 seconds
# Progress: 99.68% Cur Image: 8134.npy TIME REMAINING: 12.58 seconds
# Progress: 99.74% Cur Image: 8139.npy TIME REMAINING: 10.77 seconds
# Progress: 99.80% Cur Image: 8144.npy TIME REMAINING: 7.77 seconds
# Progress: 99.87% Cur Image: 8149.npy TIME REMAINING: 5.20 seconds
# Progress: 99.93% Cur Image: 8154.npy TIME REMAINING: 2.63 seconds
# Progress: 99.99% Cur Image: 8159.npy TIME REMAINING: 0.48 seconds
# /Volumes/GoogleDrive/My Drive/TemporalData-Processed-Train-SWIR/labels.npy
# (8162, 4, 51, 51)
# (4, 3)

# %%
np.save(os.path.join(src_DIR, 'Collated.npy'), X_data)

# %%
#X_data = np.load('/Volumes/GoogleDrive/My Drive/TemporalData-Processed-Train/Collated.npy')
#y_data = np.load('/Volumes/GoogleDrive/My Drive/TemporalData-Processed-Train/labels.npy')
X_test = np.load('/Volumes/GoogleDrive/My Drive/TemporalData-Processed-Eval/Collated.npy')
y_test = np.load('/Volumes/GoogleDrive/My Drive/TemporalData-Processed-Eval/labels.npy')

# %%
X_train, X_val, y_train, y_val = train_test_split(X_data[:-1], y_data, test_size=0.20, random_state=42)

# %% [markdown]
# Total Images for Temporal: 43,652
#
# Total Images for Spatial: 35,340
#
# Temporal:
#
# Training: (6528, 4, 51, 51, 3), (6528, 3)
#
# Validation: (1633, 4, 51, 51, 3), (1633, 3)
#
# Testing: (2752, 4, 51, 51, 3), (2751, 3)
#
# Spatial:

# %%
print ("Training: {}, {}".format(X_train.shape, y_train.shape))
print ("Validation: {}, {}".format(X_val.shape, y_val.shape))
print ("Testing: {}, {}".format(X_test.shape, y_test.shape))
# Out:
# Training: (6528, 4, 51, 51, 3), (6528, 3)
# Validation: (1633, 4, 51, 51, 3), (1633, 3)
# Testing: (2752, 4, 51, 51, 3), (2751, 3)

# %%
# Construct a figure on which we will visualize the images.
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

# Plot each of the sequential images for one random data example.
data_choice = np.random.choice(range(len(X_data)), size=1)[0]
for idx, ax in enumerate(axes.flat):
    new_img = X_data[data_choice][idx]
    ax.imshow(np.squeeze(new_img))
    ax.set_title(f"Frame {idx + 1}")
    ax.axis("off")

# Print information and display the figure.
print(f"Displaying frames for example {data_choice}.")
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Displaying frames for example 7296.

# %%
# # Construct the input layer with no definite frame size.
# inp = layers.Input(shape=(None, *X_train.shape[2:]))

# # We will construct 3 `ConvLSTM2D` layers with batch normalization,
# # followed by a `Conv3D` layer for the spatiotemporal outputs.
# x = layers.ConvLSTM2D(
#     filters=64,
#     kernel_size=(5, 5),
#     padding="same",
#     return_sequences=True,
#     activation="relu",
# )(inp)
# x = layers.BatchNormalization()(x)
# x = layers.ConvLSTM2D(
#     filters=64,
#     kernel_size=(3, 3),
#     padding="same",
#     return_sequences=True,
#     activation="relu",
# )(x)
# x = layers.BatchNormalization()(x)
# x = layers.ConvLSTM2D(
#     filters=64,
#     kernel_size=(1, 1),
#     padding="same",
#     return_sequences=True,
#     activation="relu",
# )(x)
# x = layers.Conv3D(
#     filters=3, kernel_size=(3, 3, 3), activation="softmax", padding="same"
# )(x)

# # Next, we will build the complete model and compile it.
# model = keras.models.Model(inp, x)
# model.compile(
#     loss=keras.losses.binary_crossentropy, optimizer=keras.optimizers.Adam(),
# )

# %%
# # Define some callbacks to improve training.
# early_stopping = keras.callbacks.EarlyStopping(monitor="val_loss", patience=10)
# reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor="val_loss", patience=5)

# # Define modifiable training hyperparameters.
# epochs = 5
# batch_size = 5

# # Fit the model to the training data.
# model.fit(
#     X_train,
#     y_train,
#     batch_size=batch_size,
#     epochs=epochs,
#     validation_data=(X_val, y_val),
#     callbacks=[early_stopping, reduce_lr],
# )
# Out:
# Epoch 1/5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-144762e978fe> in <module>
#       8
#       9 # Fit the model to the training data.
# ---> 10 model.fit(
#      11     X_train,
#      12     y_train,
#
# ~/miniconda3/envs/tile2vec/lib/python3.8/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~/miniconda3/envs/tile2vec/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in autograph_handler(*args, **kwargs)
#    1127           except Exception as e:  # pylint:disable=broad-except
#    1128             if hasattr(e, "ag_error_metadata"):
# -> 1129               raise e.ag_error_metadata.to_exception(e)
#    1130             else:
#    1131               raise
#
# ValueError: in user code:
#
#     File "/Users/calummcmeekin/miniconda3/envs/tile2vec/lib/python3.8/site-packages/keras/engine/training.py", line 878, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/calummcmeekin/miniconda3/envs/tile2vec/lib/python3.8/site-packages/keras/engine/training.py", line 867, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/calummcmeekin/miniconda3/envs/tile2vec/lib/python3.8/site-packages/keras/engine/training.py", line 860, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/calummcmeekin/miniconda3/envs/tile2vec/lib/python3.8/site-packages/keras/engine/training.py", line 809, in train_step
#         loss = self.compiled_loss(
#     File "/Users/calummcmeekin/miniconda3/envs/tile2vec/lib/python3.8/site-packages/keras/engine/compile_utils.py", line 201, in __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "/Users/calummcmeekin/miniconda3/envs/tile2vec/lib/python3.8/site-packages/keras/losses.py", line 141, in __call__
#         losses = call_fn(y_true, y_pred)
#     File "/Users/calummcmeekin/miniconda3/envs/tile2vec/lib/python3.8/site-packages/keras/losses.py", line 245, in call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "/Users/calummcmeekin/miniconda3/envs/tile2vec/lib/python3.8/site-packages/keras/losses.py", line 1807, in binary_crossentropy
#         backend.binary_crossentropy(y_true, y_pred, from_logits=from_logits),
#     File "/Users/calummcmeekin/miniconda3/envs/tile2vec/lib/python3.8/site-packages/keras/backend.py", line 5158, in binary_crossentropy
#         return tf.nn.sigmoid_cross_entropy_with_logits(labels=target, logits=output)
#
#     ValueError: `logits` and `labels` must have the same shape, received ((None, 4, 51, 51, 3) vs (None, 3)).

# %%
from keras.models import Sequential, Model 

batch_size = 100
epochs = 1

model = Sequential()
model.add(
    layers.ConvLSTM2D(
        filters = 64, 
        kernel_size = (3, 3), 
        return_sequences = False, 
        data_format = "channels_last", 
        input_shape = (4, 51, 51, 3)
    )
)
model.add(
    layers.Dropout(0.2)
)
model.add(
    layers.Flatten()
)
model.add(
    layers.Dense(256, activation="relu")
)
model.add(
    layers.Dropout(0.3)
)
model.add(
    layers.Dense(3, activation = "softmax")
)
 
model.summary()

#opt = keras.optimizers.SGD(lr=0.001)
opt = keras.optimizers.Adam()

early_stopping = keras.callbacks.EarlyStopping(monitor="val_loss", patience=10)
reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor="val_loss", patience=5)

model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=["accuracy"])
 
callbacks = [early_stopping, reduce_lr]
 
history = model.fit(
    X_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    callbacks=[early_stopping, reduce_lr],
)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_lstm2d_2 (ConvLSTM2D)  (None, 49, 49, 64)        154624
#
#  dropout_4 (Dropout)         (None, 49, 49, 64)        0
#
#  flatten_2 (Flatten)         (None, 153664)            0
#
#  dense_4 (Dense)             (None, 256)               39338240
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 39,493,635
# Trainable params: 39,493,635
# Non-trainable params: 0
# _________________________________________________________________
# 66/66 [==============================] - 875s 13s/step - loss: 3.3457 - accuracy: 0.6463 - val_loss: 0.5363 - val_accuracy: 0.7685 - lr: 0.0010

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([[0.07264602, 0.8493258 , 0.07802824],
#        [0.9753186 , 0.01641382, 0.00826761],
#        [0.04599274, 0.55436516, 0.39964217],
#        ...,
#        [0.09036884, 0.54387844, 0.36575273],
#        [0.26394713, 0.4346916 , 0.3013613 ],
#        [0.03977095, 0.5872738 , 0.37295523]], dtype=float32)

# %%
from sklearn.metrics import classification_report

y_pred_ugly = y_pred.argmax(axis = 1)
y_test_ugly = y_test.argmax(axis = 1)
 
print(classification_report(y_test_ugly, y_pred_ugly[0:-1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.89      0.88      1171
#            1       0.61      0.92      0.73       800
#            2       0.86      0.39      0.54       780
#
#     accuracy                           0.75      2751
#    macro avg       0.78      0.73      0.72      2751
# weighted avg       0.79      0.75      0.74      2751

# %%
from DataBuilder import *

get_data()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-7408fb02e273> in <module>
#       1 from DataBuilder import *
#       2
# ----> 3 get_data()
#
# ~/Documents/GitHub/MInf-Project/Part 2/ImageAcquisition/src/DataBuilder.py in get_data()
#      27     head_DIR = '/Volumes/GoogleDrive/My Drive/TemporalData'
#      28     save_DIR = '/Volumes/GoogleDrive/My Drive/TemporalData-Processed'
# ---> 29     test_DIR = '/Users/calummcmeekin/Documents/GitHub/MInf-Project/Part 2/ImageAcquisition/src'
#      30     subfolders = [f.path for f in os.scandir(test_DIR) if f.is_dir()]
#      31     idx = 0
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Volumes/GoogleDrive/My Drive/TemporalData'

# %%
amazonia_img_dir = '../data/Amazon' # directory where amazonia images are saved

cerrado_img_dir = '../data/Cerrado' # directory where cerrado images are saved

caatinga_img_dir = '../data/Caatinga' # directory where caatinga images are saved

# Get Amazonia triplets
amazonia_img_triplets = get_triplet_imgs(amazonia_img_dir, n_triplets=30000) 

# Get Cerrado triplets
cerrado_img_triplets = get_triplet_imgs(cerrado_img_dir, n_triplets=25000) 

# Get Amazonia
caatinga_img_triplets = get_triplet_imgs(caatinga_img_dir, n_triplets=25000)


print(cerrado_img_triplets[:5,:])

# %% [markdown]
# # ResNet

# %%
X_data = np.load('/Volumes/GoogleDrive/My Drive/ResNet18-2019-Training/train_data.npy')
y_data = np.load('/Volumes/GoogleDrive/My Drive/ResNet18-2019-Training/labels.npy')
#X_test = np.load('/Volumes/GoogleDrive/My Drive/TemporalData-Processed-Eval/Collated.npy')
#y_test = np.load('/Volumes/GoogleDrive/My Drive/TemporalData-Processed-Eval/labels.npy')

# %%
X_train, X_val, y_train, y_val = train_test_split(X_data, y_data, test_size=0.20, random_state=42)

# %%
# !pip install img2vec_pytorch
# Out:
# Requirement already satisfied: img2vec_pytorch in /Users/calummcmeekin/miniconda3/envs/tile2vec/lib/python3.8/site-packages (0.2.5)
# Requirement already satisfied: numpy in /Users/calummcmeekin/miniconda3/envs/tile2vec/lib/python3.8/site-packages (from img2vec_pytorch) (1.18.4)
# Requirement already satisfied: torchvision in /Users/calummcmeekin/miniconda3/envs/tile2vec/lib/python3.8/site-packages (from img2vec_pytorch) (0.6.1)
# Requirement already satisfied: torch in /Users/calummcmeekin/miniconda3/envs/tile2vec/lib/python3.8/site-packages (from img2vec_pytorch) (1.5.1)
# Requirement already satisfied: pillow>=4.1.1 in /Users/calummcmeekin/miniconda3/envs/tile2vec/lib/python3.8/site-packages (from torchvision->img2vec_pytorch) (7.1.2)
# Requirement already satisfied: future in /Users/calummcmeekin/miniconda3/envs/tile2vec/lib/python3.8/site-packages (from torch->img2vec_pytorch) (0.18.2)

# %%
z_dim = 512
cuda = torch.cuda.is_available()
print (cuda)
# Out:
# False

# %%
def get_ResNet_Prediction(X_train):
    # Initialize Img2Vec with GPU
    img2vec = Img2Vec(cuda)

    UPSCALE = False
    t0 = time()

    X_pred = np.zeros((len(X_train), z_dim))

    for idx in range(len(X_train)):

        # Read in an image
        img = X_train[idx]

        # Upscale image
        if (UPSCALE):
            x, y, z = img.shape

            img = resize(img, (224, 224,z))
        
        im = Image.fromarray((img * 255).astype(np.uint8))   

        vec = img2vec.get_vec(im, tensor=True)
        
        new_vec = [x for x in vec[0]]

        X_pred[idx, :] = new_vec
        
        if (idx % 1000 == 0):
            print ("Progress: {:.2f}%".format(idx/len(X_train)*100))
            
    t1 = time()
    print('Embedded {} images: {:0.3f}s'.format(len(X_train), t1-t0))
    return X_pred

# %%
X_train_emb = get_ResNet_Prediction(X_train)
X_val_emb = get_ResNet_Prediction(X_val)
# Out:
# /Users/calummcmeekin/miniconda3/envs/tile2vec/lib/python3.8/site-packages/torchvision/transforms/transforms.py:210: UserWarning: The use of the transforms.Scale transform is deprecated, please use transforms.Resize instead.
#   warnings.warn("The use of the transforms.Scale transform is deprecated, " +
# Progress: 0.00%
# Embedded 44 images: 3.541s
# Progress: 0.00%
# Embedded 11 images: 0.892s

# %% [markdown]
# ## Multinomial Logistic Regression

# %%
y_train_ugly = one_ugly_encoding(y_train)
y_val_ugly = one_ugly_encoding(y_val)
print (y_val_ugly)
# Out:
# [2 1 2 1 1 3 3 2 3 1 3]

# %%
n_trials = 1
accs = np.zeros((n_trials,))
precisions = np.zeros((n_trials,))
recalls = np.zeros((n_trials,))
fscores = np.zeros((n_trials,))

for i in range(n_trials):
    
    # Splitting data and training RF classifer
    # Define the multinomial logistic regression model    
    lr = make_pipeline(StandardScaler(), LogisticRegression(max_iter=1000, solver='saga', multi_class='multinomial'))
    
    # Fit the model on the whole dataset
    lr.fit(X_train_emb, y_train_ugly)
    
    accs[i] = lr.score(X_val_emb, y_val_ugly)
    
    y_pred = lr.predict(X_val_emb)
        
    precisions[i], recalls[i], fscores[i], _ = precision_recall_fscore_support(y_val_ugly, y_pred, average='macro')
    
    print ("TRIAL: {}".format(i))
    
print ("____Accuracy____")
print('Mean accuracy: {:0.4f}'.format(accs.mean()))
print('Standard deviation: {:0.4f}'.format(accs.std()))

print ("____Macro Precision____")
print('Mean macro precision: {:0.4f}'.format(precisions.mean()))
print('Standard deviation: {:0.4f}'.format(precisions.std()))

print ("____Macro Recall____")
print('Mean macro recall: {:0.4f}'.format(recalls.mean()))
print('Standard deviation: {:0.4f}'.format(recalls.std()))

print ("____Macro F1-Score____")
print('Mean macro F1-Score: {:0.4f}'.format(fscores.mean()))
print('Standard deviation: {:0.4f}'.format(fscores.std()))
# Out:
# TRIAL: 0
# ____Accuracy____
# Mean accuracy: 0.6364
# Standard deviation: 0.0000
# ____Macro Precision____
# Mean macro precision: 0.6333
# Standard deviation: 0.0000
# ____Macro Recall____
# Mean macro recall: 0.6389
# Standard deviation: 0.0000
# ____Macro F1-Score____
# Mean macro F1-Score: 0.6111
# Standard deviation: 0.0000
